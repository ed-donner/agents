# %%
# Import required libraries
from dotenv import load_dotenv
from openai import OpenAI
import os

# Load variables from .env
load_dotenv(override=True)

# Read your Gemini API key
gemini_api_key = os.getenv("GEMINI_API_KEY")

# Create the OpenAI client for Gemini
openai = OpenAI(
    api_key=gemini_api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

print("Setup completed successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 messages = [{"role": "user", "content": "Choose one business area that has potential for improvement using AI.Respond only with the name of Business area"}]
#       4
#       5 # Then make the first call:
#       6
# ----> 7 response = openai.chat.completions.create(model="models/gemini-flash-latest", messages=messages)
#       8
#       9 # Then read the business idea:
#      10
#
# NameError: name 'openai' is not defined
