# %% [markdown]
# ### Week 5 Day 4
#
# AutoGen Core - Distributed
#
# I'm only going to give a Teaser of this!!
#
# Partly because I'm unsure how relevant it is to you. If you'd like me to add more content for this, please do let me know..

# %%
from dataclasses import dataclass
from autogen_core import AgentId, MessageContext, RoutedAgent, message_handler
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.messages import TextMessage
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_ext.tools.langchain import LangChainToolAdapter
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain.agents import Tool
from IPython.display import display, Markdown
from autogen_core.models import ModelInfo

from dotenv import load_dotenv
import os

load_dotenv(override=True)

ALL_IN_ONE_WORKER = False

# %% [markdown]
# ### Start with our Message class

# %%
@dataclass
class Message:
    content: str

# %% [markdown]
# ### And now - a host for our distributed runtime

# %%
from autogen_ext.runtimes.grpc import GrpcWorkerAgentRuntimeHost

host = GrpcWorkerAgentRuntimeHost(address="localhost:50051")
host.start()

# %% [markdown]
# ### Let's reintroduce a tool

# %%
serper = GoogleSerperAPIWrapper()
langchain_serper =Tool(name="internet_search", func=serper.run, description="Useful for when you need to search the internet")
autogen_serper = LangChainToolAdapter(langchain_serper)

# %%
instruction1 = "To help with a decision on whether to use AutoGen in a new AI Agent project, \
please research and briefly respond with reasons in favor of choosing AutoGen; the pros of AutoGen."

instruction2 = "To help with a decision on whether to use AutoGen in a new AI Agent project, \
please research and briefly respond with reasons against choosing AutoGen; the cons of Autogen."

judge = "You must make a decision on whether to use AutoGen for a project. \
Your research team has come up with the following reasons for and against. \
Based purely on the research from your team, please respond with your decision and brief rationale."

# %% [markdown]
# ### And make some Agents

# %%
class Player1Agent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        #model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")
        model_client = OpenAIChatCompletionClient(
            model="gemini-2.5-flash",
            api_key=os.environ["GOOGLE_API_KEY"],
            base_url="https://generativelanguage.googleapis.com/v1beta/openai",
            model_info=ModelInfo(
            vision=True, 
            function_calling=True,
            json_output=True, 
            family="gemini-2.5", 
            structured_output=True
            )
        )   
        self._delegate = AssistantAgent(name, model_client=model_client, tools=[autogen_serper], reflect_on_tool_use=True)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        return Message(content=response.chat_message.content)
    
class Player2Agent(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        #model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")
        model_client = OpenAIChatCompletionClient(
            model="gemini-2.5-flash",
            api_key=os.environ["GOOGLE_API_KEY"],
            base_url="https://generativelanguage.googleapis.com/v1beta/openai",
            model_info=ModelInfo(
            vision=True, 
            function_calling=True,
            json_output=True, 
            family="gemini-2.5", 
            structured_output=True
            )
        )   
        self._delegate = AssistantAgent(name, model_client=model_client, tools=[autogen_serper], reflect_on_tool_use=True)

    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        text_message = TextMessage(content=message.content, source="user")
        response = await self._delegate.on_messages([text_message], ctx.cancellation_token)
        return Message(content=response.chat_message.content)
    
class Judge(RoutedAgent):
    def __init__(self, name: str) -> None:
        super().__init__(name)
        #model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")
        model_client = OpenAIChatCompletionClient(
            model="gemini-2.5-flash",
            api_key=os.environ["GOOGLE_API_KEY"],
            base_url="https://generativelanguage.googleapis.com/v1beta/openai",
            model_info=ModelInfo(
            vision=True, 
            function_calling=True,
            json_output=True, 
            family="gemini-2.5", 
            structured_output=True
            )
        )   
        self._delegate = AssistantAgent(name, model_client=model_client)
        
    @message_handler
    async def handle_my_message_type(self, message: Message, ctx: MessageContext) -> Message:
        message1 = Message(content=instruction1)
        message2 = Message(content=instruction2)
        inner_1 = AgentId("player1", "default")
        inner_2 = AgentId("player2", "default")
        response1 = await self.send_message(message1, inner_1)
        response2 = await self.send_message(message2, inner_2)
        result = f"## Pros of AutoGen:\n{response1.content}\n\n## Cons of AutoGen:\n{response2.content}\n\n"
        judgement = f"{judge}\n{result}Respond with your decision and brief explanation"
        message = TextMessage(content=judgement, source="user")
        response = await self._delegate.on_messages([message], ctx.cancellation_token)
        return Message(content=result + "\n\n## Decision:\n\n" + response.chat_message.content)

# %%
from autogen_ext.runtimes.grpc import GrpcWorkerAgentRuntime

if ALL_IN_ONE_WORKER:

    worker = GrpcWorkerAgentRuntime(host_address="localhost:50051")
    await worker.start()

    await Player1Agent.register(worker, "player1", lambda: Player1Agent("player1"))
    await Player2Agent.register(worker, "player2", lambda: Player2Agent("player2"))
    await Judge.register(worker, "judge", lambda: Judge("judge"))

    agent_id = AgentId("judge", "default")

else:

    worker1 = GrpcWorkerAgentRuntime(host_address="localhost:50051")
    await worker1.start()
    await Player1Agent.register(worker1, "player1", lambda: Player1Agent("player1"))

    worker2 = GrpcWorkerAgentRuntime(host_address="localhost:50051")
    await worker2.start()
    await Player2Agent.register(worker2, "player2", lambda: Player2Agent("player2"))

    worker = GrpcWorkerAgentRuntime(host_address="localhost:50051")
    await worker.start()
    await Judge.register(worker, "judge", lambda: Judge("judge"))
    agent_id = AgentId("judge", "default")

# %%
response = await worker.send_message(Message(content="Go!"), agent_id)

# %%
display(Markdown(response.content))
# Out:
# ## Pros of AutoGen:
# AutoGen offers several compelling advantages for AI Agent projects:
#
# *   **Multi-Agent Communication and Coordination:** It excels at orchestrating complex interactions between multiple AI agents, allowing them to collaborate, communicate, and coordinate tasks effectively to achieve a common goal.
# *   **Tool and API Integration:** AutoGen can seamlessly integrate with various APIs, external tools, and systems, significantly enhancing the agents' functionality and allowing them to perform a wider range of actions and access external data.
# *   **Customizable Agent Roles and Behaviors:** It provides the flexibility to define custom roles, behaviors, and capabilities for each individual agent, allowing developers to tailor agents precisely to specific tasks and project requirements.
# *   **Versatile Application:** AutoGen is well-suited for a broad spectrum of AI applications, including automation of workflows, complex data analysis tasks, and building sophisticated conversational AI systems.
#
# ## Cons of AutoGen:
# Here are some reasons against choosing AutoGen for a new AI Agent project, based on common feedback regarding its limitations:
#
# *   **Higher Technical Barrier:** AutoGen requires a deeper understanding of multi-agent systems and how different agents interact and collaborate. This can be a significant hurdle for teams new to this paradigm.
# *   **Complex Setup and Configuration:** Getting started with AutoGen often involves a more complex setup process and requires more technical knowledge and time to configure agents and their interactions effectively compared to simpler frameworks.
# *   **Agent Coordination Complexity:** As the number of agents and the complexity of their tasks grow, managing and orchestrating their coordination can become challenging and difficult to optimize.
# *   **Debugging Challenges:** Debugging multi-agent systems, especially when interactions are complex and involve multiple steps and decision points, can be significantly more difficult than debugging a single-agent system. Tracing issues across agents can be time-consuming.
# *   **Production Deployment Considerations:** Moving an AutoGen-based multi-agent system from development to production can present challenges related to scalability, resource management, and robust error handling in a live environment.
#
#
#
# ## Decision:
#
# Based purely on the research provided:
#
# **Decision:** Do not use AutoGen.
#
# **Rationale:** While AutoGen offers compelling advantages for multi-agent communication, tool integration, and customization for complex AI agent projects, the research highlights significant practical challenges. These include a high technical barrier, complex setup and configuration, increasing coordination complexity with scale, severe debugging difficulties, and notable hurdles for production deployment. These operational complexities cumulatively suggest that the overhead in development, maintenance, and deployment would be substantial, potentially outweighing the benefits for a new project.

# %%
await worker.stop()
if not ALL_IN_ONE_WORKER:
    await worker1.stop()
    await worker2.stop()

# %%
await host.stop()
