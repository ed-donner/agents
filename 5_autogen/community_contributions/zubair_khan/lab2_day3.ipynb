# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../../../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Welcome to the Lab2 Week 1, Day 3</h2>
#             <span style="color:#ff7800;">Problem Statement:
#                 Develop an AI governance controls framework in an health care company wherein the need to adhere to processes are very high.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")
google_api_key = os.getenv("GOOGLE_API_KEY")
groq_api_key = os.getenv("GROQ_API_KEY")

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Google API Key exists and begins AI
# Groq API Key exists and begins gsk_

# %%
question = "Please develop an AI governance controls framework for an health care company wherein the need to adhere to processes are very high "
question += "Answer should be in bullet points, no explanation."
messages = [{"role": "user", "content": question}]

# %%
print(messages)
# Out:
# [{'role': 'user', 'content': 'Please develop an AI governance controls framework for an health care company wherein the need to adhere to processes are very high Answer should be in bullet points, no explanation.'}]

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %%
model_name = "gpt-5-mini"
openai = OpenAI()

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# - Governance & oversight
#   - Establish AI Governance Committee with defined charter, membership, authority, meeting cadence
#   - Appoint accountable roles: Executive Sponsor, AI Program Lead, Clinical Safety Officer, Data Protection Officer, Security Lead
#   - Define roles & responsibilities (RACI) for all AI lifecycle activities
#   - Formal policy suite: AI policy, acceptable-use, safety, risk, privacy, procurement, third-party, and lifecycle policies
#   - Approval gates and mandatory sign-offs for design, validation, deployment, and retirement
#   - Periodic governance reviews and board-level reporting
#
# - Risk management
#   - Mandatory pre-deployment AI risk assessment (clinical, safety, privacy, security, operational, reputational)
#   - Documented risk treatment plans with owners, mitigations, and residual risk acceptance
#   - Periodic risk re-assessments and event-driven reassessments
#   - Threat modeling and clinical hazard analysis (FMEA/HIRA) for each model/use case
#
# - Regulatory & legal compliance
#   - Maintain regulatory mapping (HIPAA, HITECH, FDA/EMA SaMD guidance, GDPR, local healthcare laws)
#   - Legal review and regulatory submission gating where required
#   - Maintain audit trails and records to satisfy regulatory inspections
#   - Maintain process for mandatory adverse event and breach reporting
#
# - Data governance & management
#   - Data provenance, lineage, and cataloging for all datasets used in development and monitoring
#   - Consent management and lawful basis documentation for patient data use
#   - De-identification/pseudonymization standards and data minimization rules
#   - Data quality controls: validation, completeness, labeling standards, error-rate thresholds
#   - Controlled data access policies and segmented environments for training vs production
#   - Retention, archival, and deletion schedules consistent with regulations
#
# - Security & privacy controls
#   - Encryption of data at rest and in transit; robust key management
#   - Identity and Access Management (RBAC, least privilege, MFA) for all systems
#   - Privileged access management and periodic access reviews
#   - Secure development lifecycle (S-SDLC), code reviews, static/dynamic analysis
#   - Vulnerability scanning, penetration testing, and third-party security assessments
#   - Logging, centralized monitoring (SIEM), tamper-evident audit logs
#   - Data leakage and exfiltration controls, DLP policies
#
# - Model development & lifecycle controls
#   - Standardized MLOps pipeline with version control for code, data, models, and configs
#   - Reproducibility requirements: seed, environment, dependency manifest, training artifacts
#   - Model documentation (model cards, data sheets) mandatory before approval
#   - Peer code review and model design review checkpoints
#   - Secure artifact signing and immutable storage for approved models
#   - Environment isolation between development, staging, and production
#
# - Validation & verification
#   - Pre-deployment validation plan: unit, integration, system, clinical validation
#   - Define acceptance criteria and performance thresholds aligned to clinical safety needs
#   - Bias, fairness, and subgroup performance testing with documented remediation
#   - Adversarial, robustness, and edge-case testing
#   - Clinical validation: retrospective, prospective, and real-world performance studies as required
#   - Independent technical and clinical review prior to release
#
# - Deployment & change control
#   - Formal change management process with change requests, impact analysis, approvals, and rollback plans
#   - Staged deployment practices (canary, blue/green, phased rollout) and monitoring gates
#   - Deployment checklist including security, privacy, performance, logging, alerting
#   - Emergency rollback and mitigation procedures with tested runbooks
#
# - Monitoring & operations
#   - Continuous monitoring for model performance, calibration, concept/data drift, and safety signals
#   - Alerting thresholds, automated alerts, and defined escalation paths
#   - Operational logging of model inputs, outputs, decisions, and user interactions (with privacy controls)
#   - Regular performance reporting vs. baseline and clinical KPIs
#   - Scheduled retraining triggers and controlled model update process
#
# - Incident management & response
#   - AI incident response plan integrated into enterprise incident response
#   - Defined incident categorization, triage, root cause analysis, remediation and communication procedures
#   - Regulatory and patient notification templates and timelines
#   - Post-incident review, corrective/preventive actions, and evidence retention
#
# - Third-party & vendor management
#   - Due diligence and security/privacy questionnaires for vendors and pre-trained models
#   - Contract clauses: compliance, audit rights, data usage limits, liability, termination and transition
#   - SLA definitions for availability, performance, incident response, and data return/destruction
#   - Ongoing vendor monitoring and periodic reassessments
#
# - Ethics, transparency & patient rights
#   - Ethical review board for high-risk or novel AI uses
#   - Requirements for explainability/interpretability appropriate to clinical context
#   - Informed consent or disclosure requirements for patients and clinicians
#   - Ability for human override and clear human-in-loop responsibilities
#   - Policies for prohibited or restricted uses
#
# - Documentation & recordkeeping
#   - Maintain complete lifecycle records: requirements, specs, datasets, training logs, validation reports, deployment records, monitoring logs, incident records
#   - Model card, data sheet, clinical safety case, and validation dossier mandatory for each model
#   - Immutable audit trail and retention schedules aligned to regulatory requirements
#
# - Training & competency
#   - Role-based mandatory training: clinical safety, AI literacy, data privacy, secure coding, incident handling
#   - Certification/approval for clinical users before live use
#   - Training records, refresh schedules, and competency assessments
#
# - Audit, assurance & continuous improvement
#   - Internal and independent external audits of AI processes and controls
#   - Periodic assurance reviews and remediation tracking
#   - Continuous improvement program with lessons-learned and control updates
#   - Maturity model and roadmap for AI governance adoption
#
# - Access, identity & privilege controls
#   - Enforce least privilege, MFA, session timeouts, and SSO
#   - Periodic privileged access reviews and just-in-time access for high-risk operations
#   - Session recording and activity logging for critical actions
#
# - Business continuity & resilience
#   - Business continuity and disaster recovery plans for AI systems with defined RTO/RPO
#   - High-availability and failover strategies; safe-mode operational procedures
#   - Regular DR testing and recovery validation
#
# - Metrics, KPIs & reporting
#   - Define clinical and operational KPIs: sensitivity/specificity, calibration, false negatives (safety-critical), uptime, incident metrics
#   - Executive dashboards and periodic reporting to governance committee
#   - Thresholds for intervention and automated remediation triggers
#
# - Clinical safety & patient harm mitigation
#   - Clinical safety case for each AI system documenting hazards, mitigations, and residual risk
#   - Active surveillance for patient harm and near-miss events
#   - Safety monitoring board for high-risk applications and periodic safety reviews
#
# - Procurement & contracting controls
#   - Standard procurement checklist including regulatory evidence, validation artifacts, security posture
#   - Source code/model escrow and transition plans where appropriate
#   - Termination clauses to ensure data return/destruction and continuity
#
# - Change/version control & retirement
#   - Formal versioning schema and immutable change logs for models and data
#   - Retirement criteria, decommissioning checklist, and archival procedures
#   - Backwards-compatibility and migration plans for model updates
#
# - Legal, insurance & liability
#   - Legal review for liability allocation and compliance risk
#   - Appropriate cyber and professional liability insurance coverage
#   - Process for indemnity and contractual risk allocation
#
# - Implementation & maturity roadmap
#   - Phased implementation plan with prioritized controls for high-risk systems first
#   - Target maturity levels, timelines, and resourcing plan
#   - Continuous measurement against maturity targets and periodic reassessment

# %%
model_name = "gemini-2.5-flash-lite"
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# *   **AI Ethics Committee:**
# *   **AI Risk Assessment Framework:**
# *   **Data Privacy and Security Protocols:**
# *   **AI Model Validation and Verification Procedures:**
# *   **Transparency and Explainability Requirements:**
# *   **Bias Detection and Mitigation Strategies:**
# *   **Human Oversight and Intervention Guidelines:**
# *   **Accountability and Responsibility Matrix:**
# *   **Regulatory Compliance Monitoring:**
# *   **AI Incident Response Plan:**
# *   **Continuous AI Performance Monitoring:**
# *   **Data Governance Policies for AI:**
# *   **AI Training and Awareness Programs:**
# *   **Algorithmic Auditing Procedures:**
# *   **Third-Party AI Vendor Due Diligence:**
# *   **Patient Consent Management for AI Use:**
# *   **AI Model Lifecycle Management:**
# *   **Documentation Standards for AI Development:**
# *   **Ethical AI Design Principles:**
# *   **Adversarial Robustness Testing:**

# %%
model_name="openai/gpt-oss-120b"
groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# - **Governance Structure**
#   - Establish an AI Governance Board with senior executives, clinical leaders, compliance officers, and data privacy experts.
#   - Define clear roles and responsibilities for AI owners, developers, data stewards, and auditors.
#   - Create an AI Ethics Committee to review high‑risk use cases and ensure alignment with patient‑centered values.
#
# - **Risk Management**
#   - Conduct AI Risk Assessments for every model before deployment (clinical impact, safety, privacy, bias, regulatory).
#   - Classify AI systems by risk tier (e.g., Tier 1 = critical patient care; Tier 2 = operational support; Tier 3 = administrative).
#   - Require formal risk mitigation plans for Tier 1 and Tier 2 systems.
#
# - **Regulatory & Compliance**
#   - Map AI processes to relevant regulations (HIPAA, GDPR, FDA Software as a Medical Device, HITECH, state privacy laws).
#   - Implement a compliance checklist for model development, validation, and release.
#   - Maintain a regulatory filing log and ensure timely submissions for FDA‑cleared algorithms.
#
# - **Data Governance**
#   - Enforce data provenance tracking for all training, validation, and inference datasets.
#   - Apply strict de‑identification and anonymization standards; obtain documented patient consent where required.
#   - Implement role‑based access controls (RBAC) and audit trails for data handling.
#
# - **Model Development Lifecycle**
#   - Standardize a phased workflow: problem definition → data collection → preprocessing → model design → training → validation → clinical evaluation → deployment → post‑market surveillance.
#   - Require documented version control for code, data, and model artifacts.
#   - Use reproducible pipelines (e.g., containerization, CI/CD) with automated testing suites.
#
# - **Validation & Testing**
#   - Perform internal validation on representative patient cohorts; document performance metrics (sensitivity, specificity, AUC, calibration).
#   - Conduct external validation with independent datasets before clinical use.
#   - Require bias analysis across demographics (age, gender, race, socioeconomic status) and implement corrective measures.
#
# - **Deployment Controls**
#   - Enforce change‑control procedures for model updates; require impact analysis and sign‑off from the AI Governance Board.
#   - Deploy models in a staged manner (sandbox → pilot → full rollout) with real‑time monitoring thresholds.
#   - Integrate fail‑safe mechanisms (e.g., human‑in‑the‑loop overrides) for high‑risk decisions.
#
# - **Monitoring & Performance Management**
#   - Implement continuous monitoring dashboards for model drift, data drift, and outcome variance.
#   - Set automated alerts for deviations beyond predefined thresholds.
#   - Schedule periodic re‑validation (e.g., quarterly) and retraining cycles as needed.
#
# - **Incident Management**
#   - Define an AI Incident Response Plan (detection, containment, investigation, remediation, reporting).
#   - Log all adverse events linked to AI outputs in the patient safety system.
#   - Conduct root‑cause analysis and update controls after each incident.
#
# - **Documentation & Transparency**
#   - Maintain a Model Card for each AI system (purpose, data sources, performance, limitations, ethical considerations).
#   - Provide clinicians with Explainability Summaries (feature importance, confidence scores) at point‑of‑care.
#   - Archive all governance decisions, risk assessments, and audit findings for the required retention period.
#
# - **Training & Competency**
#   - Deliver mandatory AI governance and ethics training for all staff involved in AI development, deployment, and use.
#   - Certify clinicians on interpreting AI outputs and recognizing potential failures.
#   - Update training materials annually or when major policy changes occur.
#
# - **Audit & Oversight**
#   - Conduct internal audits of AI processes at least annually; include external third‑party reviews for Tier 1 systems.
#   - Track audit findings, corrective actions, and closure status in a centralized governance portal.
#   - Report audit outcomes to the Board and relevant regulatory bodies as required.
#
# - **Third‑Party & Vendor Management**
#   - Perform due‑diligence assessments on AI vendors (security, compliance, model provenance).
#   - Include contractual clauses for data protection, audit rights, and liability for AI‑related harms.
#   - Require vendors to adhere to the same governance framework and provide model documentation.
#
# - **Ethical & Social Considerations**
#   - Establish guidelines for equitable AI use, avoiding discrimination and ensuring accessibility.
#   - Conduct stakeholder impact assessments (patients, providers, communities) for new AI initiatives.
#   - Implement a mechanism for patient and clinician feedback on AI system performance and fairness.

# %%
#Now using ollama, the local ai

ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Here is a possible AI governance controls framework for a healthcare company:
#
# **Governance Structure:**
#
# * Establish an AI Governance Board with representatives from IT, clinical staff, and executive leadership
# * Define roles and responsibilities for AI governance, development, deployment, and monitoring
# * Create a clear organizational hierarchy for decision-making and compliance
#
# **Risk Management Framework:**
#
# * Conduct regular vulnerability assessments for AI systems and data
# * Implement controls to prevent or mitigate adversarial attacks on AI systems
# * Develop a plan for response to potential AI-related security breaches or misuses
#
# **Data Governance Framework:**
#
# * Establish a Data Management Office (DMO) responsible for managing AI-generated data
# * Define requirements for data quality, accuracy, and format standards
# * Implement access controls, encryption, and storage best practices for sensitive patient data
#
# **Regulatory Compliance Framework:**
#
# * Conduct regular updates on regulatory requirements and guidelines for AI development, deployment, and testing
# * Train employees on relevant regulations and industry standards (e.g., HIPAA, GDPR)
# * Establish a process for reporting and addressing any breaches or non-compliance incidents related to AI systems
#
# **Process Control Framework:**
#
# * Develop standardized processes for AI-assisted patient care decisions and data-intensive workflows
# * Implement role-based access controls for different levels of expertise and clearance for AI system use
# * Continuously monitor and update governance policies, procedures, and guidelines as necessary
#
# **Monitoring and Auditing Framework:**
#
# * Establish a continuous monitoring program to track system performance, data integrity, and user activity
# * Regularly review and audit AI governance structures and operational protocols
# * Develop incident response plans for adverse outcomes or breaches detected during monitoring and audits
#
# **Training and Awareness:**
#
# * Provide training on AI-related ethics, bias mitigation, and regulatory compliance
# * Establish a culture of transparency and open communication about AI system risks and benefits
# * Recognize and reward employees for promoting AI governance best practices

# %%
print(competitors)
print(answers)
# Out:
# ['gpt-5-mini', 'gemini-2.5-flash-lite', 'openai/gpt-oss-120b', 'llama3.2']
# ['- Governance & oversight\n  - Establish AI Governance Committee with defined charter, membership, authority, meeting cadence\n  - Appoint accountable roles: Executive Sponsor, AI Program Lead, Clinical Safety Officer, Data Protection Officer, Security Lead\n  - Define roles & responsibilities (RACI) for all AI lifecycle activities\n  - Formal policy suite: AI policy, acceptable-use, safety, risk, privacy, procurement, third-party, and lifecycle policies\n  - Approval gates and mandatory sign-offs for design, validation, deployment, and retirement\n  - Periodic governance reviews and board-level reporting\n\n- Risk management\n  - Mandatory pre-deployment AI risk assessment (clinical, safety, privacy, security, operational, reputational)\n  - Documented risk treatment plans with owners, mitigations, and residual risk acceptance\n  - Periodic risk re-assessments and event-driven reassessments\n  - Threat modeling and clinical hazard analysis (FMEA/HIRA) for each model/use case\n\n- Regulatory & legal compliance\n  - Maintain regulatory mapping (HIPAA, HITECH, FDA/EMA SaMD guidance, GDPR, local healthcare laws)\n  - Legal review and regulatory submission gating where required\n  - Maintain audit trails and records to satisfy regulatory inspections\n  - Maintain process for mandatory adverse event and breach reporting\n\n- Data governance & management\n  - Data provenance, lineage, and cataloging for all datasets used in development and monitoring\n  - Consent management and lawful basis documentation for patient data use\n  - De-identification/pseudonymization standards and data minimization rules\n  - Data quality controls: validation, completeness, labeling standards, error-rate thresholds\n  - Controlled data access policies and segmented environments for training vs production\n  - Retention, archival, and deletion schedules consistent with regulations\n\n- Security & privacy controls\n  - Encryption of data at rest and in transit; robust key management\n  - Identity and Access Management (RBAC, least privilege, MFA) for all systems\n  - Privileged access management and periodic access reviews\n  - Secure development lifecycle (S-SDLC), code reviews, static/dynamic analysis\n  - Vulnerability scanning, penetration testing, and third-party security assessments\n  - Logging, centralized monitoring (SIEM), tamper-evident audit logs\n  - Data leakage and exfiltration controls, DLP policies\n\n- Model development & lifecycle controls\n  - Standardized MLOps pipeline with version control for code, data, models, and configs\n  - Reproducibility requirements: seed, environment, dependency manifest, training artifacts\n  - Model documentation (model cards, data sheets) mandatory before approval\n  - Peer code review and model design review checkpoints\n  - Secure artifact signing and immutable storage for approved models\n  - Environment isolation between development, staging, and production\n\n- Validation & verification\n  - Pre-deployment validation plan: unit, integration, system, clinical validation\n  - Define acceptance criteria and performance thresholds aligned to clinical safety needs\n  - Bias, fairness, and subgroup performance testing with documented remediation\n  - Adversarial, robustness, and edge-case testing\n  - Clinical validation: retrospective, prospective, and real-world performance studies as required\n  - Independent technical and clinical review prior to release\n\n- Deployment & change control\n  - Formal change management process with change requests, impact analysis, approvals, and rollback plans\n  - Staged deployment practices (canary, blue/green, phased rollout) and monitoring gates\n  - Deployment checklist including security, privacy, performance, logging, alerting\n  - Emergency rollback and mitigation procedures with tested runbooks\n\n- Monitoring & operations\n  - Continuous monitoring for model performance, calibration, concept/data drift, and safety signals\n  - Alerting thresholds, automated  ...

# %%
for competitor, answer in zip(competitors,answers):
    print(f"Competitor: {competitor}\n\n\n{answer}")
# Out:
# Competitor: gpt-5-mini
#
#
# - Governance & oversight
#   - Establish AI Governance Committee with defined charter, membership, authority, meeting cadence
#   - Appoint accountable roles: Executive Sponsor, AI Program Lead, Clinical Safety Officer, Data Protection Officer, Security Lead
#   - Define roles & responsibilities (RACI) for all AI lifecycle activities
#   - Formal policy suite: AI policy, acceptable-use, safety, risk, privacy, procurement, third-party, and lifecycle policies
#   - Approval gates and mandatory sign-offs for design, validation, deployment, and retirement
#   - Periodic governance reviews and board-level reporting
#
# - Risk management
#   - Mandatory pre-deployment AI risk assessment (clinical, safety, privacy, security, operational, reputational)
#   - Documented risk treatment plans with owners, mitigations, and residual risk acceptance
#   - Periodic risk re-assessments and event-driven reassessments
#   - Threat modeling and clinical hazard analysis (FMEA/HIRA) for each model/use case
#
# - Regulatory & legal compliance
#   - Maintain regulatory mapping (HIPAA, HITECH, FDA/EMA SaMD guidance, GDPR, local healthcare laws)
#   - Legal review and regulatory submission gating where required
#   - Maintain audit trails and records to satisfy regulatory inspections
#   - Maintain process for mandatory adverse event and breach reporting
#
# - Data governance & management
#   - Data provenance, lineage, and cataloging for all datasets used in development and monitoring
#   - Consent management and lawful basis documentation for patient data use
#   - De-identification/pseudonymization standards and data minimization rules
#   - Data quality controls: validation, completeness, labeling standards, error-rate thresholds
#   - Controlled data access policies and segmented environments for training vs production
#   - Retention, archival, and deletion schedules consistent with regulations
#
# - Security & privacy controls
#   - Encryption of data at rest and in transit; robust key management
#   - Identity and Access Management (RBAC, least privilege, MFA) for all systems
#   - Privileged access management and periodic access reviews
#   - Secure development lifecycle (S-SDLC), code reviews, static/dynamic analysis
#   - Vulnerability scanning, penetration testing, and third-party security assessments
#   - Logging, centralized monitoring (SIEM), tamper-evident audit logs
#   - Data leakage and exfiltration controls, DLP policies
#
# - Model development & lifecycle controls
#   - Standardized MLOps pipeline with version control for code, data, models, and configs
#   - Reproducibility requirements: seed, environment, dependency manifest, training artifacts
#   - Model documentation (model cards, data sheets) mandatory before approval
#   - Peer code review and model design review checkpoints
#   - Secure artifact signing and immutable storage for approved models
#   - Environment isolation between development, staging, and production
#
# - Validation & verification
#   - Pre-deployment validation plan: unit, integration, system, clinical validation
#   - Define acceptance criteria and performance thresholds aligned to clinical safety needs
#   - Bias, fairness, and subgroup performance testing with documented remediation
#   - Adversarial, robustness, and edge-case testing
#   - Clinical validation: retrospective, prospective, and real-world performance studies as required
#   - Independent technical and clinical review prior to release
#
# - Deployment & change control
#   - Formal change management process with change requests, impact analysis, approvals, and rollback plans
#   - Staged deployment practices (canary, blue/green, phased rollout) and monitoring gates
#   - Deployment checklist including security, privacy, performance, logging, alerting
#   - Emergency rollback and mitigation procedures with tested runbooks
#
# - Monitoring & operations
#   - Continuous monitoring for model performance, calibration, concept/data drift, and safety signals
#   - Alerting thresholds, automated alerts, and defined escalation paths
#   - Operational logging of model inputs, outputs, decisions, and user interactions (with privacy controls)
#   - Regular performance reporting vs. baseline and clinical KPIs
#   - Scheduled retraining triggers and controlled model update process
#
# - Incident management & response
#   - AI incident response plan integrated into enterprise incident response
#   - Defined incident categorization, triage, root cause analysis, remediation and communication procedures
#   - Regulatory and patient notification templates and timelines
#   - Post-incident review, corrective/preventive actions, and evidence retention
#
# - Third-party & vendor management
#   - Due diligence and security/privacy questionnaires for vendors and pre-trained models
#   - Contract clauses: compliance, audit rights, data usage limits, liability, termination and transition
#   - SLA definitions for availability, performance, incident response, and data return/destruction
#   - Ongoing vendor monitoring and periodic reassessments
#
# - Ethics, transparency & patient rights
#   - Ethical review board for high-risk or novel AI uses
#   - Requirements for explainability/interpretability appropriate to clinical context
#   - Informed consent or disclosure requirements for patients and clinicians
#   - Ability for human override and clear human-in-loop responsibilities
#   - Policies for prohibited or restricted uses
#
# - Documentation & recordkeeping
#   - Maintain complete lifecycle records: requirements, specs, datasets, training logs, validation reports, deployment records, monitoring logs, incident records
#   - Model card, data sheet, clinical safety case, and validation dossier mandatory for each model
#   - Immutable audit trail and retention schedules aligned to regulatory requirements
#
# - Training & competency
#   - Role-based mandatory training: clinical safety, AI literacy, data privacy, secure coding, incident handling
#   - Certification/approval for clinical users before live use
#   - Training records, refresh schedules, and competency assessments
#
# - Audit, assurance & continuous improvement
#   - Internal and independent external audits of AI processes and controls
#   - Periodic assurance reviews and remediation tracking
#   - Continuous improvement program with lessons-learned and control updates
#   - Maturity model and roadmap for AI governance adoption
#
# - Access, identity & privilege controls
#   - Enforce least privilege, MFA, session timeouts, and SSO
#   - Periodic privileged access reviews and just-in-time access for high-risk operations
#   - Session recording and activity logging for critical actions
#
# - Business continuity & resilience
#   - Business continuity and disaster recovery plans for AI systems with defined RTO/RPO
#   - High-availability and failover strategies; safe-mode operational procedures
#   - Regular DR testing and recovery validation
#
# - Metrics, KPIs & reporting
#   - Define clinical and operational KPIs: sensitivity/specificity, calibration, false negatives (safety-critical), uptime, incident metrics
#   - Executive dashboards and periodic reporting to governance committee
#   - Thresholds for intervention and automated remediation triggers
#
# - Clinical safety & patient harm mitigation
#   - Clinical safety case for each AI system documenting hazards, mitigations, and residual risk
#   - Active surveillance for patient harm and near-miss events
#   - Safety monitoring board for high-risk applications and periodic safety reviews
#
# - Procurement & contracting controls
#   - Standard procurement checklist including regulatory evidence, validation artifacts, security posture
#   - Source code/model escrow and transition plans where appropriate
#   - Termination clauses to ensure data return/destruction and continuity
#
# - Change/version control & retirement
#   - Formal versioning schema and immutable change logs for models and data
#   - Retirement criteria, decommissioning checklist, and archival procedures
#   - Backwards-compatibility and migration plans for model updates
#
# - Legal, insurance & liability
#   - Legal review for liability allocation and compliance risk
#   - Appropriate cyber and professional liability insurance coverage
#   - Process for indemnity and contractual risk allocation
#
# - Implementation & maturity roadmap
#   - Phased implementation plan with prioritized controls for high-risk systems first
#   - Target maturity levels, timelines, and resourcing plan
#   - Continuous measurement against maturity targets and periodic reassessment
# Competitor: gemini-2.5-flash-lite
#
#
# *   **AI Ethics Committee:**
# *   **AI Risk Assessment Framework:**
# *   **Data Privacy and Security Protocols:**
# *   **AI Model Validation and Verification Procedures:**
# *   **Transparency and Explainability Requirements:**
# *   **Bias Detection and Mitigation Strategies:**
# *   **Human Oversight and Intervention Guidelines:**
# *   **Accountability and Responsibility Matrix:**
# *   **Regulatory Compliance Monitoring:**
# *   **AI Incident Response Plan:**
# *   **Continuous AI Performance Monitoring:**
# *   **Data Governance Policies for AI:**
# *   **AI Training and Awareness Programs:**
# *   **Algorithmic Auditing Procedures:**
# *   **Third-Party AI Vendor Due Diligence:**
# *   **Patient Consent Management for AI Use:**
# *   **AI Model Lifecycle Management:**
# *   **Documentation Standards for AI Development:**
# *   **Ethical AI Design Principles:**
# *   **Adversarial Robustness Testing:**
# Competitor: openai/gpt-oss-120b
#
#
# - **Governance Structure**
#   - Establish an AI Governance Board with senior executives, clinical leaders, compliance officers, and data privacy experts.
#   - Define clear roles and responsibilities for AI owners, developers, data stewards, and auditors.
#   - Create an AI Ethics Committee to review high‑risk use cases and ensure alignment with patient‑centered values.
#
# - **Risk Management**
#   - Conduct AI Risk Assessments for every model before deployment (clinical impact, safety, privacy, bias, regulatory).
#   - Classify AI systems by risk tier (e.g., Tier 1 = critical patient care; Tier 2 = operational support; Tier 3 = administrative).
#   - Require formal risk mitigation plans for Tier 1 and Tier 2 systems.
#
# - **Regulatory & Compliance**
#   - Map AI processes to relevant regulations (HIPAA, GDPR, FDA Software as a Medical Device, HITECH, state privacy laws).
#   - Implement a compliance checklist for model development, validation, and release.
#   - Maintain a regulatory filing log and ensure timely submissions for FDA‑cleared algorithms.
#
# - **Data Governance**
#   - Enforce data provenance tracking for all training, validation, and inference datasets.
#   - Apply strict de‑identification and anonymization standards; obtain documented patient consent where required.
#   - Implement role‑based access controls (RBAC) and audit trails for data handling.
#
# - **Model Development Lifecycle**
#   - Standardize a phased workflow: problem definition → data collection → preprocessing → model design → training → validation → clinical evaluation → deployment → post‑market surveillance.
#   - Require documented version control for code, data, and model artifacts.
#   - Use reproducible pipelines (e.g., containerization, CI/CD) with automated testing suites.
#
# - **Validation & Testing**
#   - Perform internal validation on representative patient cohorts; document performance metrics (sensitivity, specificity, AUC, calibration).
#   - Conduct external validation with independent datasets before clinical use.
#   - Require bias analysis across demographics (age, gender, race, socioeconomic status) and implement corrective measures.
#
# - **Deployment Controls**
#   - Enforce change‑control procedures for model updates; require impact analysis and sign‑off from the AI Governance Board.
#   - Deploy models in a staged manner (sandbox → pilot → full rollout) with real‑time monitoring thresholds.
#   - Integrate fail‑safe mechanisms (e.g., human‑in‑the‑loop overrides) for high‑risk decisions.
#
# - **Monitoring & Performance Management**
#   - Implement continuous monitoring dashboards for model drift, data drift, and outcome variance.
#   - Set automated alerts for deviations beyond predefined thresholds.
#   - Schedule periodic re‑validation (e.g., quarterly) and retraining cycles as needed.
#
# - **Incident Management**
#   - Define an AI Incident Response Plan (detection, containment, investigation, remediation, reporting).
#   - Log all adverse events linked to AI outputs in the patient safety system.
#   - Conduct root‑cause analysis and update controls after each incident.
#
# - **Documentation & Transparency**
#   - Maintain a Model Card for each AI system (purpose, data sources, performance, limitations, ethical considerations).
#   - Provide clinicians with Explainability Summaries (feature importance, confidence scores) at point‑of‑care.
#   - Archive all governance decisions, risk assessments, and audit findings for the required retention period.
#
# - **Training & Competency**
#   - Deliver mandatory AI governance and ethics training for all staff involved in AI development, deployment, and use.
#   - Certify clinicians on interpreting AI outputs and recognizing potential failures.
#   - Update training materials annually or when major policy changes occur.
#
# - **Audit & Oversight**
#   - Conduct internal audits of AI processes at least annually; include external third‑party reviews for Tier 1 systems.
#   - Track audit findings, corrective actions, and closure status in a centralized governance portal.
#   - Report audit outcomes to the Board and relevant regulatory bodies as required.
#
# - **Third‑Party & Vendor Management**
#   - Perform due‑diligence assessments on AI vendors (security, compliance, model provenance).
#   - Include contractual clauses for data protection, audit rights, and liability for AI‑related harms.
#   - Require vendors to adhere to the same governance framework and provide model documentation.
#
# - **Ethical & Social Considerations**
#   - Establish guidelines for equitable AI use, avoiding discrimination and ensuring accessibility.
#   - Conduct stakeholder impact assessments (patients, providers, communities) for new AI initiatives.
#   - Implement a mechanism for patient and clinician feedback on AI system performance and fairness.
# Competitor: llama3.2
#
#
# Here is a possible AI governance controls framework for a healthcare company:
#
# **Governance Structure:**
#
# * Establish an AI Governance Board with representatives from IT, clinical staff, and executive leadership
# * Define roles and responsibilities for AI governance, development, deployment, and monitoring
# * Create a clear organizational hierarchy for decision-making and compliance
#
# **Risk Management Framework:**
#
# * Conduct regular vulnerability assessments for AI systems and data
# * Implement controls to prevent or mitigate adversarial attacks on AI systems
# * Develop a plan for response to potential AI-related security breaches or misuses
#
# **Data Governance Framework:**
#
# * Establish a Data Management Office (DMO) responsible for managing AI-generated data
# * Define requirements for data quality, accuracy, and format standards
# * Implement access controls, encryption, and storage best practices for sensitive patient data
#
# **Regulatory Compliance Framework:**
#
# * Conduct regular updates on regulatory requirements and guidelines for AI development, deployment, and testing
# * Train employees on relevant regulations and industry standards (e.g., HIPAA, GDPR)
# * Establish a process for reporting and addressing any breaches or non-compliance incidents related to AI systems
#
# **Process Control Framework:**
#
# * Develop standardized processes for AI-assisted patient care decisions and data-intensive workflows
# * Implement role-based access controls for different levels of expertise and clearance for AI system use
# * Continuously monitor and update governance policies, procedures, and guidelines as necessary
#
# **Monitoring and Auditing Framework:**
#
# * Establish a continuous monitoring program to track system performance, data integrity, and user activity
# * Regularly review and audit AI governance structures and operational protocols
# * Develop incident response plans for adverse outcomes or breaches detected during monitoring and audits
#
# **Training and Awareness:**
#
# * Provide training on AI-related ethics, bias mitigation, and regulatory compliance
# * Establish a culture of transparency and open communication about AI system risks and benefits
# * Recognize and reward employees for promoting AI governance best practices

# %%
cumulativeAnswer = ""
for index, answer in enumerate(answers):
    cumulativeAnswer += f"# Response from competitor {index+1}\n\n"
    cumulativeAnswer += answer + "\n\n"

# %%
print(cumulativeAnswer)
# Out:
# # Response from competitor 1
#
# - Governance & oversight
#   - Establish AI Governance Committee with defined charter, membership, authority, meeting cadence
#   - Appoint accountable roles: Executive Sponsor, AI Program Lead, Clinical Safety Officer, Data Protection Officer, Security Lead
#   - Define roles & responsibilities (RACI) for all AI lifecycle activities
#   - Formal policy suite: AI policy, acceptable-use, safety, risk, privacy, procurement, third-party, and lifecycle policies
#   - Approval gates and mandatory sign-offs for design, validation, deployment, and retirement
#   - Periodic governance reviews and board-level reporting
#
# - Risk management
#   - Mandatory pre-deployment AI risk assessment (clinical, safety, privacy, security, operational, reputational)
#   - Documented risk treatment plans with owners, mitigations, and residual risk acceptance
#   - Periodic risk re-assessments and event-driven reassessments
#   - Threat modeling and clinical hazard analysis (FMEA/HIRA) for each model/use case
#
# - Regulatory & legal compliance
#   - Maintain regulatory mapping (HIPAA, HITECH, FDA/EMA SaMD guidance, GDPR, local healthcare laws)
#   - Legal review and regulatory submission gating where required
#   - Maintain audit trails and records to satisfy regulatory inspections
#   - Maintain process for mandatory adverse event and breach reporting
#
# - Data governance & management
#   - Data provenance, lineage, and cataloging for all datasets used in development and monitoring
#   - Consent management and lawful basis documentation for patient data use
#   - De-identification/pseudonymization standards and data minimization rules
#   - Data quality controls: validation, completeness, labeling standards, error-rate thresholds
#   - Controlled data access policies and segmented environments for training vs production
#   - Retention, archival, and deletion schedules consistent with regulations
#
# - Security & privacy controls
#   - Encryption of data at rest and in transit; robust key management
#   - Identity and Access Management (RBAC, least privilege, MFA) for all systems
#   - Privileged access management and periodic access reviews
#   - Secure development lifecycle (S-SDLC), code reviews, static/dynamic analysis
#   - Vulnerability scanning, penetration testing, and third-party security assessments
#   - Logging, centralized monitoring (SIEM), tamper-evident audit logs
#   - Data leakage and exfiltration controls, DLP policies
#
# - Model development & lifecycle controls
#   - Standardized MLOps pipeline with version control for code, data, models, and configs
#   - Reproducibility requirements: seed, environment, dependency manifest, training artifacts
#   - Model documentation (model cards, data sheets) mandatory before approval
#   - Peer code review and model design review checkpoints
#   - Secure artifact signing and immutable storage for approved models
#   - Environment isolation between development, staging, and production
#
# - Validation & verification
#   - Pre-deployment validation plan: unit, integration, system, clinical validation
#   - Define acceptance criteria and performance thresholds aligned to clinical safety needs
#   - Bias, fairness, and subgroup performance testing with documented remediation
#   - Adversarial, robustness, and edge-case testing
#   - Clinical validation: retrospective, prospective, and real-world performance studies as required
#   - Independent technical and clinical review prior to release
#
# - Deployment & change control
#   - Formal change management process with change requests, impact analysis, approvals, and rollback plans
#   - Staged deployment practices (canary, blue/green, phased rollout) and monitoring gates
#   - Deployment checklist including security, privacy, performance, logging, alerting
#   - Emergency rollback and mitigation procedures with tested runbooks
#
# - Monitoring & operations
#   - Continuous monitoring for model performance, calibration, concept/data drift, and safety signals
#   - Alerting thresholds, automated alerts, and defined escalation paths
#   - Operational logging of model inputs, outputs, decisions, and user interactions (with privacy controls)
#   - Regular performance reporting vs. baseline and clinical KPIs
#   - Scheduled retraining triggers and controlled model update process
#
# - Incident management & response
#   - AI incident response plan integrated into enterprise incident response
#   - Defined incident categorization, triage, root cause analysis, remediation and communication procedures
#   - Regulatory and patient notification templates and timelines
#   - Post-incident review, corrective/preventive actions, and evidence retention
#
# - Third-party & vendor management
#   - Due diligence and security/privacy questionnaires for vendors and pre-trained models
#   - Contract clauses: compliance, audit rights, data usage limits, liability, termination and transition
#   - SLA definitions for availability, performance, incident response, and data return/destruction
#   - Ongoing vendor monitoring and periodic reassessments
#
# - Ethics, transparency & patient rights
#   - Ethical review board for high-risk or novel AI uses
#   - Requirements for explainability/interpretability appropriate to clinical context
#   - Informed consent or disclosure requirements for patients and clinicians
#   - Ability for human override and clear human-in-loop responsibilities
#   - Policies for prohibited or restricted uses
#
# - Documentation & recordkeeping
#   - Maintain complete lifecycle records: requirements, specs, datasets, training logs, validation reports, deployment records, monitoring logs, incident records
#   - Model card, data sheet, clinical safety case, and validation dossier mandatory for each model
#   - Immutable audit trail and retention schedules aligned to regulatory requirements
#
# - Training & competency
#   - Role-based mandatory training: clinical safety, AI literacy, data privacy, secure coding, incident handling
#   - Certification/approval for clinical users before live use
#   - Training records, refresh schedules, and competency assessments
#
# - Audit, assurance & continuous improvement
#   - Internal and independent external audits of AI processes and controls
#   - Periodic assurance reviews and remediation tracking
#   - Continuous improvement program with lessons-learned and control updates
#   - Maturity model and roadmap for AI governance adoption
#
# - Access, identity & privilege controls
#   - Enforce least privilege, MFA, session timeouts, and SSO
#   - Periodic privileged access reviews and just-in-time access for high-risk operations
#   - Session recording and activity logging for critical actions
#
# - Business continuity & resilience
#   - Business continuity and disaster recovery plans for AI systems with defined RTO/RPO
#   - High-availability and failover strategies; safe-mode operational procedures
#   - Regular DR testing and recovery validation
#
# - Metrics, KPIs & reporting
#   - Define clinical and operational KPIs: sensitivity/specificity, calibration, false negatives (safety-critical), uptime, incident metrics
#   - Executive dashboards and periodic reporting to governance committee
#   - Thresholds for intervention and automated remediation triggers
#
# - Clinical safety & patient harm mitigation
#   - Clinical safety case for each AI system documenting hazards, mitigations, and residual risk
#   - Active surveillance for patient harm and near-miss events
#   - Safety monitoring board for high-risk applications and periodic safety reviews
#
# - Procurement & contracting controls
#   - Standard procurement checklist including regulatory evidence, validation artifacts, security posture
#   - Source code/model escrow and transition plans where appropriate
#   - Termination clauses to ensure data return/destruction and continuity
#
# - Change/version control & retirement
#   - Formal versioning schema and immutable change logs for models and data
#   - Retirement criteria, decommissioning checklist, and archival procedures
#   - Backwards-compatibility and migration plans for model updates
#
# - Legal, insurance & liability
#   - Legal review for liability allocation and compliance risk
#   - Appropriate cyber and professional liability insurance coverage
#   - Process for indemnity and contractual risk allocation
#
# - Implementation & maturity roadmap
#   - Phased implementation plan with prioritized controls for high-risk systems first
#   - Target maturity levels, timelines, and resourcing plan
#   - Continuous measurement against maturity targets and periodic reassessment
#
# # Response from competitor 2
#
# *   **AI Ethics Committee:**
# *   **AI Risk Assessment Framework:**
# *   **Data Privacy and Security Protocols:**
# *   **AI Model Validation and Verification Procedures:**
# *   **Transparency and Explainability Requirements:**
# *   **Bias Detection and Mitigation Strategies:**
# *   **Human Oversight and Intervention Guidelines:**
# *   **Accountability and Responsibility Matrix:**
# *   **Regulatory Compliance Monitoring:**
# *   **AI Incident Response Plan:**
# *   **Continuous AI Performance Monitoring:**
# *   **Data Governance Policies for AI:**
# *   **AI Training and Awareness Programs:**
# *   **Algorithmic Auditing Procedures:**
# *   **Third-Party AI Vendor Due Diligence:**
# *   **Patient Consent Management for AI Use:**
# *   **AI Model Lifecycle Management:**
# *   **Documentation Standards for AI Development:**
# *   **Ethical AI Design Principles:**
# *   **Adversarial Robustness Testing:**
#
# # Response from competitor 3
#
# - **Governance Structure**
#   - Establish an AI Governance Board with senior executives, clinical leaders, compliance officers, and data privacy experts.
#   - Define clear roles and responsibilities for AI owners, developers, data stewards, and auditors.
#   - Create an AI Ethics Committee to review high‑risk use cases and ensure alignment with patient‑centered values.
#
# - **Risk Management**
#   - Conduct AI Risk Assessments for every model before deployment (clinical impact, safety, privacy, bias, regulatory).
#   - Classify AI systems by risk tier (e.g., Tier 1 = critical patient care; Tier 2 = operational support; Tier 3 = administrative).
#   - Require formal risk mitigation plans for Tier 1 and Tier 2 systems.
#
# - **Regulatory & Compliance**
#   - Map AI processes to relevant regulations (HIPAA, GDPR, FDA Software as a Medical Device, HITECH, state privacy laws).
#   - Implement a compliance checklist for model development, validation, and release.
#   - Maintain a regulatory filing log and ensure timely submissions for FDA‑cleared algorithms.
#
# - **Data Governance**
#   - Enforce data provenance tracking for all training, validation, and inference datasets.
#   - Apply strict de‑identification and anonymization standards; obtain documented patient consent where required.
#   - Implement role‑based access controls (RBAC) and audit trails for data handling.
#
# - **Model Development Lifecycle**
#   - Standardize a phased workflow: problem definition → data collection → preprocessing → model design → training → validation → clinical evaluation → deployment → post‑market surveillance.
#   - Require documented version control for code, data, and model artifacts.
#   - Use reproducible pipelines (e.g., containerization, CI/CD) with automated testing suites.
#
# - **Validation & Testing**
#   - Perform internal validation on representative patient cohorts; document performance metrics (sensitivity, specificity, AUC, calibration).
#   - Conduct external validation with independent datasets before clinical use.
#   - Require bias analysis across demographics (age, gender, race, socioeconomic status) and implement corrective measures.
#
# - **Deployment Controls**
#   - Enforce change‑control procedures for model updates; require impact analysis and sign‑off from the AI Governance Board.
#   - Deploy models in a staged manner (sandbox → pilot → full rollout) with real‑time monitoring thresholds.
#   - Integrate fail‑safe mechanisms (e.g., human‑in‑the‑loop overrides) for high‑risk decisions.
#
# - **Monitoring & Performance Management**
#   - Implement continuous monitoring dashboards for model drift, data drift, and outcome variance.
#   - Set automated alerts for deviations beyond predefined thresholds.
#   - Schedule periodic re‑validation (e.g., quarterly) and retraining cycles as needed.
#
# - **Incident Management**
#   - Define an AI Incident Response Plan (detection, containment, investigation, remediation, reporting).
#   - Log all adverse events linked to AI outputs in the patient safety system.
#   - Conduct root‑cause analysis and update controls after each incident.
#
# - **Documentation & Transparency**
#   - Maintain a Model Card for each AI system (purpose, data sources, performance, limitations, ethical considerations).
#   - Provide clinicians with Explainability Summaries (feature importance, confidence scores) at point‑of‑care.
#   - Archive all governance decisions, risk assessments, and audit findings for the required retention period.
#
# - **Training & Competency**
#   - Deliver mandatory AI governance and ethics training for all staff involved in AI development, deployment, and use.
#   - Certify clinicians on interpreting AI outputs and recognizing potential failures.
#   - Update training materials annually or when major policy changes occur.
#
# - **Audit & Oversight**
#   - Conduct internal audits of AI processes at least annually; include external third‑party reviews for Tier 1 systems.
#   - Track audit findings, corrective actions, and closure status in a centralized governance portal.
#   - Report audit outcomes to the Board and relevant regulatory bodies as required.
#
# - **Third‑Party & Vendor Management**
#   - Perform due‑diligence assessments on AI vendors (security, compliance, model provenance).
#   - Include contractual clauses for data protection, audit rights, and liability for AI‑related harms.
#   - Require vendors to adhere to the same governance framework and provide model documentation.
#
# - **Ethical & Social Considerations**
#   - Establish guidelines for equitable AI use, avoiding discrimination and ensuring accessibility.
#   - Conduct stakeholder impact assessments (patients, providers, communities) for new AI initiatives.
#   - Implement a mechanism for patient and clinician feedback on AI system performance and fairness.
#
# # Response from competitor 4
#
# Here is a possible AI governance controls framework for a healthcare company:
#
# **Governance Structure:**
#
# * Establish an AI Governance Board with representatives from IT, clinical staff, and executive leadership
# * Define roles and responsibilities for AI governance, development, deployment, and monitoring
# * Create a clear organizational hierarchy for decision-making and compliance
#
# **Risk Management Framework:**
#
# * Conduct regular vulnerability assessments for AI systems and data
# * Implement controls to prevent or mitigate adversarial attacks on AI systems
# * Develop a plan for response to potential AI-related security breaches or misuses
#
# **Data Governance Framework:**
#
# * Establish a Data Management Office (DMO) responsible for managing AI-generated data
# * Define requirements for data quality, accuracy, and format standards
# * Implement access controls, encryption, and storage best practices for sensitive patient data
#
# **Regulatory Compliance Framework:**
#
# * Conduct regular updates on regulatory requirements and guidelines for AI development, deployment, and testing
# * Train employees on relevant regulations and industry standards (e.g., HIPAA, GDPR)
# * Establish a process for reporting and addressing any breaches or non-compliance incidents related to AI systems
#
# **Process Control Framework:**
#
# * Develop standardized processes for AI-assisted patient care decisions and data-intensive workflows
# * Implement role-based access controls for different levels of expertise and clearance for AI system use
# * Continuously monitor and update governance policies, procedures, and guidelines as necessary
#
# **Monitoring and Auditing Framework:**
#
# * Establish a continuous monitoring program to track system performance, data integrity, and user activity
# * Regularly review and audit AI governance structures and operational protocols
# * Develop incident response plans for adverse outcomes or breaches detected during monitoring and audits
#
# **Training and Awareness:**
#
# * Provide training on AI-related ethics, bias mitigation, and regulatory compliance
# * Establish a culture of transparency and open communication about AI system risks and benefits
# * Recognize and reward employees for promoting AI governance best practices

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{cumulativeAnswer}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""
