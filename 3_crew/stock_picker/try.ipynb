# %%
import crewai
print(dir(crewai))
# Out:
# ['Agent', 'Any', 'BaseLLM', 'Crew', 'CrewOutput', 'Flow', 'Knowledge', 'LLM', 'LLMGuardrail', 'PlanningConfig', 'Process', 'Task', 'TaskOutput', 'Telemetry', '_LAZY_IMPORTS', '__all__', '__annotations__', '__builtins__', '__cached__', '__doc__', '__file__', '__getattr__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_suppress_pydantic_deprecation_warnings', '_telemetry_submitted', '_track_install', '_track_install_async', 'a2a', 'agent', 'agents', 'cli', 'context', 'contextvars', 'core', 'crew', 'crews', 'events', 'experimental', 'flow', 'hooks', 'knowledge', 'lite_agent_output', 'llm', 'llms', 'mcp', 'memory', 'process', 'rag', 'security', 'task', 'tasks', 'telemetry', 'threading', 'tools', 'types', 'urllib', 'utilities', 'warnings']

# %%
import crewai.memory.storage.
print(dir(crewai.memory))
# Out:
# ['Any', 'MemoryMatch', 'MemoryRecord', 'MemoryScope', 'MemorySlice', 'ScopeInfo', '_LAZY_IMPORTS', '__all__', '__annotations__', '__builtins__', '__cached__', '__doc__', '__file__', '__getattr__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'analyze', 'annotations', 'compute_composite_score', 'embed_text', 'embed_texts', 'memory_scope', 'recall_flow', 'storage', 'types', 'unified_memory']
