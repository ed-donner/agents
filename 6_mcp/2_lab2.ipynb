# %% [markdown]
# ### Week 6, Day 2
#
# We're about to create and use our own MCP Server and MCP Client!
#
# It's pretty simple, but it's not super-simple. The excitment around MCP is about how easy it is to share and use other MCP Servers - making our own does involve a bit of work.
#
# Let's review some python code made mostly by a hard-working Engineering Team:
#
# accounts.py

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from agents.mcp import MCPServerStdio
from IPython.display import display, Markdown

load_dotenv(override=True)
# Out:
# True

# %%
from accounts import Account

# %%
account = Account.get("Ed")
account
# Out:
# Account(name='ed', balance=6879.772000000004, strategy='', holdings={'AMZN': 57}, transactions=[3 shares of AMZN at 74.148 each., 3 shares of AMZN at 59.118 each., 3 shares of AMZN at 97.194 each., 3 shares of AMZN at 47.094 each., 3 shares of AMZN at 34.068 each., 3 shares of AMZN at 17.034 each., 3 shares of AMZN at 53.106 each., 3 shares of AMZN at 32.064 each., 3 shares of AMZN at 62.124 each., 3 shares of AMZN at 53.106 each., 3 shares of AMZN at 56.112 each., 3 shares of AMZN at 39.078 each., 3 shares of AMZN at 86.172 each., 3 shares of AMZN at 57.114 each., 3 shares of AMZN at 57.114 each., 3 shares of AMZN at 92.184 each., 3 shares of AMZN at 99.198 each., 3 shares of AMZN at 4.008 each., 3 shares of AMZN at 20.04 each.], portfolio_value_time_series=[('2026-06-03 11:15:46', 9786.556), ('2026-06-03 11:15:46', 9798.556), ('2026-06-03 11:58:28', 10122.202000000001), ('2026-06-03 11:58:28', 9630.202000000001), ('2026-06-03 11:58:53', 9930.202000000001), ('2026-06-03 11:58:53', 9
# ...

# %%
account.buy_shares("AMZN", 3, "Because this bookstore website looks promising")
# Out:
# 'Completed. Latest details:\n{"name": "ed", "balance": 6828.670000000004, "strategy": "", "holdings": {"AMZN": 60}, "transactions": [{"symbol": "AMZN", "quantity": 3, "price": 74.148, "timestamp": "2026-06-03 11:15:46", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 59.118, "timestamp": "2026-06-03 11:58:28", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 97.194, "timestamp": "2026-06-03 12:19:19", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 47.094, "timestamp": "2026-06-03 13:57:34", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 34.068, "timestamp": "2026-06-05 09:14:00", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 17.034, "timestamp": "2026-06-05 09:16:39", "rationale": "Because t
# ...

# %%
account.report()
# Out:
# '{"name": "ed", "balance": 6828.670000000004, "strategy": "", "holdings": {"AMZN": 60}, "transactions": [{"symbol": "AMZN", "quantity": 3, "price": 74.148, "timestamp": "2026-06-03 11:15:46", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 59.118, "timestamp": "2026-06-03 11:58:28", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 97.194, "timestamp": "2026-06-03 12:19:19", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 47.094, "timestamp": "2026-06-03 13:57:34", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 34.068, "timestamp": "2026-06-05 09:14:00", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 17.034, "timestamp": "2026-06-05 09:16:39", "rationale": "Because this bookstore website looks 
# ...

# %%
account.list_transactions()
# Out:
# [{'symbol': 'AMZN',
#   'quantity': 3,
#   'price': 74.148,
#   'timestamp': '2026-06-03 11:15:46',
#   'rationale': 'Because this bookstore website looks promising'},
#  {'symbol': 'AMZN',
#   'quantity': 3,
#   'price': 59.118,
#   'timestamp': '2026-06-03 11:58:28',
#   'rationale': 'Because this bookstore website looks promising'},
#  {'symbol': 'AMZN',
#   'quantity': 3,
#   'price': 97.194,
#   'timestamp': '2026-06-03 12:19:19',
#   'rationale': 'Because this bookstore website looks promising'},
#  {'symbol': 'AMZN',
#   'quantity': 3,
#   'price': 47.094,
#   'timestamp': '2026-06-03 13:57:34',
#   'rationale': 'Because this bookstore website looks promising'},
#  {'symbol': 'AMZN',
#   'quantity': 3,
#   'price': 34.068,
#   'timestamp': '2026-06-05 09:14:00',
#   'rationale': 'Because this bookstore website looks promising'},
#  {'symbol': 'AMZN',
#   'quantity': 3,
#   'price': 17.034,
#   'timestamp': '2026-06-05 09:16:39',
# ...

# %% [markdown]
# ### Now we write an MCP server and use it directly!

# %%
import sys
sys.stdout = sys.__stdout__
sys.stderr = sys.__stderr__

# %% [markdown]
# ### Windows/Jupyter note (MCP server startup)
#
# If MCP server startup fails with a `fileno`-related error in Jupyter, run the stdout/stderr reset cell above before creating MCP servers.
#
# After adding or updating this cell, reselect the notebook kernel and run from the top so the stream handles are reinitialized correctly.

# %%
# Now let's use our accounts server as an MCP server

params = {"command": "uv", "args": ["run", "accounts_server.py"]}
async with MCPServerStdio(params=params, client_session_timeout_seconds=120) as server:
    mcp_tools = await server.list_tools()
mcp_tools
# Out:
# [Tool(name='get_balance', title=None, description='Get the cash balance of the given account name.\n\n    Args:\n        name: The name of the account holder\n    ', inputSchema={'properties': {'name': {'title': 'Name', 'type': 'string'}}, 'required': ['name'], 'title': 'get_balanceArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'title': 'Result', 'type': 'number'}}, 'required': ['result'], 'title': 'get_balanceOutput', 'type': 'object'}, icons=None, annotations=None, meta=None, execution=None),
# ...

# %%
instructions = "You are able to manage an account for a client, and answer questions about the account."
request = "My name is Ed and my account is under the name Ed. What's my balance and my holdings?"
model = "gpt-4.1-mini"

# %%
async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as mcp_server:
    agent = Agent(name="account_manager", instructions=instructions, model=model, mcp_servers=[mcp_server])
    with trace("account_manager"):
        result = await Runner.run(agent, request)
    display(Markdown(result.final_output))
# Out:
# Ed, your account balance is $6,828.67. You currently hold 60 shares of Amazon (AMZN) in your portfolio. If you have any other questions or want to make any changes, just let me know!

# %% [markdown]
# ### Now let's build our own MCP Client

# %%
from accounts_client import get_accounts_tools_openai, read_accounts_resource, list_accounts_tools

mcp_tools = await list_accounts_tools()
print(mcp_tools)
openai_tools = await get_accounts_tools_openai()
print(openai_tools)

# %%
request = "My name is Ed and my account is under the name Ed. What's my balance?"

with trace("account_mcp_client"):
    agent = Agent(name="account_manager", instructions=instructions, model=model, tools=openai_tools)
    result = await Runner.run(agent, request)
    display(Markdown(result.final_output))
# Out:
# Ed, your current account balance is $6828.67. If you need any further information or assistance with your account, please let me know!

# %%
context = await read_accounts_resource("ed")
print(context)

# %%
from accounts import Account
Account.get("ed").report()
# Out:
# '{"name": "ed", "balance": 6828.670000000004, "strategy": "", "holdings": {"AMZN": 60}, "transactions": [{"symbol": "AMZN", "quantity": 3, "price": 74.148, "timestamp": "2026-06-03 11:15:46", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 59.118, "timestamp": "2026-06-03 11:58:28", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 97.194, "timestamp": "2026-06-03 12:19:19", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 47.094, "timestamp": "2026-06-03 13:57:34", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 34.068, "timestamp": "2026-06-05 09:14:00", "rationale": "Because this bookstore website looks promising"}, {"symbol": "AMZN", "quantity": 3, "price": 17.034, "timestamp": "2026-06-05 09:16:39", "rationale": "Because this bookstore website looks 
# ...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercises</h2>
#             <span style="color:#ff7800;">Make your own MCP Server! Make a simple function to return the current Date, and expose it as a tool so that an Agent can tell you today's date.<br/>Harder optional exercise: then make an MCP Client, and use a native OpenAI call (without the Agents SDK) to use your tool via your client.
#             </span>
#         </td>
#     </tr>
# </table>
