# %% [markdown]
# # Emoji MCP server
# Sunmitted by : Bharat Puri

# %%
import os, shutil
print('CWD:', os.getcwd())
print('uv path:', shutil.which('uv'))
# Out:
# CWD: /Users/bhpuri/Documents/devops/projects/bharat_ai/repos/agents/6_mcp/community_contributions/bharat_puri/emoji_mcp
# uv path: /Users/bhpuri/.local/bin/uv

# %%
# Show server and client code
from pathlib import Path
print('--- emoji_server.py ---')
print(Path('emoji_server.py').read_text())
print('\n--- emoji_client.py ---')
print(Path('emoji_client.py').read_text())
# Out:
# --- emoji_server.py ---
# from mcp.server.fastmcp import FastMCP
# from datetime import datetime
#
# mcp = FastMCP("emoji_server")
#
# # Static emoji dictionary
# EMOJIS = {
#     "smile": "😄",
#     "laugh": "😂",
#     "wink": "😉",
#     "heart": "❤️",
#     "thumbs_up": "👍",
#     "fire": "🔥",
#     "star": "⭐",
#     "ok": "👌",
#
#     # Categories
#     "animals": {
#         "dog": "🐶",
#         "cat": "🐱",
#         "lion": "🦁",
#         "panda": "🐼"
#     },
#
#     "food": {
#         "pizza": "🍕",
#         "burger": "🍔",
#         "fries": "🍟",
#         "apple": "🍎"
#     }
# }
#
#
# # -------------------------------------------------------------------------
# # Tool 1: Get a single emoji
# # -------------------------------------------------------------------------
# @mcp.tool()
# async def get_emoji(name: str) -> str:
#     """Return an emoji by simple name."""
#     if name in EMOJIS:
#         return EMOJIS[name]
#     # Search subcategories
# ...

# %%
from emoji_client import list_emoji_tools
tools = await list_emoji_tools()
[t.name for t in tools]
# Out:
# ['get_emoji', 'emoji_categories', 'list_emojis']

# %%
from emoji_client import call_emoji_tool

res = await call_emoji_tool("get_emoji", {"name": "smile"})
[x.text for x in res.content]
# Out:
# ['😄']

# %%
[x.text for x in (await call_emoji_tool("get_emoji", {"name": "fire"})).content]
# Out:
# ['🔥']

# %%
res = await call_emoji_tool("emoji_categories")
[x.text for x in res.content]
# Out:
# ['animals', 'food']
