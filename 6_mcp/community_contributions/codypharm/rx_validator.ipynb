# %%
from agents.mcp import MCPServerStdio
from IPython.display import Markdown, display
from agents import Agent, Runner, trace

# %%
params = {"command": "uv", "args": ["run", "rx_logic.py"]}

try:
    async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
        mcp_tools = await server.list_tools()

    if not mcp_tools:
        raise RuntimeError("MCP server started but returned no tools — check rx_logic.py for registration errors.")

    print(f"✓ {len(mcp_tools)} tools loaded: {[t.name for t in mcp_tools]}")
except FileNotFoundError:
    print("✗ Could not start MCP server — is 'uv' installed and rx_logic.py in the current directory?")
    raise
except Exception as e:
    print(f"✗ MCP server error: {type(e).__name__}: {e}")
    raise
# Out:
# [Tool(name='normalize_drug_name', title=None, description='\n    Normalize drug name using RxNorm API.\n    Returns RxCUI, preferred name, ingredients, brand names, ATC classes, etc.\n    ', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}}, 'required': ['drug_name'], 'title': 'normalize_drug_nameArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'normalize_drug_nameOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_drug_allergy', title=None, description='\n    Check for direct allergy or cross-reactivity.\n    Enhanced with RxNorm ingredients when available.\n    ', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}, 'patient_allergies': {'items': {'type': 'string'}, 'title': 'Patient Allergies', 'type': 'array'}, 'normalized': {'anyOf': [{'additionalProperties': True, 'type': 'object'}, {'type': 'null'}], 'default': None, 'title': 'Normalized'}}, 'required': ['drug_name', 'patient_allergies'], 'title': 'check_drug_allergyArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_drug_allergyOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_drug_recall', title=None, description='Check FDA recalls (your original function - kept mostly unchanged)', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}, 'lot_number': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Lot Number'}}, 'required': ['drug_name'], 'title': 'check_drug_recallArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_drug_recallOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_pregnancy_safety', title=None, description='\n    Check if drug is safe during pregnancy.\n    Use for any pregnant patient.\n    \n    Returns dict with pregnancy_category, is_safe, risks, recommendation\n    ', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}, 'trimester': {'anyOf': [{'type': 'integer'}, {'type': 'null'}], 'default': None, 'title': 'Trimester'}}, 'required': ['drug_name'], 'title': 'check_pregnancy_safetyArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_pregnancy_safetyOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_renal_dosing', title=None, description='\n    Check if renal dose adjustment is needed.\n    Use when patient has CrCl < 60 mL/min.\n    \n    Returns dict with requires_adjustment, severity, guidance, recommendation\n    ', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}, 'creatinine_clearance': {'title': 'Creatinine Clearance', 'type': 'number'}}, 'required': ['drug_name', 'creatinine_clearance'], 'title': 'check_renal_dosingArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_renal_dosingOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_pediatric_dosing', title=None, description='\n    Check if pediatric dosing is appropriate.\n    Use for patients under 18 years old.\n    \n    Returns dict with approved_for_age, dosing_info, weight_based, recommendation\n    ', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}, 'patient_age': {'title': 'Patient Age', 'type': 'integer'}, 'weight_kg': {'anyOf': [{'type': 'number'}, {'type': 'null'}], 'default': None, 'title': 'Weight Kg'}}, 'required': ['drug_name', 'patient_age'], 'title': 'check_pediatric_dosingArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_pediatric_dosingOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_geriatric_considerations', title=None, description='\n    Check for special considerations in elderly patients (65+).\n    Use for patients 65 years or older.\n    \n    Returns dict with requires_adjustment, beers_criteria, considerations, recommendation\n    ', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}, 'patient_age': {'title': 'Patient Age', 'type': 'integer'}}, 'required': ['drug_name', 'patient_age'], 'title': 'check_geriatric_considerationsArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_geriatric_considerationsOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_drug_interaction', title=None, description='\n    Check if two drugs have a known interaction.\n    \n    Returns dict with has_interaction, severity, description, recommendation\n    ', inputSchema={'properties': {'drug1': {'title': 'Drug1', 'type': 'string'}, 'drug2': {'title': 'Drug2', 'type': 'string'}}, 'required': ['drug1', 'drug2'], 'title': 'check_drug_interactionArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_drug_interactionOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_contraindication', title=None, description='\n    Check if drug is contraindicated for a specific patient condition.\n    \n    Returns dict with is_contraindicated, reason, recommendation\n    ', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}, 'patient_condition': {'title': 'Patient Condition', 'type': 'string'}}, 'required': ['drug_name', 'patient_condition'], 'title': 'check_contraindicationArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_contraindicationOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_duplicate_therapy', title=None, description="\n    Check for duplicate medications in a prescription.\n    \n    Args:\n        medications: List of dicts with 'drug_name' and optionally 'generic_name'\n    \n    Returns:\n        List of duplicate issues found\n    ", inputSchema={'properties': {'medications': {'items': {'additionalProperties': True, 'type': 'object'}, 'title': 'Medications', 'type': 'array'}}, 'required': ['medications'], 'title': 'check_duplicate_therapyArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'items': {'additionalProperties': True, 'type': 'object'}, 'title': 'Result', 'type': 'array'}}, 'required': ['result'], 'title': 'check_duplicate_therapyOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='calculate_daily_dose', title=None, description='\n    Calculate total daily dose from single dose and frequency.\n    \n    Returns dict with daily_dose_mg, doses_per_day, frequency_parsed, warning\n    ', inputSchema={'properties': {'dose_per_administration': {'title': 'Dose Per Administration', 'type': 'string'}, 'frequency': {'title': 'Frequency', 'type': 'string'}}, 'required': ['dose_per_administration', 'frequency'], 'title': 'calculate_daily_doseArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'calculate_daily_doseOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_multi_drug_interactions', title=None, description='\n    Basic multi-drug interaction scan (label-based pairwise).\n    Production recommendation: replace with DrugBank / FDB / Medi-Span API.\n    ', inputSchema={'properties': {'drugs': {'items': {'type': 'string'}, 'title': 'Drugs', 'type': 'array'}}, 'required': ['drugs'], 'title': 'check_multi_drug_interactionsArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'check_multi_drug_interactionsOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='check_therapeutic_duplication', title=None, description="\n    Detect exact duplicates and therapeutic class duplication using ATC codes.\n    Expects medications = [{'drug_name': str, 'normalized': Dict (optional)}, ...]\n    ", inputSchema={'properties': {'medications': {'items': {'additionalProperties': True, 'type': 'object'}, 'title': 'Medications', 'type': 'array'}}, 'required': ['medications'], 'title': 'check_therapeutic_duplicationArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'items': {'additionalProperties': True, 'type': 'object'}, 'title': 'Result', 'type': 'array'}}, 'required': ['result'], 'title': 'check_therapeutic_duplicationOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='get_controlled_substance_info', title=None, description='Determine DEA schedule via openFDA NDC data', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}, 'rxcui': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Rxcui'}}, 'required': ['drug_name'], 'title': 'get_controlled_substance_infoArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'get_controlled_substance_infoOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='get_drug_label_info', title=None, description='\n    Get comprehensive FDA drug label information.\n    \n    Returns dict with drug details including indications, contraindications,\n    warnings, interactions, dosing, pregnancy info, etc.\n    ', inputSchema={'properties': {'drug_name': {'title': 'Drug Name', 'type': 'string'}}, 'required': ['drug_name'], 'title': 'get_drug_label_infoArguments', 'type': 'object'}, outputSchema={'properties': {'result': {'additionalProperties': True, 'title': 'Result', 'type': 'object'}}, 'required': ['result'], 'title': 'get_drug_label_infoOutput', 'type': 'object'}, icons=None, annotations=None, meta=None)]

# %%
INSTRUCTIONS = """
You are a clinical pharmacy validation assistant. You have access to a set of MCP tools
backed by the RxNorm API and the FDA openFDA API. Your role is to assist pharmacists
and clinicians in reviewing prescriptions for safety issues — not to make final clinical
decisions.

## Capabilities

You can validate a prescription against all of the following dimensions:
- Drug name normalisation (RxNorm)
- Allergy and cross-reactivity checking
- Active FDA recalls
- Pregnancy safety (label-based)
- Renal dose adjustment (CrCl-guided)
- Paediatric appropriateness
- Geriatric considerations (simplified Beers-style)
- Drug–drug interactions (pairwise label search)
- Multi-drug interaction scan across a full medication list
- Therapeutic and exact-duplicate detection (ATC-based and generic-based)
- Daily dose calculation (standard oral frequency abbreviations)
- Controlled-substance DEA scheduling
- Full FDA label retrieval (contraindications, warnings, dosing, interactions, etc.)

## Mandatory workflow

Follow these steps in order for every prescription validation request:

1. **Normalise each drug name** using `normalize_drug_name`.
   - Capture `rxcui`, `generic_name`, `ingredients`, and `atc_classes` from the result.
   - Pass the returned dict as `normalized` to `check_drug_allergy` and as the
     `normalized` field inside each medication dict for `check_therapeutic_duplication`.
   - If normalisation fails (`success: false`), note it but proceed using the raw name.

2. **Run mandatory safety gates** (do not skip these):
   - `check_drug_allergy` — pass the patient's full allergy list.
   - `check_drug_recall` — pass lot number when available.

3. **Run patient-specific checks** (only when the relevant data is present):
   - `check_pregnancy_safety` — any pregnant patient; include `trimester` if known.
   - `check_renal_dosing` — when CrCl is documented or suspected to be impaired.
   - `check_pediatric_dosing` — patients under 18; include weight in kg when known.
   - `check_geriatric_considerations` — patients 65 and older.

4. **Check interactions and duplicates** for multi-drug regimens:
   - `check_drug_interaction(drug1, drug2)` for targeted pairwise checking.
   - `check_multi_drug_interactions(drugs)` to scan all pairs in a list.
   - `check_duplicate_therapy(medications)` and/or `check_therapeutic_duplication(medications)`
     to catch redundant therapy.

5. **Verify contraindications** for relevant patient conditions:
   - `check_contraindication(drug_name, patient_condition)` for each known condition.

6. **Calculate daily dose** when the dose and frequency are provided:
   - `calculate_daily_dose(dose_per_administration, frequency)`.

7. **Retrieve full label** when you need indications, full warnings, or storage details:
   - `get_drug_label_info(drug_name)`.

## Interpreting results — critical rules

- `has_interaction: null` → Label data was unavailable. **Do not say "no interaction found."**
  Report it as unverified and recommend consulting a drug-interaction database.
- `is_contraindicated: null` → Condition was not found in the label.
  **Do not say the drug is safe for that condition.** Report as unverified.
- `has_allergy: false` → No substring match in this heuristic.
  **Do not say the patient is not allergic.** This check is not exhaustive.
- `has_recall: null` → The recall API call failed; status is unknown, not clear.
- Any empty `{}` label return → The FDA label was not found; do not infer safety.

## Communicating findings

Structure your response as a validation report with these sections:
1. **Drug identity** — normalised name, RxCUI, generic name, ATC class(es).
2. **Safety alerts** — allergy hits, active recalls, contraindications. Flag anything with
   `CRITICAL` or `DO NOT DISPENSE` prominently.
3. **Patient-specific concerns** — pregnancy, renal, paediatric, geriatric (as applicable).
4. **Interactions** — list any pairs flagged; include severity and source.
5. **Duplicates** — exact or therapeutic class.
6. **Dosing** — calculated daily dose; flag unusual frequencies.
7. **Controlled substance status** — DEA schedule when applicable.
8. **Data gaps** — explicitly list every check that returned null or no label, and recommend
   consulting Lexicomp, Micromedex, or a licensed pharmacist for those gaps.

## Scope and disclaimer

These tools use public APIs and heuristic label-text parsing. They are **not** a replacement
for a licensed pharmacist, clinical decision-support system (Lexicomp, Micromedex,
DrugBank, FDB, Medi-Span), or institutional formulary review. Always surface the
`recommendation` strings returned by each tool — they are written with cautious language.
Tell the user to confirm findings with a qualified clinician before any dispensing decision.
"""

# %%
REQUEST = """
Please perform a full prescription validation for the following patient and medication order.

## Patient
- Age: 72 years old
- Weight: 68 kg
- Sex: Female
- Pregnant: No
- Renal function: CrCl 22 mL/min (severe impairment)
- Known allergies: penicillin, sulfa drugs
- Active conditions: type 2 diabetes, hypertension, chronic kidney disease stage 4

## Prescription
- Drug: Metformin
- Strength / dose: 1000 mg per dose
- Route: Oral
- Frequency: BID (twice daily)
- Duration: 90 days
- Indication: glycaemic control

## Concurrent medications already prescribed
- Lisinopril 10 mg once daily
- Amlodipine 5 mg once daily
- Atorvastatin 40 mg once daily at bedtime

Please validate all of the following and provide a structured report:
1. Confirm the drug identity and generic name via RxNorm.
2. Check for allergy or cross-reactivity against her documented allergies.
3. Check for any active FDA recalls.
4. Assess whether Metformin is appropriate given CrCl 22 mL/min, and recommend dose adjustment or alternative if needed.
5. Check for relevant contraindications given her CKD stage 4 and diabetes.
6. Scan all four medications for drug–drug interactions.
7. Check for therapeutic duplication across the full regimen.
8. Calculate the total daily dose of Metformin as prescribed.
9. Note any geriatric considerations given her age.
10. Report any data gaps where findings could not be verified from available label data.
"""

# %%
params = {"command": "uv", "args": ["run", "rx_logic.py"]}

try:
    async with MCPServerStdio(params=params, client_session_timeout_seconds=120) as rx_logic_server:
        agent = Agent(
            name="RxValidator",
            model="gpt-4.1-mini",
            instructions=INSTRUCTIONS,
            mcp_servers=[rx_logic_server],
        )
        with trace("Rx_validation"):
            result = await Runner.run(agent, REQUEST, max_turns=30)

    if result.final_output:
        display(Markdown(result.final_output))
    else:
        print("⚠ Agent returned no output. Check the trace for tool call failures.")

except TimeoutError:
    print("✗ MCP session timed out — increase client_session_timeout_seconds or simplify the request.")
    raise
except Exception as e:
    print(f"✗ Validation failed: {type(e).__name__}: {e}")
    raise
# Out:
# Prescription Validation Report:
#
# 1. Drug Identity:
# - Metformin: Normalization via RxNorm failed in automated call, but it is a well-known generic drug for type 2 diabetes.
# - No normalized identifiers (RxCUI) or ATC class could be retrieved due to API failure.
#
# 2. Safety Alerts:
# - Allergy: No detected allergy or cross-reactivity with penicillin or sulfa drugs.
# - Active FDA Recalls:
#   - Metformin: ACTIVE RECALL DO NOT DISPENSE. Several ongoing recalls for Metformin hydrochloride extended-release tablets due to foreign tablets or NDMA impurities.
#   - Lisinopril: ACTIVE RECALL DO NOT DISPENSE. Ongoing recall of Lisinopril and Hydrochlorothiazide due to product mix-up (foreign tablets found).
#   - Amlodipine: ACTIVE RECALL DO NOT DISPENSE. Multiple ongoing recalls related to labeling errors and impurities in combination products with Amlodipine.
#   - Atorvastatin: ACTIVE RECALL DO NOT DISPENSE. Ongoing recalls for different lots due to failed dissolution and cGMP deviations.
# - Given the recalls on all current medications including Metformin, dispensing should be carefully reconsidered.
#
# 3. Patient-Specific Concerns:
# - Renal Dosing: Metformin requires dose adjustment given severe renal impairment (CrCl 22 mL/min). Use with caution or consider alternative antihyperglycemic agents.
# - Pregnancy: Not applicable (patient not pregnant).
# - Geriatric: Dose adjustment recommended in elderly patients; start low and titrate carefully due to altered renal/hepatic function and risk of lactic acidosis.
# - Contraindications: No label-based contraindication found for Metformin with chronic kidney disease, but clinical caution is advised. Verify with specialist references.
#
# 4. Interactions:
# - No drug–drug interaction found between Metformin, Lisinopril, Amlodipine, and Atorvastatin based on label data.
# - Interactions not ruled out beyond label — clinical monitoring remains appropriate.
#
# 5. Duplicates:
# - No exact or therapeutic duplication detected among Metformin, Lisinopril, Amlodipine, or Atorvastatin.
#
# 6. Dosing:
# - Total daily dose of Metformin prescribed: 2000 mg/day (1000 mg twice daily).
# - Dose requires adjustment for renal impairment and geriatric considerations.
#
# 7. Controlled Substance Status:
# - Not applicable.
#
# 8. Data Gaps:
# - Drug name normalization failed for all drugs; manual validation recommended.
# - Allergy checks are heuristic; absence of allergy alerts does not confirm safety.
# - Contraindication for CKD not explicitly labeled; recommend specialist consultation.
# - FDA recalls data is lot-specific and may not apply to all product batches.
# - Interaction labels showed no interactions but data sometimes incomplete; clinical vigilance needed.
#
# Summary & Recommendations:
# - DO NOT DISPENSE the current batches of Metformin, Lisinopril, Amlodipine, and Atorvastatin due to active FDA recalls.
# - Given patient's severe renal impairment, Metformin dose should be re-evaluated and alternative agents considered.
# - Start Metformin at a lower dose in geriatric patients and monitor renal function closely.
# - Confirm allergy safety manually and consult specialist references for contraindications and dosing.
# - Review all medications and batches for recall status before dispensing.
# - Confirm all findings with qualified clinicians and licensed pharmacists before any clinical decision or dispensing.
