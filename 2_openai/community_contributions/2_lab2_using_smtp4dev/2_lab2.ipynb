# %% [markdown]
# ## Week 2 Day 2
#
# Our first Agentic Framework project!!
#
# Prepare yourself for something ridiculously easy.
#
# We're going to build a simple Agent system for generating cold sales outreach emails:
# 1. Agent workflow
# 2. Use of tools to call functions
# 3. Agent collaboration via Tools and Handoffs

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">IMPORTANT PLEASE READ - Emails with SendGrid</h2>
#             <span style="color:#ff7800;">We are going to use the email provider SendGrid. But this is OPTIONAL.<br/>
#             The next cell contains instructions for SendGrid. But if this gives you problems, or if you'd rather use any alternative,<br/>
#             please see <a href="https://edwarddonner.com/faq">Q29 on the FAQ page here</a> for the full explanation and alternatives.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# In this lab you'll can choose between two SMTP providers: one third-party (Sendgrid) and a local (Smtp4Dev). Before setting up the SMTP server, load the common dependencies

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool
from openai.types.responses import ResponseTextDeltaEvent
from typing import Dict
import os
import asyncio
import time
import requests

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# # Setting up to send emails from your SMTP server
# ## Step 1: Determining your SMTP Server
# Either Google or ask ChatGPT/Claude fpr the SMTP server for your email. Here a some common ones. Some email providers might not have SMTP server enabled (eg Microsoft 365 for work/school)
#
# Another way to test email is to use a free tool like smtp4dev
#
# ## Step 2: Running Smtp4Dev
# Smtp4Dev is a free tool for testing and debugging. For more information visit https://smtp4dev.com/
#
# To install you can download the installer for Windows, macOS or Linux, or you can run using Docker.
#
# To run using Docker it's necessary to have a Docker Client installed on your computer. After installing execute this command:
#
# ```bash
# docker run -p 8080:80 -p 2525:25 rnwood/smtp4dev
# ```
#
# for persistent storage:
# ```bash
# docker run -p 8080:80 -p 2525:25 -v /path/to/data:/smtp4dev rnwood/smtp4dev
# ```
#
# ## Step 3: Configuring Smtp4Dev
# After running the Smtp4Dev we'll need to configure Mailboxes and Users. These configurations are available in Settings (⚙️) icon in the top right header.
#
# ### Setting up a Mailbox
# 1. Navigate to **Mailboxes** tab
# 2. Uncheck `Deliver messages to sending user's default mailbox`
# 3. Click on `+New Mailbox`
# 4. Set a name
# 5. Set the recipients
#
# ### Creating users
# 1. Navigate to **Users** tab
# 2. Click on `New User`
# 3. Set a username, password and select the default Mailbox
#
# Add this two new lines to your .env file:
#
# `SMTP4DEV_HOST=localhost`
#
# `SMTP4DEV_PORT=2525`

# %%
FROM_EMAIL_ADDRESS = os.environ.get("FROM_EMAIL")
TO_EMAIL_ADDRESS = os.environ.get("TO_EMAIL")
SMTP4DEV_HOST = os.environ.get("SMTP4DEV_HOST")
SMTP4DEV_PORT = int(os.environ.get("SMTP4DEV_PORT", 2525))
SMTP4DEV_BASE_URL = os.environ.get("SMTP4DEV_BASE_URL")
SMTP4DEV_MAILBOX = os.environ.get("SMTP4DEV_MAILBOX")

if FROM_EMAIL_ADDRESS:
    print("From Email address set")
else:
    print("From email address is not set")

if TO_EMAIL_ADDRESS:
    print("To Email address set")
else:
    print("To email address is not set")

USE_EMAIL = FROM_EMAIL_ADDRESS and TO_EMAIL_ADDRESS and SMTP4DEV_HOST and SMTP4DEV_PORT

if USE_EMAIL:
    print("Email is set up and we'll try to use it in Smtp4Dev")
else:
    print("Email is not set up. We will send push notification instead")

SMTP4DEV_TEST = SMTP4DEV_BASE_URL and SMTP4DEV_MAILBOX
if SMTP4DEV_TEST:
    print("Smtp4Dev is set for debugging.")
else:
    print("Smtp4Dev is not set for debugging.")
# Out:
# From Email address set
# To Email address set
# Email is set up and we'll try to use it in Smtp4Dev
# Smtp4Dev is set for debugging.

# %%
# Dependencies for Smtp4Dev
import smtplib
from email.mime.text import MIMEText

# %%
# Let's check if Smtp4Dev is working
def send_test_smtp4dev_email(subject: str, text_body: str):
    msg = MIMEText(text_body)
    msg['Subject'] = subject
    msg['From'] = FROM_EMAIL_ADDRESS
    msg['To'] = TO_EMAIL_ADDRESS

    with smtplib.SMTP(SMTP4DEV_HOST, SMTP4DEV_PORT) as smtp:
        smtp.send_message(msg)

    # check if email was sent
    time.sleep(2)
    
    response = requests.get(f"{SMTP4DEV_BASE_URL}/api/messages?mailboxName={SMTP4DEV_MAILBOX}")
    messages = response.json()

    if len(messages) > 0:
        print("Message sent to Smtp4Devs")
    else: 
        print("No message sent.")

    received_message_subject = messages['results'][0]['subject']

    if received_message_subject == subject:
        print("Test message found in inbox")
    else:
        print("No test message found in inbox")
    

send_test_smtp4dev_email("Test Smtp4Dev", "Smtp4Dev is working!")
# Out:
# Message sent to Smtp4Devs
# Test message found in inbox

# %% [markdown]
# Fallback strategy - send a push

# %%
pushover_user = os.getenv("PUSHOVER_USER")
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

if pushover_user:
    if pushover_user.startswith("u"):
        print("Pushover user found and looks good")
    else:
        print("Pushouver user found but doesn't start with u")
else:
    print("Pushover user not found")

if pushover_token:
    if pushover_token.startswith("a"):
        print("Pushover token found and looks good")
    else:
        print("Pushover token found but doesn't start with a")
else:
    print("Pushover token not found")
# Out:
# Pushover user not found
# Pushover token not found

# %%
def push(message):
    print(f"Push: {message}")
    payload = {"user": pushover_user, "token": pushover_token, "message": message}
    requests.post(pushover_url, json=payload)

# %% [markdown]
# ## Setting up SendGrid
#
#
# Please visit Sendgrid at: https://sendgrid.com/
#
# (Sendgrid is a Twilio company for sending emails.)
#
# __If SendGrid gives you problems, see the alternative implementations on Q29 of my FAQ page at https://edwarddonner.com/faq that includes "Resend Email" in community_contributions/2_lab2_with_resend_email and just skipping email altogether.__
#
# Setting up a SendGrid account is free! (at least, for me, right now).
#
# Once you've created an account, click on:
#
# Settings (left sidebar) >> API Keys >> Create API Key (button on top right)
#
# Copy the key to the clipboard, then add a new line to your .env file:
#
# `SENDGRID_API_KEY=xxxx`
#
# And also, within SendGrid, go to:
#
# Settings (left sidebar) >> Sender Authentication >> "Verify a Single Sender"
# and verify that your own email address is a real email address, so that SendGrid can send emails for you.

# %%
import sendgrid
from sendgrid.helpers.mail import Mail, Email, To, Content

# %%
SENDGRID_API_KEY = os.environ.get("SENDGRID_API_KEY")

if SENDGRID_API_KEY:
    print("SendGrip API key is set")
else:
    print("SendGrip API key is not set")
# Out:
# SendGrip API key is not set

# %%
# Let's just check emails are working for you

def send_test_sendgrid_email(subject: str, text_body: str):
    sg = sendgrid.SendGridAPIClient(api_key=SENDGRID_API_KEY)
    from_email = Email(FROM_EMAIL_ADDRESS)  # Change to your verified sender
    to_email = To(TO_EMAIL_ADDRESS)  # Change to your recipient
    content = Content("text/plain", text_body)
    mail = Mail(from_email, to_email, subject, content).get()
    response = sg.client.mail.send.post(request_body=mail)
    print(response.status_code)

send_test_sendgrid_email("Test SendGrid", "Sent Grid is good to go!")
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedError                         Traceback (most recent call last)
# Cell In[50], line 12
#       9     response = sg.client.mail.send.post(request_body=mail)
#      10     print(response.status_code)
# ---> 12 send_test_sendgrid_email("Test SendGrid", "Sent Grid is good to go!")
#
# Cell In[50], line 9, in send_test_sendgrid_email(subject, text_body)
#       7 content = Content("text/plain", text_body)
#       8 mail = Mail(from_email, to_email, subject, content).get()
# ----> 9 response = sg.client.mail.send.post(request_body=mail)
#      10 print(response.status_code)
#
# File ~/Projects/udemy/agentics-ai/agents/.venv/lib/python3.12/site-packages/python_http_client/client.py:277, in Client.__getattr__.<locals>.http_request(request_body, query_params, request_headers, timeout, **_)
#     271     _logger.debug('PAYLOAD: {data}'.format(
#     272         data=request.data))
# ...

# %%
def send_message(subject: str, text_body: str):
    if os.environ.get('SENDGRID_API_KEY'):
        print("SendGrid configured. Sending email.")
        send_test_smtp4dev_email(subject, text_body)
    elif USE_EMAIL:
        print("Smtp4Dev configured. Sending email.")
        send_test_smtp4dev_email(subject, text_body)
    else:
        print('Fallback strategy: push message')
        push(f"Subject: {subject}\n\n{text_body}")

send_message("Big news!", "Communications are a go!")
# Out:
# Smtp4Dev configured. Sending email.
# Message sent to Smtp4Devs
# Test message found in inbox

# %% [markdown]
# ### Did you receive the test email
#
# If you get a 202, then you're good to go!
#
# #### Certificate error
#
# If you get an error SSL: CERTIFICATE_VERIFY_FAILED then students Chris S and Oleksandr K have suggestions:
# First run this: `!uv pip install --upgrade certifi`
# Next, run this:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# #### Other errors or no email
#
# If there are other problems, you'll need to check your API key and your verified sender email address in the SendGrid dashboard
#
# Or use the alternative implementation using "Resend Email" in community_contributions/2_lab2_with_resend_email
#
# (Or - you could always replace the email sending code below with a Pushover call, or something to simply write to a flat file)

# %% [markdown]
# ## Step 1: Agent workflow

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gpt-4o-mini"
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gpt-4o-mini"
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gpt-4o-mini"
)

# %%
result = Runner.run_streamed(sales_agent1, input="Write a cold sales email")
async for event in result.stream_events():
    if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
        print(event.data.delta, end="", flush=True)
# Out:
# Subject: Simplify Your SOC 2 Compliance Journey with ComplAI
#
# Dear [Recipient's Name],
#
# I hope this message finds you well.
#
# Navigating the complexities of SOC 2 compliance can be daunting, especially in today’s fast-paced business environment. At ComplAI, we understand the challenges companies face when preparing for audits and ensuring ongoing compliance. Our AI-powered SaaS tool is designed to streamline this process, making it more efficient and less time-consuming.
#
# With ComplAI, you can:
#
# - Automate compliance documentation and reporting
# - Stay up-to-date with regulatory changes
# - Identify gaps in your current compliance strategy
# - Prepare for audits with confidence, knowing you're fully equipped to meet requirements
#
# Our platform has helped numerous businesses reduce the time spent on compliance by up to 50%, allowing teams to focus on what they do best.
#
# ...

# %%
message = "Write a cold sales email"

with trace("Parallel cold emails"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )

outputs = [result.final_output for result in results]

for output in outputs:
    print(output + "\n\n")
# Out:
# Subject: Streamline Your SOC 2 Compliance Process
#
# Hi [Recipient's Name],
#
# I hope this message finds you well. My name is [Your Name], and I'm reaching out from ComplAI, where we specialize in providing AI-powered solutions for SOC 2 compliance.
#
# As organizations increasingly prioritize data security and privacy, ensuring robust compliance frameworks can be both challenging and time-consuming. Our SaaS tool simplifies the entire compliance process, enabling you to prepare for audits efficiently while reducing manual efforts.
#
# Here’s how ComplAI can benefit your organization:
#
# - **Automated Documentation:** Generate necessary documentation effortlessly, ensuring alignment with SOC 2 requirements.
# - **Real-Time Monitoring:** Stay ahead of compliance with automated alerts and insights tailored to your organization’s needs.
# - **Streamlined Audits:** Simplify the audit process with comprehensive reports that are ready for review at any time.
#
# ...

# %%
sales_picker = Agent(
    name="sales_picker",
    instructions="You pick the best cold sales email from the given options. \
Imagine you are a customer and pick the one you are most likely to respond to. \
Do not give an explanation; reply with the selected email only.",
    model="gpt-4o-mini"
)

# %%
message = "Write a cold sales email"

with trace("Selection from sales people"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )
    outputs = [result.final_output for result in results]

    emails = "Cold sales emails:\n\n" + "\n\nEmail:\n\n".join(outputs)

    best = await Runner.run(sales_picker, emails)

    print(f"Best sales email:\n{best.final_output}")
# Out:
# Best sales email:
# Subject: Is Your SOC2 Compliance as Relaxed as a Cat on a Sunny Windowsill? 😺🌞
#
# Hey [Recipient's Name],
#
# I hope this email finds you lounging comfortably in the sun with a cup of coffee—just like that cat I mentioned!
#
# Now, I know that SOC2 compliance isn’t usually as cozy as a catnap, but at ComplAI, we’re here to change that. Think of us as the fluffy blanket that wraps you up in a world of stress-free audits and seamless compliance solutions!
#
# Our AI-powered SaaS tool takes the headache out of compliance management. Need to ensure your data security is top-notch? Done! Want to prepare for audits without breaking a sweat? Done! It’s like having a compliance superhero on your team—cape included (metaphorically, of course).
#
# Let’s chat! I promise there’s no long-winded sales pitch, just a friendly conversation about how we can make your compliance journey as smooth as...well, a cat sliding off a windowsill!
#
# ...

# %% [markdown]
# Now go and check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 2: use of tools
#
# Now we will add a tool to the mix.
#
# Remember all that json boilerplate and the `handle_tool_calls()` function with the if logic..

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="gpt-4o-mini",
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="gpt-4o-mini",
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="gpt-4o-mini",
)

# %%
sales_agent1
# Out:
# Agent(name='Professional Sales Agent', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write professional, serious cold emails.', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %% [markdown]
# ## Steps 2 and 3: Tools and Agent interactions
#
# Remember all that boilerplate json?
#
# Simply wrap your function with the decorator `@function_tool`

# %%
@function_tool
def send_email(body: str):
    """ Send out an email with the given body to all sales prospects """
    if SENDGRID_API_KEY:
        send_email_with_sendgrid(body)
        return {"status": "success"}
    if USE_EMAIL:
        send_email_with_smtp4dev(body)
    else:
        push(body)
    return {"status": "success"}


def send_email_with_sendgrid(body: str):
    sg = sendgrid.SendGridAPIClient(api_key=SENDGRID_API_KEY)
    from_email = Email(FROM_EMAIL_ADDRESS)  # Change to your verified sender
    to_email = To(TO_EMAIL_ADDRESS)  # Change to your recipient
    content = Content("text/plain", body)
    mail = Mail(from_email, to_email, "Sales email", content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}


def send_email_with_smtp4dev(body: str):
    msg = MIMEText(body)
    msg['Subject'] = 'Test Email'
    msg['From'] = FROM_EMAIL_ADDRESS
    msg['To'] = TO_EMAIL_ADDRESS
    with smtplib.SMTP(SMTP4DEV_HOST, SMTP4DEV_PORT) as smtp:
        smtp.send_message(msg)
    return {"status": "success"}

# %% [markdown]
# ### This has automatically been converted into a tool, with the boilerplate json created

# %%
# Let's look at it
send_email
# Out:
# FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x70ba9d747c40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %%
send_email.params_json_schema
# Out:
# {'properties': {'body': {'title': 'Body', 'type': 'string'}},
#  'required': ['body'],
#  'title': 'send_email_args',
#  'type': 'object',
#  'additionalProperties': False}

# %%
from agents import ModelSettings


decision = """
You pick the best cold sales email from the given options.
Imagine you are a customer and pick the one you are most likely to respond to.
Then use your tool to send the email.
"""

require_tool = ModelSettings(tool_choice="required")

sales_sender = Agent(name="Sales Sender", instructions=decision, model="gpt-4o-mini", tools=[send_email], model_settings=require_tool)

# %%
message = "Write a cold sales email"

with trace("Selection from sales people"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )
    outputs = [result.final_output for result in results]

    emails = "Cold sales emails:\n\n" + "\n\nEmail:\n\n".join(outputs)

    response = await Runner.run(sales_sender, emails)

    print(f"Best sales email:\n{best.final_output}")
# Out:
# Best sales email:
# Subject: Is Your SOC2 Compliance as Relaxed as a Cat on a Sunny Windowsill? 😺🌞
#
# Hey [Recipient's Name],
#
# I hope this email finds you lounging comfortably in the sun with a cup of coffee—just like that cat I mentioned!
#
# Now, I know that SOC2 compliance isn’t usually as cozy as a catnap, but at ComplAI, we’re here to change that. Think of us as the fluffy blanket that wraps you up in a world of stress-free audits and seamless compliance solutions!
#
# Our AI-powered SaaS tool takes the headache out of compliance management. Need to ensure your data security is top-notch? Done! Want to prepare for audits without breaking a sweat? Done! It’s like having a compliance superhero on your team—cape included (metaphorically, of course).
#
# Let’s chat! I promise there’s no long-winded sales pitch, just a friendly conversation about how we can make your compliance journey as smooth as...well, a cat sliding off a windowsill!
#
# ...

# %% [markdown]
# ### And you can also convert an Agent into a tool

# %%
tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description="Write a cold sales email")
tool1
# Out:
# FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x70ba9cc5c540>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)

# %% [markdown]
# ### So now we can gather all the tools together:
#
# A tool for each of our 3 email-writing agents
#
# And a tool for our function to send emails

# %%
description = "Write a cold sales email"

tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_agent2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_agent3", tool_description=description)

tools = [tool1, tool2, tool3, send_email]

tools
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x70ba9cc5c5e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
#  FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x70bab099d800>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None),
# ...

# %% [markdown]
# ## And now it's time for our Sales Manager - our planning agent

# %%
# Improved instructions thanks to student Guillermo F.

instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use the send_email tool to send the best email (and only the best email) to the user.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must send ONE email using the send_email tool — never more than one.
"""


sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model="gpt-4o-mini")

message = "Send a cold sales email addressed to 'Dear CEO'"

with trace("Sales manager"):
    result = await Runner.run(sales_manager, message)

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Wait - you didn't get an email??</h2>
#             <span style="color:#ff7800;">With much thanks to student Chris S. for describing his issue and fixes.
#             If you don't receive an email after running the prior cell, here are some things to check: <br/>
#             First, check your Spam folder! Several students have missed that the emails arrived in Spam!<br/>Second, print(result) and see if you are receiving errors about SSL.
#             If you're receiving SSL errors, then please check out theses <a href="https://chatgpt.com/share/680620ec-3b30-8012-8c26-ca86693d0e3d">networking tips</a> and see the note in the next cell. Also look at the trace in OpenAI, and investigate on the SendGrid website, to hunt for clues. Let me know if I can help!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And one more suggestion to send emails from student Oleksandr on Windows 11:
#
# If you are getting certificate SSL errors, then:
# Run this in a terminal: `uv pip install --upgrade certifi`
#
# Then run this code:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# Thank you Oleksandr!

# %% [markdown]
# ## Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# ### Handoffs represent a way an agent can delegate to an agent, passing control to it
#
# Handoffs and Agents-as-tools are similar:
#
# In both cases, an Agent can collaborate with another Agent
#
# With tools, control passes back
#
# With handoffs, control passes across

# %%
subject_instructions = "You can write a subject for a cold sales email. \
You are given a message and you need to write a subject for an email that is likely to get a response."

html_instructions = "You can convert a text email body to an HTML email body. \
You are given a text email body which might have some markdown \
and you need to convert it to an HTML email body with simple, clear, compelling layout and design."

subject_writer = Agent(name="Email subject writer", instructions=subject_instructions, model="gpt-4o-mini")
subject_tool = subject_writer.as_tool(tool_name="subject_writer", tool_description="Write a subject for a cold sales email")

html_converter = Agent(name="HTML email body converter", instructions=html_instructions, model="gpt-4o-mini")
html_tool = html_converter.as_tool(tool_name="html_converter",tool_description="Convert a text email body to an HTML email body")

# %%
@function_tool
def send_html_email(subject: str, html_body: str) -> Dict[str, str]:
    """ Send out an email with the given subject and HTML body to all sales prospects """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("ed@edwarddonner.com")  # Change to your verified sender
    to_email = To("ed.donner@gmail.com")  # Change to your recipient
    content = Content("text/html", html_body)
    mail = Mail(from_email, to_email, subject, content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %%
tools = [subject_tool, html_tool, send_html_email]

# %%
tools

# %%
instructions ="You are an email formatter and sender. You receive the body of an email to be sent. \
You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. \
Finally, you use the send_html_email tool to send the email with the subject and HTML body."


emailer_agent = Agent(
    name="Email Manager",
    instructions=instructions,
    tools=tools,
    model="gpt-4o-mini",
    handoff_description="Convert an email to HTML and send it")

# %% [markdown]
# ### Now we have 3 tools and 1 handoff

# %%
tools = [tool1, tool2, tool3]
handoffs = [emailer_agent]
print(tools)
print(handoffs)

# %%
# Improved instructions thanks to student Guillermo F.

sales_manager_instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
You can use the tools multiple times if you're not satisfied with the results from the first try.
 
3. Handoff for Sending: Pass ONLY the winning email draft to the 'Email Manager' agent. The Email Manager will take care of formatting and sending.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must hand off exactly ONE email to the Email Manager — never more than one.
"""


sales_manager = Agent(
    name="Sales Manager",
    instructions=sales_manager_instructions,
    tools=tools,
    handoffs=handoffs,
    model="gpt-4o-mini")

message = "Send out a cold sales email addressed to Dear CEO from Alice"

with trace("Automated SDR"):
    result = await Runner.run(sales_manager, message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 24
#       1 # Improved instructions thanks to student Guillermo F.
#       3 sales_manager_instructions = """
#       4 You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
#       5
#    (...)     16 - You must hand off exactly ONE email to the Email Manager — never more than one.
#      17 """
#      20 sales_manager = Agent(
#      21     name="Sales Manager",
#      22     instructions=sales_manager_instructions,
#      23     tools=tools,
# ---> 24     handoffs=handoffs,
#      25     model="gpt-4o-mini")
#      27 message = "Send out a cold sales email addressed to Dear CEO from Alice"
#      29 with trace("Automated SDR"):
#
# NameError: name 'handoffs' is not defined

# %% [markdown]
# ### Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Can you identify the Agentic design patterns that were used here?<br/>
#             What is the 1 line that changed this from being an Agentic "workflow" to "agent" under Anthropic's definition?<br/>
#             Try adding in more tools and Agents! You could have tools that handle the mail merge to send to a list.<br/><br/>
#             HARD CHALLENGE: research how you can have SendGrid call a Callback webhook when a user replies to an email,
#             Then have the SDR respond to keep the conversation going! This may require some "vibe coding" 😂
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">This is immediately applicable to Sales Automation; but more generally this could be applied to  end-to-end automation of any business process through conversations and tools. Think of ways you could apply an Agent solution
#             like this in your day job.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Extra note:
#
# Google has released their Agent Development Kit (ADK). It's not yet got the traction of the other frameworks on this course, but it's getting some attention. It's interesting to note that it looks quite similar to OpenAI Agents SDK. To give you a preview, here's a peak at sample code from ADK:
#
# ```
# root_agent = Agent(
#     name="weather_time_agent",
#     model="gemini-2.0-flash",
#     description="Agent to answer questions about the time and weather in a city.",
#     instruction="You are a helpful agent who can answer user questions about the time and weather in a city.",
#     tools=[get_weather, get_current_time]
# )
# ```
#
# Well, that looks familiar!
#
# And a student has contributed a customer care agent in community_contributions that uses ADK.
