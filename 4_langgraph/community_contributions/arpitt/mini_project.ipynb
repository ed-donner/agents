# %% [markdown]
# Research + Report Agent

# %% [markdown]
# EXAMPLE --> "Research future of EV industry in India and save a report"

# %% [markdown]
# Let's make use of these tools for this  -->
#
# 1. Planner Node --- this will op in SO
# 2. Worker Node ----> makes use of WebSearchTool and also, a File Saving tool(need to think more on this)
# 3. Evaluator Node ----> OP = SO

# %%
from typing import Annotated, TypedDict, List, Dict, Any, Optional
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit, FileManagementToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser
from langgraph.graph import StateGraph, START, END
from langgraph.checkpoint.memory import MemorySaver
from langgraph.prebuilt import ToolNode
from langgraph.graph.message import add_messages
from pydantic import BaseModel, Field
from IPython.display import Image, display
import gradio as gr
import uuid
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
class PlannerSO(BaseModel) : 
    plan : List[str] = Field(description='The plan')

# %%
class EvaluatorSO(BaseModel) : 
    feedback : str
    rework_required : bool
    max_retry : int

# %%
class State(TypedDict) :
    
    messages : Annotated[List[Any], add_messages]
    plan : List[str]
    feedback : str
    rework_required : bool
    report : str
    max_retry : int

# %%
# Get our async Playwright tools
# If you get a NotImplementedError here or later, see the Heads Up at the top of the 3_lab3 notebook

import nest_asyncio
nest_asyncio.apply()
async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
web_tools = toolkit.get_tools()

# %%
w_tools = web_tools

# %%
planner_llm = ChatOpenAI(model='gpt-4o-mini')
planner_llm = planner_llm.with_structured_output(PlannerSO)

worker_llm =  ChatOpenAI(model='gpt-4o-mini')
worker_llm_with_tools = worker_llm.bind_tools(w_tools)

evaluator_llm = ChatOpenAI(model='gpt-4o-mini')
evaluator_llm = evaluator_llm.with_structured_output(EvaluatorSO)

# %%
def planner(state : State) -> Dict[str, Any] :
    planner_prompt = f''' You are an excellent planner and expert. 
    You are an expert in planning. 
    You are provided with a user's query which is \n {state['messages']}
    Your job is to create a clear step-by-step execution plan
    for solving the user's request.
    Create a concise actionable plan.
    Each step should represent one meaningful action.
    Do not execute the steps.
    Only create the plan.
    '''

    response = planner_llm.invoke(planner_prompt)
    print(f'Planners PLAN - {response}' )

    return {
        'plan' : response
    }

# %%
def worker(state : State) -> Dict[str, Any]:

    worker_prompt = f'''
    You are an expert at research.  
    YOu are provided with a plan of action which is \n {state["plan"]}.
    You are also provided with tools such as the Web Search Tool
    for doing the research.
    Use these tools to do research .
    Do not explain what you will do.
    Execute the task using tools and come up with a final report.
    '''

    if state.get('rework_required') :
        worker_prompt += f''' Earlier you had provided the report but it was rejected by the 
        evaluator llm with this feedback -  \n {state["feedback"]}
        With this feedback, please continue the assignment and make it right.                               
    '''

    w_response = worker_llm.invoke(worker_prompt)
    print(f'Here\'s the report by the Worker - \n {w_response}')

    return {
        'report' : w_response
    }

# %%
def evaluator(state : State) -> Dict[str, Any] :
    eval_prompt = f''' You are an expert intelliigent evaluator. You are provided with a user\'s
    input query which is this - \n {state['messages'][-1].content}
    Planner llm has given this action plan - {state["plan"]}
    and worker llm has created this report from the plan - \n {state["report"]}
    Evaluate the report and check if this fulfills user\'s inquired details or not.
    Provide your feedback on the report and also, ratew the report on a scale of 10. 
    '''

    e_response = evaluator_llm.invoke(eval_prompt)

    print(f'Evaluation of the report \n - {e_response}')

    return {
        'feedback' : e_response.feedback,
        'rework_required' : e_response.rework_required,
        'max_retry': state['max_retry'] + 1
    }

# %%
def write_report(state : State) :

    report_text = state['report'].content
    
    with open("langgraph_report.txt" , "w", encoding='utf-8') as f:
        f.write(report_text)
    
    print("Report written successfully.")

    return {}

# %%
def eval_routing(state : State) : 
    if state['rework_required'] and state['max_retry'] <5:
        return 'worker'
    else:
        return 'write_report'

# %%
def worker_tool_routing(state : State) :
    last_message = state['messages'][-1]

    if hasattr(last_message, "tool_calls") and last_message.tool_calls :
        return "tools"
    else:
        return "evaluator"

# %%
print(worker_llm_with_tools)
# Out:
# bound=ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x0000023BBB8E5490>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000023BBB8B9010>, root_client=<openai.OpenAI object at 0x0000023BBB8E7710>, root_async_client=<openai.AsyncOpenAI object at 0x0000023BBB8E65D0>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True) kwargs={'tools': [{'type': 'function', 'function': {'name': 'click_element', 'description': 'Click on an element with the given CSS selector', 'parameters': {'properties': {'selector': {'description': 'CSS selector for the element to click', 'type': 'string'}}, 'required': ['selector'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'navigate_browser', 'description': 'Navigate a browser to the specified URL', 'parameters': {'properties': {'url': {'description': 'url to navigate to', 'type': 'string'}}, 'required': ['url'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'previous_webpage', 'description': 'Navigate back to the previous page in the browser history', 'parameters': {'properties': {}, 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'extract_text', 'description': 'Extract all the text on the current webpage', 'parameters': {'properties': {}, 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'extract_hyperlinks', 'description': 'Extract all hyperlinks on the current webpage', 'parameters': {'properties': {'absolute_urls': {'default': False, 'description': 'Return absolute URLs instead of relative URLs', 'type': 'boolean'}}, 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'get_elements', 'description': 'Retrieve elements in the current web page matching the given CSS selector', 'parameters': {'properties': {'selector': {'description': "CSS selector, such as '*', 'div', 'p', 'a', #id, .classname", 'type': 'string'}, 'attributes': {'description': 'Set of attributes to retrieve for each element', 'items': {'type': 'string'}, 'type': 'array'}}, 'required': ['selector', 'attributes'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'current_webpage', 'description': 'Returns the URL of the current page', 'parameters': {'properties': {}, 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'copy_file', 'description': 'Create a copy of a file in a specified location', 'parameters': {'properties': {'source_path': {'description': 'Path of the file to copy', 'type': 'string'}, 'destination_path': {'description': 'Path to save the copied file', 'type': 'string'}}, 'required': ['source_path', 'destination_path'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'file_delete', 'description': 'Delete a file', 'parameters': {'properties': {'file_path': {'description': 'Path of the file to delete', 'type': 'string'}}, 'required': ['file_path'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'file_search', 'description': 'Recursively search for files in a subdirectory that match the regex pattern', 'parameters': {'properties': {'dir_path': {'default': '.', 'description': 'Subdirectory to search in.', 'type': 'string'}, 'pattern': {'description': 'Unix shell regex, where * matches everything.', 'type': 'string'}}, 'required': ['pattern'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'move_file', 'description': 'Move or rename a file from one location to another', 'parameters': {'properties': {'source_path': {'description': 'Path of the file to move', 'type': 'string'}, 'destination_path': {'description': 'New path for the moved file', 'type': 'string'}}, 'required': ['source_path', 'destination_path'], 'type': 'object'}}}, {'type': 'function', 'function': {'name': 'read_file', 'description': 'Read file from disk', 'parameters': {'properties': {'file_path': {'description': 'name of file', 'type': 'string'}}, 'required': ['file_path'], 'type': 'object' ...

# %%
graph1 = StateGraph(State)

graph1.add_node('planner', planner)
graph1.add_node('tools', ToolNode(tools=w_tools))
graph1.add_node('worker', worker)
graph1.add_node('evaluator', evaluator)
graph1.add_node('write_report', write_report)

graph1.add_edge(START, 'planner')
graph1.add_edge('planner', 'worker')
graph1.add_conditional_edges('worker', worker_tool_routing, {'tools' : 'tools' , 'evaluator' : 'evaluator'})
graph1.add_edge('tools', 'worker')
graph1.add_conditional_edges('evaluator' , eval_routing, {'worker' : 'worker', 'write_report' : 'write_report'})
graph1.add_edge('write_report', END)

# %%
graph = graph1.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
#invoking
messagess = [
    SystemMessage(content= 'You are a helpful assistant'),
    HumanMessage(content='future trends of Porn Industry in coming years')
]

state = {

    "messages" : messagess,
    "plan" : None,
    "feedback" : None,
    "rework_required" : None,
    "report" : None,
    "max_retry" : 0
}

result = await graph.ainvoke(state)
# Out:
# Planners PLAN - plan=['Research current trends in the porn industry as of 2023.', 'Identify technological advancements impacting the industry (e.g., VR, AI, streaming technology).', 'Analyze regulatory changes and societal attitudes towards adult content.', 'Examine emerging platforms and content delivery methods (e.g., subscription models, social media influence).', 'Investigate user demographics and preferences shifts in the pornographic audience.', 'Explore potential impacts of mental health awareness on consumption patterns.', 'Forecast future developments based on current data and historical patterns.', 'Compile findings into a comprehensive report highlighting key future trends.']
# Here's the report by the Worker -
#  content="I will now execute the plan of action using the Web Search Tool.\n\n1. Research current trends in the porn industry as of 2023.\n2. Identify technological advancements impacting the industry (e.g., VR, AI, streaming technology).\n3. Analyze regulatory changes and societal attitudes towards adult content.\n4. Examine emerging platforms and content delivery methods (e.g., subscription models, social media influence).\n5. Investigate user demographics and preferences shifts in the pornographic audience.\n6. Explore potential impacts of mental health awareness on consumption patterns.\n7. Forecast future developments based on current data and historical patterns.\n8. Compile findings into a comprehensive report highlighting key future trends. \n\nLet's begin with the first step. Searching for current trends in the porn industry as of 2023." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 156, 'prompt_tokens': 214, 'total_tokens': 370, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a7b0b5e194', 'id': 'chatcmpl-DkaLceyTfjEjMFoJt0H61jzvueKmW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--de9f21c9-7091-4e2a-b468-cd0f46d82d52-0' usage_metadata={'input_tokens': 214, 'output_tokens': 156, 'total_tokens': 370, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# Evaluation of the report
#  - feedback="The report outlines a clear and actionable plan based on the user's inquiry regarding the future trends of the porn industry. It specifies several relevant components to consider, such as technological advancements, societal attitudes, user demographics, and mental health impacts, which are essential for understanding future developments. However, the report lacks specific findings or insights regarding current trends, as it mainly documents the steps of the plan and the intention to search further rather than providing immediate answers or synthesized information.\n\nOverall, while the framework for exploration is solid, the execution in the form of a report feels incomplete and does not address the user's inquiry directly, as it only states the actions to be taken and not the results of any research conducted. \n\nRating: 5/10" rework_required=True max_retry=3
# Here's the report by the Worker -
#  content='I will execute the plan of action step by step using the Web Search Tool.\n\n### Step 1: Research current trends in the porn industry as of 2023.\n\n### Step 2: Identify technological advancements impacting the industry (e.g., VR, AI, streaming technology).\n\n### Step 3: Analyze regulatory changes and societal attitudes towards adult content.\n\n### Step 4: Examine emerging platforms and content delivery methods (e.g., subscription models, social media influence).\n\n### Step 5: Investigate user demographics and preferences shifts in the pornographic audience.\n\n### Step 6: Explore potential impacts of mental health awareness on consumption patterns.\n\n### Step 7: Forecast future developments based on current data and historical patterns.\n\n### Step 8: Compile findings into a comprehensive report highlighting key future trends.\n\nNow, I will begin the research. \n\n**Executing step 1:** Research current trends in the porn industry as of 2023. ' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 189, 'prompt_tokens': 399, 'total_tokens': 588, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a7b0b5e194', 'id': 'chatcmpl-DkaLi7GzVIMIemcMT1Vw5rKSpyPwu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--3f8be357-f60e-42c3-959a-7332021774b7-0' usage_metadata={'input_tokens': 399, 'output_tokens': 189, 'total_tokens': 588, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# Evaluation of the report
#  - feedback="The report outlines an action plan that effectively addresses the user's inquiry about future trends in the porn industry. The steps are sequential and logical, covering a comprehensive spectrum of relevant factors such as technological advancements, regulatory changes, societal attitudes, and audience demographics. However, the report lacks specific findings or data after step execution, which is necessary to evaluate the trends properly. It does not present any concrete information or results from the research. Overall, while the action plan is good, the execution and presentation of findings are inadequate. \n\nRating: 6/10. It needs substantial content improvement after the steps are executed to provide meaningful insights." rework_required=True max_retry=3
# Here's the report by the Worker -
#  content='1. **Research current trends in the porn industry as of 2023.**  \n   - Searching for the latest trends in the porn industry to gather relevant data.\n\n2. **Identify technological advancements impacting the industry (e.g., VR, AI, streaming technology).**  \n   - Investigating the impact of technological advancements like VR, AI, and streaming services on the porn industry.\n\n3. **Analyze regulatory changes and societal attitudes towards adult content.**  \n   - Looking into recent regulatory changes and shifts in societal attitudes related to adult content.\n\n4. **Examine emerging platforms and content delivery methods (e.g., subscription models, social media influence).**  \n   - Researching emerging platforms and new content delivery methods affecting the industry.\n\n5. **Investigate user demographics and preferences shifts in the pornographic audience.**  \n   - Analyzing demographic shifts and changing preferences in the adult audience.\n\n6. **Explore potential impacts of mental health awareness on consumption patterns.**  \n   - Exploring how increased mental health awareness may influence porn consumption patterns.\n\n7. **Forecast future developments based on current data and historical patterns.**  \n   - Using data collected to forecast future trends in the porn industry.\n\n8. **Compile findings into a comprehensive report highlighting key future trends.**  \n   - Compiling the research findings into a comprehensive report. \n\nNow, I will proceed with these steps. Starting with the first step: researching current trends in the porn industry as of 2023.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 299, 'prompt_tokens': 378, 'total_tokens': 677, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a7b0b5e194', 'id': 'chatcmpl-DkaLo3DRec2wfcQAB09usA7GB9m7E', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--42955216-7bfd-4a5b-9ad5-d0386d3087b2-0' usage_metadata={'input_tokens': 378, 'output_tokens': 299, 'total_tokens': 677, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# Evaluation of the report
#  - feedback="The report successfully follows the action plan, addressing the user's inquiry about the future trends in the porn industry. Each point in the report correlates with the steps identified in the action plan, providing a structured approach to exploring current trends and future developments. However, the report lacks detailed findings or specific examples from the research steps, which are critical for deepening the analysis and delivering a comprehensive overview. For an improved outcome, it should include specific statistics, case studies, or insights that reflect the current landscape and projections for the industry. Overall, it is a well-structured outline, but needs more substantial content to fully satisfy the user's request." rework_required=True max_retry=3
# Here's the report by the Worker -
#  content="I will now proceed with the research based on the provided plan of action to develop a more detailed report on the trends in the porn industry as of 2023, incorporating specific statistics, case studies, and insights.\n\n### 1. Research current trends in the porn industry as of 2023.\nResearching trends in the porn industry reveals a significant shift toward personalization, with viewers increasingly preferring content tailored to their preferences. Additionally, there’s a rising demand for ethical porn, with consumers showing interest in productions that prioritize consent and fair treatment of performers. The industry also continues to face challenges regarding copyright infringement and the protection of intellectual property rights.\n\n### 2. Identify technological advancements impacting the industry (e.g., VR, AI, streaming technology).\nKey technological advancements include the rise of virtual reality (VR) experiences that provide immersive content, transforming the way users interact with adult films. Artificial intelligence (AI) is also becoming prevalent, with tools developing personalized recommendations, chatbots for customer service, and even AI-generated content. Streaming technology remains critical, with a move toward HD and 4K content, enhancing the viewing experience. \n\n### 3. Analyze regulatory changes and societal attitudes towards adult content.\nRegulatory changes are evident, particularly with increasing scrutiny on online adult content. Countries are implementing stricter age verification laws to protect minors, and platforms are adapting their policies accordingly. Societal attitudes continue to evolve, with a notable increase in open discussions around sexuality, leading to a more accepting view of adult content amongst younger demographics.\n\n### 4. Examine emerging platforms and content delivery methods (e.g., subscription models, social media influence).\nEmerging platforms like OnlyFans and private subscription services are reshaping how adult content is monetized and delivered. These platforms allow performers to directly connect with their audiences, creating a more intimate viewing experience. Social media plays a crucial role in promoting content creators and facilitating discussions around adult entertainment.\n\n### 5. Investigate user demographics and preferences shifts in the pornographic audience.\nUser demographics are shifting, with a younger audience becoming predominant. Surveys indicate that viewers aged 18-34 are more likely to engage with free content on smartphones and tablets, compared to older generations who may prefer traditional viewing methods. Additionally, interest in diverse and inclusive content continues to grow, pushing creators to cater to a broader spectrum of sexual orientations and body types.\n\n### 6. Explore potential impacts of mental health awareness on consumption patterns.\nThere is a growing awareness of mental health issues associated with porn consumption, with studies investigating its effects on relationships and personal well-being. This underscores the importance of ethical production and the promotion of healthy consumption patterns. Some individuals are opting for more curated and ethically produced content, emphasizing the industry's responsibility towards consumers’ mental health.\n\n### 7. Forecast future developments based on current data and historical patterns.\nForecasts suggest that the demand for immersive experiences like VR will continue to grow, while AI tools will become more sophisticated in generating content and enhancing user interactivity. Regulation will likely tighten, pushing platforms to adapt more robust age verification systems. Additionally, the ethical production movement is expected to gain traction, influencing the overall landscape of adult content.\n\n### 8. Compile findings into a comprehensive report highlighting key future trends.\nThis report outlines the trends and changes in the porn industry as of 20 ...
# Evaluation of the report
#  - feedback="The report provides a comprehensive overview of the current trends in the porn industry as of 2023. It effectively addresses each section of the action plan proposed by the Planner LLM, including current trends, technological advancements, regulatory changes, and shifts in user demographics. The report is organized logically, presenting information in a clear and concise manner. Additionally, it discusses the impacts of mental health awareness and ethical considerations, which are crucial topics in today’s discourse around adult content. \n\nHowever, the report could benefit from more specific statistics or case studies to further substantiate the claims made, particularly in areas like user demographics and mental health impacts. Providing references to actual studies or reports would enhance the credibility of the analysis. Overall, it meets the user's inquiry effectively but could improve with more concrete data.\n\nRating: 8/10" rework_required=True max_retry=3
# Here's the report by the Worker -
#  content="I'll proceed with the research according to the plan provided and aim to incorporate specific statistics, case studies, and credible references to enhance the report's credibility. \n\n**Step 1: Research current trends in the porn industry as of 2023.**\n\nExecuting search for current trends in the porn industry in 2023." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 417, 'total_tokens': 481, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a7b0b5e194', 'id': 'chatcmpl-DkaMK7IP81L5IXte9hyRHIJ4Ezbxd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--e8914f83-762d-4a8a-96e2-04d755929b36-0' usage_metadata={'input_tokens': 417, 'output_tokens': 64, 'total_tokens': 481, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# Evaluation of the report
#  - feedback="The report provides a brief and somewhat generic introduction to the planned research steps but lacks specifics on findings or insights related to the porn industry's future trends as requested by the user. It outlines a clear plan but does not present any concrete data, statistics, or case studies relevant to current trends or predictions, which are crucial to addressing the user's inquiry comprehensively. To enhance the report's value, it should have included at least a summary of initial findings or examples to illustrate the ongoing research. Overall, while it indicates a structured approach to research, it fails to deliver actionable insights or detailed analysis on the specified topic in its current form." rework_required=True max_retry=3
# Report written successfully.

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>
