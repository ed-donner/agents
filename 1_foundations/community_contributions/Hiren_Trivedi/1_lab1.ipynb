# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY') 

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins AQ.Ab8RN

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite",messages=messages)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='-T-4atyGGfCyjuMPtZTq8Q4', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='An exceptionally promising business area for an **Agentic AI** opportunity is **Procurement and Supply Chain Management (specifically for Mid-Market Manufacturing and E-commerce).**\n\nHere is why this area is ripe for disruption, how agentic AI would work within it, and why the timing is right.\n\n---\n\n### The Business Area: Autonomous Supply Chain & Procurement Operations\n\n#### 1. The Current Pain Point\nWhile Fortune 500 companies have spent millions on custom ERP and supply chain visibility software (like SAP, Oracle, or Coupa), **mid-market companies ($50M–$500M in revenue) still run their supply chains via a chaotic mix of emails, spreadsheets, and manual phone calls.** \n\nWhen a disruption happens (e.g., a key supplier’s shipment is delayed, raw material prices spike, or a sudden surge in demand occurs), human buyers must:\n* Manually check inventory levels across multiple warehouses.\n* Email dozens of alternative suppliers for quotes and lead times.\n* Compare terms, shipping costs, and reliability ratings.\n* Negotiate and execute purchase orders.\n* Update internal stakeholders (finance, production, sales).\n\nThis process takes days or weeks. In modern commerce, that delay leads to stockouts, lost revenue, and inflated costs.\n\n#### 2. The Agentic AI Opportunity\nUnlike traditional automation (which follows rigid "If-This-Then-That" rules) or standard generative AI (which just writes emails), **Agentic AI can reason, plan, use tools, and execute multi-step workflows autonomously.**\n\nAn **Agentic Procurement System** wouldn\'t just suggest a supplier; it would manage the entire lifecycle of a procurement anomaly. \n\n**Example Workflow of the AI Agent:**\n1. **Detects an issue:** The agent monitors inventory and notices that a crucial component for an assembly line will run out in 10 days because the primary supplier is delayed.\n2. **Plans a response:** The agent determines it needs to find an alternative supplier who can deliver within 7 days at a competitive price.\n3. **Uses tools:** The agent accesses public supplier databases, browses verified B2B marketplaces (like ThomasNet or Alibaba), checks historical company data for past supplier performance, and reviews internal budget constraints via the ERP.\n4. **Executes actions:** The agent autonomously drafts and sends Request for Quotes (RFQs) to the top 5 alternative vendors.\n5. **Negotiates and closes:** As vendors reply with varying prices and terms, the agent negotiates within pre-set parameters (e.g., "accept up to a 5% price premium for 5-day delivery") and selects the best option.\n6. **Human-in-the-loop checkpoint:** The agent presents the final, optimal contract to the human procurement manager with a simple button: *"Approve and issue PO."*\n\n#### 3. Why This is Worth Exploring Now\n* **Technology Readiness:** Foundation models now possess the reasoning capabilities required to handle unstructured communication (reading messy supplier emails, parsing PDF invoices) and API integrations.\n* **High Economic Value:** Procurement mistakes are expensive. Saving a mid-market manufacturer from a production shutdown or finding a 10% cheaper raw material source yields an immediate, measurable ROI.\n* **Low Direct Competition (Yet):** Enterprise software is too bloated and slow to move here, and traditional RPA (Robotic Process Automation) is too brittle to handle the unpredictable, conversational nature of supplier management.\n\n#### 4. How to Start (Minimum Viable Product)\nInstead of trying to build an entire autonomous supply chain platform, a startup in this space should **start narrow**:\n* **Pick one niche:** E.g., Autonomous management of shipping exceptions for Shopify Plus brands, or automated indirect procurement (office supplies, IT hardware, MRO parts) for mid-sized hospitals or manufacturers.\n* ...

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = gemini.chat.completions.create(model="gemini-3.5-flash-lite",messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks the truth, False always lies, and Random whether he speaks the truth or lies is completely random. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to one and only one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What is the strategy for the set of three questions that will always determine the identities of the gods?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks the truth, False always lies, and Random whether he speaks the truth or lies is completely random. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to one and only one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What is the strategy for the set of three questions that will always determine the identities of the gods?'}]

# %%
# Ask the model to answer the hard question

response =  gemini.chat.completions.create(model="gemini-3.5-flash-lite",messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# This is famously known as **"The Hardest Logic Puzzle Ever,"** formulated by philosopher George Boolos.
#
# To solve this puzzle, we need to break it down into two main steps:
# 1. **First Question:** Find at least one god who is **definitely NOT Random** (meaning they are either True or False).
# 2. **Second & Third Questions:** Use that identified god to extract the necessary information to figure out everyone's identity.
#
# Here is the complete strategy.
#
# ---
#
# ### Key Preliminary: The "Complex Question" Trick
# Because we don't know what "da" and "ja" mean, we can use a biconditional structure (i.e., "If and only if") to force the gods to give a reliable answer regardless of the language barrier.
#
# Specifically, if you ask a question of the form:
# > *"Would you answer 'da' if and only if [Statement] is true?"*
#
# * If the god is **True** or **False** (a non-Random god), they will answer **"da"** if the statement is true, and **"ja"** if the statement is false.
# * *Exception:* If the god is **Random**, their answer tells you nothing, which is why Question 1 must be designed to avoid relying on Random.
#
# ---
#
# ### The 3-Question Strategy
#
# #### **Question 1: Ask God B**
# > **"Would you answer 'da' if and only if C is Random?"**
#
# Depending on B's answer, you will be able to identify a god who is **definitely NOT Random**.
#
# * **If God B answers "da":**
#   * Either B is True/False and C *is* Random (meaning B is not Random, so **B is safe to use**).
#   * Or B is True/False and C is *not* Random (meaning C is True or False, so **C is safe to use**).
#   * *Action:* If B said "da", your target for Question 2 is **God C**. (If C is Random, then B is not Random. If C is not Random, then C is not Random).
# * **If God B answers "ja":**
#   * By the exact same logic, **God A** is guaranteed to NOT be Random.
#   * *Action:* If B said "ja", your target for Question 2 is **God A**.
#
# *(Note: For the sake of explanation, let's assume the safe god you found using Question 1 is **God C**).*
#
# ---
#
# #### **Question 2: Ask God C (the non-Random god you just found)**
# Now that you know God C is either True or False (not Random), ask them about **God B**:
#
# > **"Would you answer 'da' if and only if B is Random?"**
#
# * **If C answers "da":** This means the statement "B is Random" is True. Therefore, **B is Random**.
#   * Since you now know B is Random, and you know C is True/False, the remaining god (**A**) must be the last remaining identity.
# * **If C answers "ja":** This means the statement "B is Random" is False. Therefore, **B is NOT Random**.
#
# ---
#
# #### **Question 3: Ask God C (the same non-Random god)**
# Now that you know B's status (from Question 2), you can determine whether C is True or False. Ask God C:
#
# > **"Would you answer 'da' if and only if I am a man?"** *(or any other obviously true statement)*
#
# * Because C is a non-Random god speaking to a true statement, C's answer will reveal whether C is **True** (if they answer "da" for yes) or **False** (if they answer "ja" for no)—which simultaneously decodes what "da" and "ja" mean!
#
# ---
#
# ### Summary of Identities
# Once you have executed these three questions:
# 1. You will know who **Random** is (eliminated via Q1).
# 2. You will know who **True** and **False** are (differentiated via Q2 and Q3).
#
# Thus, the identities of A, B, and C are completely solved!

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# This is famously known as **"The Hardest Logic Puzzle Ever,"** formulated by philosopher George Boolos.
#
# To solve this puzzle, we need to break it down into two main steps:
# 1. **First Question:** Find at least one god who is **definitely NOT Random** (meaning they are either True or False).
# 2. **Second & Third Questions:** Use that identified god to extract the necessary information to figure out everyone's identity.
#
# Here is the complete strategy.
#
# ---
#
# ### Key Preliminary: The "Complex Question" Trick
# Because we don't know what "da" and "ja" mean, we can use a biconditional structure (i.e., "If and only if") to force the gods to give a reliable answer regardless of the language barrier.
#
# Specifically, if you ask a question of the form:
# > *"Would you answer 'da' if and only if [Statement] is true?"*
#
# * If the god is **True** or **False** (a non-Random god), they will answer **"da"** if the statement is true, and **"ja"** if the statement is false.
# * *Exception:* If the god is **Random**, their answer tells you nothing, which is why Question 1 must be designed to avoid relying on Random.
#
# ---
#
# ### The 3-Question Strategy
#
# #### **Question 1: Ask God B**
# > **"Would you answer 'da' if and only if C is Random?"**
#
# Depending on B's answer, you will be able to identify a god who is **definitely NOT Random**.
#
# * **If God B answers "da":**
#   * Either B is True/False and C *is* Random (meaning B is not Random, so **B is safe to use**).
#   * Or B is True/False and C is *not* Random (meaning C is True or False, so **C is safe to use**).
#   * *Action:* If B said "da", your target for Question 2 is **God C**. (If C is Random, then B is not Random. If C is not Random, then C is not Random).
# * **If God B answers "ja":**
#   * By the exact same logic, **God A** is guaranteed to NOT be Random.
#   * *Action:* If B said "ja", your target for Question 2 is **God A**.
#
# *(Note: For the sake of explanation, let's assume the safe god you found using Question 1 is **God C**).*
#
# ---
#
# #### **Question 2: Ask God C (the non-Random god you just found)**
# Now that you know God C is either True or False (not Random), ask them about **God B**:
#
# > **"Would you answer 'da' if and only if B is Random?"**
#
# * **If C answers "da":** This means the statement "B is Random" is True. Therefore, **B is Random**.
#   * Since you now know B is Random, and you know C is True/False, the remaining god (**A**) must be the last remaining identity.
# * **If C answers "ja":** This means the statement "B is Random" is False. Therefore, **B is NOT Random**.
#
# ---
#
# #### **Question 3: Ask God C (the same non-Random god)**
# Now that you know B's status (from Question 2), you can determine whether C is True or False. Ask God C:
#
# > **"Would you answer 'da' if and only if I am a man?"** *(or any other obviously true statement)*
#
# * Because C is a non-Random god speaking to a true statement, C's answer will reveal whether C is **True** (if they answer "da" for yes) or **False** (if they answer "ja" for no)—which simultaneously decodes what "da" and "ja" mean!
#
# ---
#
# ### Summary of Identities
# Once you have executed these three questions:
# 1. You will know who **Random** is (eliminated via Q1).
# 2. You will know who **True** and **False** are (differentiated via Q2 and Q3).
#
# Thus, the identities of A, B, and C are completely solved!

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks the truth, False always lies, and Random whether he speaks the truth or lies is completely random. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to one and only one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What is the strategy for the set of three questions that will always determine the identities of the gods?
#
# And here is a possible answer that might be correct or incorrect:
# This is famously known as **"The Hardest Logic Puzzle Ever,"** formulated by philosopher George Boolos.
#
# To solve this puzzle, we need to break it down into two main steps:
# 1. **First Question:** Find at least one god who is **definitely NOT Random** (meaning they are either True or False).
# 2. **Second & Third Questions:** Use that identified god to extract the necessary information to figure out everyone's identity.
#
# Here is the complete strategy.
#
# ---
#
# ### Key Preliminary: The "Complex Question" Trick
# Because we don't know what "da" and "ja" mean, we can use a biconditional structure (i.e., "If and only if") to force the gods to give a reliable answer regardless of the language barrier.
#
# Specifically, if you ask a question of the form:
# > *"Would you answer 'da' if and only if [Statement] is true?"*
#
# * If the god is **True** or **False** (a non-Random god), they will answer **"da"** if the statement is true, and **"ja"** if the statement is false.
# * *Exception:* If the god is **Random**, their answer tells you nothing, which is why Question 1 must be designed to avoid relying on Random.
#
# ---
#
# ### The 3-Question Strategy
#
# #### **Question 1: Ask God B**
# > **"Would you answer 'da' if and only if C is Random?"**
#
# Depending on B's answer, you will be able to identify a god who is **definitely NOT Random**.
#
# * **If God B answers "da":**
#   * Either B is True/False and C *is* Random (meaning B is not Random, so **B is safe to use**).
#   * Or B is True/False and C is *not* Random (meaning C is True or False, so **C is safe to use**).
#   * *Action:* If B said "da", your target for Question 2 is **God C**. (If C is Random, then B is not Random. If C is not Random, then C is not Random).
# * **If God B answers "ja":**
#   * By the exact same logic, **God A** is guaranteed to NOT be Random.
#   * *Action:* If B said "ja", your target for Question 2 is **God A**.
#
# *(Note: For the sake of explanation, let's assume the safe god you found using Question 1 is **God C**).*
#
# ---
#
# #### **Question 2: Ask God C (the non-Random god you just found)**
# Now that you know God C is either True or False (not Random), ask them about **God B**:
#
# > **"Would you answer 'da' if and only if B is Random?"**
#
# * **If C answers "da":** This means the statement "B is Random" is True. Therefore, **B is Random**.
#   * Since you now know B is Random, and you know C is True/False, the remaining god (**A**) must be the last remaining identity.
# * **If C answers "ja":** This means the statement "B is Random" is False. Therefore, **B is NOT Random**.
#
# ---
#
# #### **Question 3: Ask God C (the same non-Random god)**
# Now that you know B's status (from Question 2), you can determine whether C is True or False. Ask God C:
#
# > **"Would you answer 'da' if and only if I am a man?"** *(or any other obviously true statement)*
#
# * Because C is a non-Random god speaking to a true statement, C's answer will reveal whether C is **True** (if they answer "da" for yes) or **False** (if they answer "ja" for no)—which simultaneously decodes what "da" and "ja" mean!
#
# ---
#
# ### Summary of Identities
# Once you have executed these three questions:
# 1. You will know who **Random** is (eliminated via Q1).
# 2. You will know who **True** and **False** are (differentiated via Q2 and Q3).
#
# Thus, the identities of A, B, and C are completely solved!
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite",messages=messages)
print(response.choices[0].message.content)
# Out:
# The provided answer is **incorrect**. While it correctly identifies the puzzle (George Boolos's "Hardest Logic Puzzle Ever") and correctly explains the "complex question trick" (the biconditional structure used to bypass the "da/ja" language barrier), the actual step-by-step logic and the specific questions outlined in the strategy contain significant errors and do not successfully solve the puzzle.
#
# Here is a breakdown of why the provided answer is incorrect:
#
# ### 1. Flawed Logic in Question 1
# The answer suggests asking God B: *"Would you answer 'da' if and only if C is Random?"* and claims that if B answers "da", then God C is safe to use (meaning C is definitely not Random), and if B answers "ja", God A is safe to use.
#
# This is logically unsound. If B is Random, B's answer is completely meaningless—B could say "da" or "ja" by pure chance, which completely invalidates the deduction that A or C is safe. A successful solution to Question 1 must account for the possibility that the god being asked is Random, usually by phrasing the question so that if the god *is* Random, the answer doesn't break the logic, or by directing the question in a way that bypasses Random altogether (e.g., finding a god who is *definitely not* Random by targeting a specific condition).
#
# ### 2. Flawed Execution of Questions 2 and 3
# * **In Question 2**, the answer has you ask God C: *"Would you answer 'da' if and only if B is Random?"* But the actual classic solution requires using the first question to find a god who is *definitely not Random*, and then using that specific god to ask about the *status of True vs. False* (e.g., asking whether another god is True or False), not asking if someone is Random.
# * **In Question 3**, the answer suggests asking a completely unrelated true statement ("Would you answer 'da' if and only if I am a man?"). In the actual solution, by the time you reach the third question, you already know the identity of the non-Random god you are talking to; the third question is used to distinguish between True and False for the *remaining* unknown gods based on the answers gathered so far.
#
# ---
#
# ### How the Puzzle is Actually Solved (Brief Overview)
# The universally accepted solution by George Boolos works as follows:
# 1. **Question 1:** Ask God B: *"If I were to ask you whether A is Random, would you say 'da'?"* (This clever nesting forces either God A or God C to be **definitely not Random**).
# 2. **Question 2:** Turn to the god identified in Step 1 as *definitely not Random* and ask them a question about another god (e.g., asking if that god is False or True).
# 3. **Question 3:** Ask the same non-Random god a question about *themselves* (or another structural comparison) to pin down all remaining identities and decode "da/ja".
#
# Because the provided answer's step-by-step logic breaks down and misallocates the purpose of the questions, the evaluation is **incorrect**.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "pick a business area that might be worth exploring for an Agentic AI opportunity"}]

# Then make the first call:

response = gemini.chat.completions.create(model="gemini-3.5-flash-lite",messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content



# And repeat! In the next message, include the business area within the message

# %%
message = f"""
Here is that industry:
{business_area}

Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.
 
"""

display(Markdown(message))
# Out:
# Here is that industry:
# An exceptionally strong business area to explore for an Agentic AI opportunity is **Global Supply Chain Risk Management and Logistics Exception Handling**.
#
# Here is a breakdown of why this area is ripe for disruption, what an agentic solution would look like, and why traditional software falls short.
#
# ---
#
# ### 1. The Problem: The Fragility of Modern Supply Chains
# Modern supply chains are hyper-complex, global, and brittle. When something goes wrong—a cargo ship gets stuck in a canal, a key supplier has a factory fire, a port goes on strike, or customs holds a container—it creates a massive ripple effect.
#
# Currently, resolving these "exceptions" is painfully manual, reactive, and siloed:
# *   **Data is fragmented:** ERP systems, IoT sensor data, weather feeds, news alerts, and supplier emails don't talk to each other seamlessly.
# *   **High cognitive load:** Human logistics managers spend hours digging through data, calling suppliers, calculating costs, and getting approvals.
# *   **Lag time:** By the time a human identifies a bottleneck and implements a workaround, days have passed and thousands (or millions) of dollars have been lost.
#
# ### 2. The Agentic AI Opportunity: Autonomous Supply Chain "Co-Pilots" to Managers
# Unlike traditional predictive analytics (which just tells you *that* a delay will happen), an **Agentic AI system** can actually *do something about it*.
#
# You could build a multi-agent system where different AI agents have specific roles:
# *   **The Sentinel Agent:** Monitors weather, geopolitical news, IoT data, and ERP schedules 24/7 to predict disruptions before they impact the business.
# *   **The Negotiator/Procurement Agent:** If a primary supplier fails, this agent autonomously searches alternative supplier databases, evaluates pricing and lead times, negotiates terms based on company policy, and drafts purchase orders.
# *   **The Logistics Agent:** Reroutes shipments in real-time, books alternative freight capacity (air, rail, ocean), and updates customs documentation automatically.
# *   **The Communication Agent:** Proactively updates internal stakeholders (sales, finance, customer success) and external customers with realistic ETA adjustments and impact assessments.
#
# ### 3. Why Agentic AI? (Why Now?)
# *   **Multi-Step Reasoning:** Supply chain fixes aren't single-prompt answers. They require multi-step workflows: *Detect delay $\rightarrow$ Calculate financial impact $\rightarrow$ Find 3 alternatives $\rightarrow$ Check budget approval limits $\rightarrow$ Execute.* Agentic loops handle this naturally.
# *   **Tool Use:** These agents can natively use APIs (FedEx, Flexport, SAP, Salesforce), browse the web for live freight rates, and interact with enterprise software through UI or API integration.
# *   **Human-in-the-Loop Governance:** High-stakes decisions (like spending $50k on emergency air freight) can require a simple "Approve/Deny" click from a human manager, while low-stakes decisions happen autonomously.
#
# ### 4. Business Model & Monetization
# *   **SaaS + Value-Based Pricing:** Charge a base subscription fee for the platform, plus a percentage of the cost savings achieved by avoiding delays, demurrage fees, and stockouts.
# *   **Enterprise Stickiness:** Once an agentic workflow is deeply integrated into a company's ERP and daily logistics operations, churn becomes virtually non-existent.
#
# ### Alternative Honorable Mentions
# If supply chain isn't your domain, two other high-potential areas for Agentic AI are:
# 1.  **Automated Medical Billing & Insurance Denials:** Agents that read medical records, cross-reference insurance policies, write appeals for denied claims, and resubmit them.
# 2.  **Enterprise IT & Cybersecurity Incident Response:** Agents that detect a network anomaly, isolate the affected server, read threat intelligence reports, patch the vulnerability, and write the post-mortem report.
#
# Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite",messages=messages)
pain_point = response.choices[0].message.content
display(Markdown(pain_point))
# Out:
# An extremely high-potential business area for an Agentic AI opportunity is **Automated Supply Chain Risk Management and Procurement Negotiation**.
#
# Here is why this area is ripe for disruption, what an agentic solution would look like, and why traditional software falls short.
#
# ---
#
# ### The Business Problem
# Modern supply chains are brittle. Global enterprises constantly face disruptions—such as port congestion, extreme weather, geopolitical tariffs, bankruptcy of tier-2 suppliers, or sudden surges in raw material prices.
#
# Currently, supply chain management is reactive. Humans monitor dashboards, read news alerts, scramble to find alternative vendors, evaluate their credibility, and manually negotiate pricing and terms via endless email chains. This process is slow, expensive, and often results in production bottlenecks or inflated costs.
#
# ### The Agentic AI Opportunity
# Unlike traditional software (which just alerts a human to a problem) or standard LLMs (which just summarize text), an **Agentic AI system** can perceive a problem, reason through options, formulate a multi-step plan, and **take autonomous action** across external systems with minimal human oversight.
#
# #### What the Agentic Workflow Looks Like:
# 1. **Perception & Monitoring:** An agent continuously monitors global news, weather feeds, shipping APIs, and internal ERP systems (like SAP).
# 2. **Reasoning & Planning:** If a typhoon shuts down a major port in Taiwan where a critical microchip is manufactured, the agent assesses the impact: *"We have 14 days of inventory left; factory line B will halt on October 12."* It then generates a recovery plan.
# 3. **Tool Use & Execution:**
#    * The agent queries a database of pre-vetted secondary suppliers.
#    * It drafts and sends Requests for Quotes (RFQs) to three alternative suppliers via email or supplier portals.
#    * It negotiates pricing and delivery timelines within pre-approved budgetary and SLA guardrails.
# 4. **Human-in-the-Loop Approval:** Once it secures the best deal, it presents the contract to a procurement manager with a simple prompt: *"Approve contract with Supplier X to avoid stockout. Estimated cost premium: 4%."*
# 5. **Action:** Upon approval, it updates the ERP, generates purchase orders, and logs the transaction.
#
# ---
#
# ### Why Now? (The Technological Catalyst)
# * **API Maturity:** Most enterprise software (ERP, CRM, communication tools) now has robust APIs that agents can use to read/write data.
# * **Reasoning Capabilities:** Models like GPT-4o or Claude 3.5 Sonnet possess the complex reasoning required to handle nuanced vendor negotiations and logistical trade-offs.
# * **Cost Efficiency:** The cost of running multi-agent loops has dropped significantly, making autonomous business workflows economically viable.
#
# ### Why This is a Great Venture Opportunity
# * **High ROI:** Preventing a single supply chain shutdown can save an enterprise millions of dollars. Companies will pay high SaaS or transactional fees for this capability.
# * **Clear Value Metric:** Success is easily measurable (e.g., hours saved in procurement, lower cost of goods sold, zero stockout days).
# * **Expansion Path:** Once you solve procurement and risk, the agentic platform can expand into logistics routing, warehouse automation, and inventory forecasting.
#
# ### Potential Moat (Defensibility)
# The true moat in this space isn't the base AI model—it is the **workflow orchestration layer** and the **proprietary vendor graph** (knowing who supplies what, their reliability scores, and historical pricing data). Training agents on industry-specific procurement data creates a powerful network effect.

# %%
message = f"""
Industry:
{business_area}
Pain point:
{pain_point}
Propose an Agentic AI solution for this pain point.
Describe: what the agent does, which tools it would use,
how it works step by step, and what a human still decides.
"""

display(Markdown(message))
# Out:
# Industry:
# An exceptionally strong business area to explore for an Agentic AI opportunity is **Global Supply Chain Risk Management and Logistics Exception Handling**.
#
# Here is a breakdown of why this area is ripe for disruption, what an agentic solution would look like, and why traditional software falls short.
#
# ---
#
# ### 1. The Problem: The Fragility of Modern Supply Chains
# Modern supply chains are hyper-complex, global, and brittle. When something goes wrong—a cargo ship gets stuck in a canal, a key supplier has a factory fire, a port goes on strike, or customs holds a container—it creates a massive ripple effect.
#
# Currently, resolving these "exceptions" is painfully manual, reactive, and siloed:
# *   **Data is fragmented:** ERP systems, IoT sensor data, weather feeds, news alerts, and supplier emails don't talk to each other seamlessly.
# *   **High cognitive load:** Human logistics managers spend hours digging through data, calling suppliers, calculating costs, and getting approvals.
# *   **Lag time:** By the time a human identifies a bottleneck and implements a workaround, days have passed and thousands (or millions) of dollars have been lost.
#
# ### 2. The Agentic AI Opportunity: Autonomous Supply Chain "Co-Pilots" to Managers
# Unlike traditional predictive analytics (which just tells you *that* a delay will happen), an **Agentic AI system** can actually *do something about it*.
#
# You could build a multi-agent system where different AI agents have specific roles:
# *   **The Sentinel Agent:** Monitors weather, geopolitical news, IoT data, and ERP schedules 24/7 to predict disruptions before they impact the business.
# *   **The Negotiator/Procurement Agent:** If a primary supplier fails, this agent autonomously searches alternative supplier databases, evaluates pricing and lead times, negotiates terms based on company policy, and drafts purchase orders.
# *   **The Logistics Agent:** Reroutes shipments in real-time, books alternative freight capacity (air, rail, ocean), and updates customs documentation automatically.
# *   **The Communication Agent:** Proactively updates internal stakeholders (sales, finance, customer success) and external customers with realistic ETA adjustments and impact assessments.
#
# ### 3. Why Agentic AI? (Why Now?)
# *   **Multi-Step Reasoning:** Supply chain fixes aren't single-prompt answers. They require multi-step workflows: *Detect delay $\rightarrow$ Calculate financial impact $\rightarrow$ Find 3 alternatives $\rightarrow$ Check budget approval limits $\rightarrow$ Execute.* Agentic loops handle this naturally.
# *   **Tool Use:** These agents can natively use APIs (FedEx, Flexport, SAP, Salesforce), browse the web for live freight rates, and interact with enterprise software through UI or API integration.
# *   **Human-in-the-Loop Governance:** High-stakes decisions (like spending $50k on emergency air freight) can require a simple "Approve/Deny" click from a human manager, while low-stakes decisions happen autonomously.
#
# ### 4. Business Model & Monetization
# *   **SaaS + Value-Based Pricing:** Charge a base subscription fee for the platform, plus a percentage of the cost savings achieved by avoiding delays, demurrage fees, and stockouts.
# *   **Enterprise Stickiness:** Once an agentic workflow is deeply integrated into a company's ERP and daily logistics operations, churn becomes virtually non-existent.
#
# ### Alternative Honorable Mentions
# If supply chain isn't your domain, two other high-potential areas for Agentic AI are:
# 1.  **Automated Medical Billing & Insurance Denials:** Agents that read medical records, cross-reference insurance policies, write appeals for denied claims, and resubmit them.
# 2.  **Enterprise IT & Cybersecurity Incident Response:** Agents that detect a network anomaly, isolate the affected server, read threat intelligence reports, patch the vulnerability, and write the post-mortem report.
# Pain point:
# An exceptionally high-potential area to explore for Agentic AI is **Supply Chain Resilience and Dynamic Procurement**.
#
# While customer service and software coding are currently flooded with AI agents, supply chain management—specifically the headache of sudden disruptions—remains heavily manual, siloed, and reactive.
#
# Here is why this area is ripe for Agentic AI, what the agents would actually do, and why the timing is right.
#
# ---
#
# ### The Problem Space
# Global supply chains are constantly battered by geopolitical tensions, extreme weather, port strikes, and supplier bankruptcies. Today, when a disruption happens (e.g., a key component factory burns down), human teams spend days or weeks:
# 1. Realizing the impact.
# 2. Sifting through databases to find alternative suppliers.
# 3. Vetting them for compliance, quality, and financial health.
# 4. Negotiating contracts and rerouting logistics.
#
# By the time humans react, revenue has already been lost.
#
# ### The Agentic AI Opportunity (Multi-Agent System)
# Unlike traditional software that just alerts humans to a problem ("Alert: Supplier X is delayed"), an **Agentic AI system** can be deployed to autonomously investigate, simulate, and execute solutions within human-defined guardrails.
#
# You could build a cooperative network of specialized agents:
#
# 1. **The Sentinel Agent:** Continuously monitors news, weather, IoT sensor data, and customs databases to predict disruptions before they hit the company.
# 2. **The Impact Analyst Agent:** Instantly calculates which specific products, revenue streams, and customer contracts are affected by the disruption.
# 3. **The Sourcing & Vetting Agent:** Scans global supplier networks, checks compliance, assesses carbon footprints, and runs financial health checks on potential new vendors.
# 4. **The Negotiation & Procurement Agent:** Reaches out to alternative suppliers via API or email, negotiates pricing and delivery terms based on predefined company budgets, and drafts contracts.
# 5. **The Logistics Orchestrator Agent:** Adjusts shipping routes, books freight, and updates warehouse inventory systems automatically.
#
# ### Why This is Worth Exploring Now
# * **High ROI:** Supply chain failures cost enterprises billions annually. A solution that reduces downtime from weeks to hours has massive, easily quantifiable value.
# * **API Maturity:** Modern enterprise resource planning (ERP) systems (SAP, Oracle) and logistics platforms (Flexport, project44) now have robust APIs, making it feasible for agents to read and write data across systems.
# * **The "Human-in-the-Loop" Sweet Spot:** Enterprises won't let AI buy millions of dollars of goods completely autonomously yet. This makes it a perfect use case for **semi-autonomous agents** that do 95% of the legwork (research, negotiation, drafting) and present a finalized "one-click approve" recommendation to a human manager.
#
# ### Potential Monetization
# * **SaaS + Transaction Fee:** A subscription model for the monitoring platform, plus a percentage fee on transactions or cost-savings realized when agents successfully reroute and save a supply chain.
# Propose an Agentic AI solution for this pain point.
# Describe: what the agent does, which tools it would use,
# how it works step by step, and what a human still decides.

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite",messages=messages)
industry_solution = response.choices[0].message.content
display(Markdown(industry_solution))
# Out:
# An extremely high-potential business area for an **Agentic AI** opportunity is:
#
# ### **Automated B2B Procurement and Supply Chain Resilience**
#
# #### **The Problem**
# Enterprise procurement (buying raw materials, software, office supplies, logistics services) is notoriously manual, fragmented, and reactive.
# * **The pain:** When a supplier fails (e.g., a factory shuts down, a shipping route is blocked, or a software vendor raises prices), human procurement teams scramble. They spend weeks reading contracts, searching for alternative vendors, requesting quotes, vetting compliance, and negotiating.
# * **The stakes:** Supply chain disruptions cost businesses billions annually. Current enterprise software (like SAP, Coupa, or Oracle) is great at *recording* transactions, but terrible at *reasoning* and *taking action* when things go wrong.
#
# #### **The Agentic AI Opportunity**
# Unlike traditional software that just displays dashboards and alerts, an **Agentic AI Procurement System** can act autonomously with human-in-the-loop oversight.
#
# You could build an ecosystem of specialized AI agents that collaborate to manage the entire supply chain lifecycle:
#
# 1. **The Monitoring Agent:** Continuously scans global news, weather, customs data, and financial health reports of current suppliers to predict disruptions *before* they happen.
# 2. **The Sourcing Agent:** If a disruption is predicted, this agent autonomously searches global databases, reads supplier catalogs, and identifies the top 3 viable alternative vendors based on price, quality, and carbon footprint.
# 3. **The Negotiation Agent:** Reaches out to the new vendors via email or API, negotiates initial terms and volume discounts based on the company's historical buying behavior, and drafts a preliminary contract.
# 4. **The Compliance & Legal Agent:** Reviews the vendor’s contract against company policies, GDPR, and local regulations, flagging hidden liabilities for human sign-off.
# 5. **The Execution Agent:** Once approved by a human, updates the ERP system, issues the purchase order, and coordinates logistics.
#
# #### **Why Now? (The Technology Convergence)**
# * **Advanced Reasoning (LLMs):** Modern models can actually read messy supplier contracts, understand nuanced pricing terms, and converse naturally via email.
# * **Tool Use & APIs:** Agents can now securely use browsers, execute Python code, and interact with enterprise software via APIs.
# * **Multi-Agent Frameworks:** Tools like AutoGen, LangGraph, and CrewAI make it feasible to orchestrate multiple agents with different "personas" (e.g., a paranoid risk-assessment agent working alongside an aggressive cost-cutting agent).
#
# #### **Monetization & Go-to-Market**
# * **SaaS + Take Rate:** Charge a base subscription fee for the platform, plus a percentage of the savings generated or a fee per automated transaction.
# * **Initial Niche:** Start by targeting mid-market manufacturing or e-commerce companies that have complex supply chains but lack the massive procurement departments of Fortune 500 companies.
