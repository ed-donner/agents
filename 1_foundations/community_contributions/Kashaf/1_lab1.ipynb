# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# Fun fact: Octopuses have three hearts—two pump blood to the gills, and one pumps it to the rest of the body. Also, when they swim, their main heart can briefly stop, which is why they often prefer crawling over swimming.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# A room contains 12 identical-looking coins, one of which is either heavier or lighter than the others, but you do not know which. Using a balance scale exactly three times, determine a strategy that will always identify the odd coin and whether it is heavier or lighter.

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'A room contains 12 identical-looking coins, one of which is either heavier or lighter than the others, but you do not know which. Using a balance scale exactly three times, determine a strategy that will always identify the odd coin and whether it is heavier or lighter.'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# Here is a standard 12-coin / 3-weighing strategy.
# Label the coins **1 through 12**.
#
# ## Weighing 1
# Weigh:
#
# - **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# There are three cases.
#
# ---
#
# ## Case 1: First weighing balances
# Then coins **1–8 are normal**, so the odd coin is among **9, 10, 11, 12**.
#
# ### Weighing 2
# Weigh **9, 10, 11** vs **1, 2, 3** (known normal coins).
#
# - If it balances, then **12 is odd**.
#   - Weighing 3: **12 vs 1**
#     - If 12 is heavier, it’s heavier.
#     - If 12 is lighter, it’s lighter.
#
# - If left side is heavier, then one of **9, 10, 11** is heavy.
#   - Weighing 3: weigh **9 vs 10**
#     - If one is heavier, that coin is the odd heavy coin.
#     - If they balance, then **11 is heavy**.
#
# - If left side is lighter, then one of **9, 10, 11** is light.
#   - Weighing 3: weigh **9 vs 10**
#     - If one is lighter, that coin is the odd light coin.
#     - If they balance, then **11 is light**.
#
# ---
#
# ## Case 2: First weighing is left heavier
# Then either:
#
# - one of **1, 2, 3, 4** is **heavy**, or
# - one of **5, 6, 7, 8** is **light**.
#
# Now we use:
#
# ### Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9** (coin 9 is known normal if case 1 happened; but here we need a normal coin. Since we don’t yet know one, instead use one of the coins from the opposite side carefully designed. A cleaner standard setup is below.)
#
# Let me give a fully correct decision tree that works from the start without needing a previously known normal coin:
#
# ---
#
# # Complete correct strategy
#
# ## Weighing 1
# Weigh **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# ### If it balances:
# Use the Case 1 strategy above.
#
# ### If left side is heavier:
# Then the odd coin is either:
# - **1, 2, 3, 4** and it is **heavy**, or
# - **5, 6, 7, 8** and it is **light**.
#
# Now do:
#
# ## Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9**
# Here, coin **9** is not yet known normal, so this still isn’t ideal unless we reserve a normal coin from the first weighing. To avoid this issue, use the standard method below instead.
#
# ---
#
# # Standard 12-coin solution with guaranteed logic
#
# Label coins **1–12**.
#
# ## Weighing 1
# **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# Let the unweighed coins **9, 10, 11, 12** be the reserve set.
#
# ---
#
# ## If weighing 1 balances
# Then odd coin is among **9–12**.
#
# ### Weighing 2
# **9, 10, 11** vs **1, 2, 3**
#
# - If balance: **12** is odd
#   - Weighing 3: **12 vs 1**
# - If left heavier: one of **9,10,11** is heavy
#   - Weighing 3: **9 vs 10**
# - If left lighter: one of **9,10,11** is light
#   - Weighing 3: **9 vs 10**
#
# ---
#
# ## If weighing 1: left side heavier
# Then the possibilities are:
#
# - **1, 2, 3, 4** is heavy, or
# - **5, 6, 7, 8** is light
#
# ### Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9**
#
# Now **9 is known normal only if weighing 1 balanced**, which it didn’t. So instead this branch is handled by a proper pre-planned table. Here is the correct concise solution table:
#
# ---
#
# # Fully correct three-weighing strategy
#
# Use this classic arrangement:
#
# ## Weighing 1
# **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# ---
#
# ## If balance
# Odd coin is among **9–12**.
#
# - **Weighing 2:** 9,10,11 vs 1,2,3
#   - balance → 12 odd
#   - left heavy → 9,10,11 heavy
#   - left light → 9,10,11 light
#
# - **Weighing 3:** identify which of the three using 9 vs 10 as above
#
# ---
#
# ## If left side heavier
# Possible sets:
# - heavy: 1,2,3,4
# - light: 5,6,7,8
#
# ### Weighing 2
# **1, 2, 5** vs **3, 6, 9**
# and use coin 9 as a known normal? Not available in this branch, so this version is invalid.
#
# ---
#
# I’ll give the actual standard working tree from memory:
#
# ## Weighing 1
# 1,2,3,4 vs 5,6,7,8
#
# ## Weighing 2
# 1,2,5,6 vs 3,4,9,10
#
# ## Weighing 3
# 1,3,5,7 vs 2,4,9,11
#
# From the pattern of the three outcomes, each coin and each heavy/light status corresponds uniquely to one outcome sequence. This is the classic “ternary code” solution.
#
# If you’d like, I can provide the full outcome table for all 12 coins, or a simpler decision-tree version.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Here is a standard 12-coin / 3-weighing strategy.
# Label the coins **1 through 12**.
#
# ## Weighing 1
# Weigh:
#
# - **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# There are three cases.
#
# ---
#
# ## Case 1: First weighing balances
# Then coins **1–8 are normal**, so the odd coin is among **9, 10, 11, 12**.
#
# ### Weighing 2
# Weigh **9, 10, 11** vs **1, 2, 3** (known normal coins).
#
# - If it balances, then **12 is odd**.
#   - Weighing 3: **12 vs 1**
#     - If 12 is heavier, it’s heavier.
#     - If 12 is lighter, it’s lighter.
#
# - If left side is heavier, then one of **9, 10, 11** is heavy.
#   - Weighing 3: weigh **9 vs 10**
#     - If one is heavier, that coin is the odd heavy coin.
#     - If they balance, then **11 is heavy**.
#
# - If left side is lighter, then one of **9, 10, 11** is light.
#   - Weighing 3: weigh **9 vs 10**
#     - If one is lighter, that coin is the odd light coin.
#     - If they balance, then **11 is light**.
#
# ---
#
# ## Case 2: First weighing is left heavier
# Then either:
#
# - one of **1, 2, 3, 4** is **heavy**, or
# - one of **5, 6, 7, 8** is **light**.
#
# Now we use:
#
# ### Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9** (coin 9 is known normal if case 1 happened; but here we need a normal coin. Since we don’t yet know one, instead use one of the coins from the opposite side carefully designed. A cleaner standard setup is below.)
#
# Let me give a fully correct decision tree that works from the start without needing a previously known normal coin:
#
# ---
#
# # Complete correct strategy
#
# ## Weighing 1
# Weigh **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# ### If it balances:
# Use the Case 1 strategy above.
#
# ### If left side is heavier:
# Then the odd coin is either:
# - **1, 2, 3, 4** and it is **heavy**, or
# - **5, 6, 7, 8** and it is **light**.
#
# Now do:
#
# ## Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9**
# Here, coin **9** is not yet known normal, so this still isn’t ideal unless we reserve a normal coin from the first weighing. To avoid this issue, use the standard method below instead.
#
# ---
#
# # Standard 12-coin solution with guaranteed logic
#
# Label coins **1–12**.
#
# ## Weighing 1
# **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# Let the unweighed coins **9, 10, 11, 12** be the reserve set.
#
# ---
#
# ## If weighing 1 balances
# Then odd coin is among **9–12**.
#
# ### Weighing 2
# **9, 10, 11** vs **1, 2, 3**
#
# - If balance: **12** is odd
#   - Weighing 3: **12 vs 1**
# - If left heavier: one of **9,10,11** is heavy
#   - Weighing 3: **9 vs 10**
# - If left lighter: one of **9,10,11** is light
#   - Weighing 3: **9 vs 10**
#
# ---
#
# ## If weighing 1: left side heavier
# Then the possibilities are:
#
# - **1, 2, 3, 4** is heavy, or
# - **5, 6, 7, 8** is light
#
# ### Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9**
#
# Now **9 is known normal only if weighing 1 balanced**, which it didn’t. So instead this branch is handled by a proper pre-planned table. Here is the correct concise solution table:
#
# ---
#
# # Fully correct three-weighing strategy
#
# Use this classic arrangement:
#
# ## Weighing 1
# **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# ---
#
# ## If balance
# Odd coin is among **9–12**.
#
# - **Weighing 2:** 9,10,11 vs 1,2,3
#   - balance → 12 odd
#   - left heavy → 9,10,11 heavy
#   - left light → 9,10,11 light
#
# - **Weighing 3:** identify which of the three using 9 vs 10 as above
#
# ---
#
# ## If left side heavier
# Possible sets:
# - heavy: 1,2,3,4
# - light: 5,6,7,8
#
# ### Weighing 2
# **1, 2, 5** vs **3, 6, 9**
# and use coin 9 as a known normal? Not available in this branch, so this version is invalid.
#
# ---
#
# I’ll give the actual standard working tree from memory:
#
# ## Weighing 1
# 1,2,3,4 vs 5,6,7,8
#
# ## Weighing 2
# 1,2,5,6 vs 3,4,9,10
#
# ## Weighing 3
# 1,3,5,7 vs 2,4,9,11
#
# From the pattern of the three outcomes, each coin and each heavy/light status corresponds uniquely to one outcome sequence. This is the classic “ternary code” solution.
#
# If you’d like, I can provide the full outcome table for all 12 coins, or a simpler decision-tree version.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A room contains 12 identical-looking coins, one of which is either heavier or lighter than the others, but you do not know which. Using a balance scale exactly three times, determine a strategy that will always identify the odd coin and whether it is heavier or lighter.
#
# And here is a possible answer that might be correct or incorrect:
# Here is a standard 12-coin / 3-weighing strategy.
# Label the coins **1 through 12**.
#
# ## Weighing 1
# Weigh:
#
# - **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# There are three cases.
#
# ---
#
# ## Case 1: First weighing balances
# Then coins **1–8 are normal**, so the odd coin is among **9, 10, 11, 12**.
#
# ### Weighing 2
# Weigh **9, 10, 11** vs **1, 2, 3** (known normal coins).
#
# - If it balances, then **12 is odd**.
#   - Weighing 3: **12 vs 1**
#     - If 12 is heavier, it’s heavier.
#     - If 12 is lighter, it’s lighter.
#
# - If left side is heavier, then one of **9, 10, 11** is heavy.
#   - Weighing 3: weigh **9 vs 10**
#     - If one is heavier, that coin is the odd heavy coin.
#     - If they balance, then **11 is heavy**.
#
# - If left side is lighter, then one of **9, 10, 11** is light.
#   - Weighing 3: weigh **9 vs 10**
#     - If one is lighter, that coin is the odd light coin.
#     - If they balance, then **11 is light**.
#
# ---
#
# ## Case 2: First weighing is left heavier
# Then either:
#
# - one of **1, 2, 3, 4** is **heavy**, or
# - one of **5, 6, 7, 8** is **light**.
#
# Now we use:
#
# ### Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9** (coin 9 is known normal if case 1 happened; but here we need a normal coin. Since we don’t yet know one, instead use one of the coins from the opposite side carefully designed. A cleaner standard setup is below.)
#
# Let me give a fully correct decision tree that works from the start without needing a previously known normal coin:
#
# ---
#
# # Complete correct strategy
#
# ## Weighing 1
# Weigh **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# ### If it balances:
# Use the Case 1 strategy above.
#
# ### If left side is heavier:
# Then the odd coin is either:
# - **1, 2, 3, 4** and it is **heavy**, or
# - **5, 6, 7, 8** and it is **light**.
#
# Now do:
#
# ## Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9**
# Here, coin **9** is not yet known normal, so this still isn’t ideal unless we reserve a normal coin from the first weighing. To avoid this issue, use the standard method below instead.
#
# ---
#
# # Standard 12-coin solution with guaranteed logic
#
# Label coins **1–12**.
#
# ## Weighing 1
# **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# Let the unweighed coins **9, 10, 11, 12** be the reserve set.
#
# ---
#
# ## If weighing 1 balances
# Then odd coin is among **9–12**.
#
# ### Weighing 2
# **9, 10, 11** vs **1, 2, 3**
#
# - If balance: **12** is odd
#   - Weighing 3: **12 vs 1**
# - If left heavier: one of **9,10,11** is heavy
#   - Weighing 3: **9 vs 10**
# - If left lighter: one of **9,10,11** is light
#   - Weighing 3: **9 vs 10**
#
# ---
#
# ## If weighing 1: left side heavier
# Then the possibilities are:
#
# - **1, 2, 3, 4** is heavy, or
# - **5, 6, 7, 8** is light
#
# ### Weighing 2
# Weigh **1, 2, 5** vs **3, 6, 9**
#
# Now **9 is known normal only if weighing 1 balanced**, which it didn’t. So instead this branch is handled by a proper pre-planned table. Here is the correct concise solution table:
#
# ---
#
# # Fully correct three-weighing strategy
#
# Use this classic arrangement:
#
# ## Weighing 1
# **1, 2, 3, 4** vs **5, 6, 7, 8**
#
# ---
#
# ## If balance
# Odd coin is among **9–12**.
#
# - **Weighing 2:** 9,10,11 vs 1,2,3
#   - balance → 12 odd
#   - left heavy → 9,10,11 heavy
#   - left light → 9,10,11 light
#
# - **Weighing 3:** identify which of the three using 9 vs 10 as above
#
# ---
#
# ## If left side heavier
# Possible sets:
# - heavy: 1,2,3,4
# - light: 5,6,7,8
#
# ### Weighing 2
# **1, 2, 5** vs **3, 6, 9**
# and use coin 9 as a known normal? Not available in this branch, so this version is invalid.
#
# ---
#
# I’ll give the actual standard working tree from memory:
#
# ## Weighing 1
# 1,2,3,4 vs 5,6,7,8
#
# ## Weighing 2
# 1,2,5,6 vs 3,4,9,10
#
# ## Weighing 3
# 1,3,5,7 vs 2,4,9,11
#
# From the pattern of the three outcomes, each coin and each heavy/light status corresponds uniquely to one outcome sequence. This is the classic “ternary code” solution.
#
# If you’d like, I can provide the full outcome table for all 12 coins, or a simpler decision-tree version.
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Call 1: pick a business area worth exploring for Agentic AI

messages = [{"role": "user", "content": "Pick one business area that might be worth exploring for an Agentic AI opportunity. Respond with only the business area and a one-sentence reason."}]

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
business_area = response.choices[0].message.content
print("Business area:\n", business_area)

# Call 2: identify a pain-point in that industry

messages = [{"role": "user", "content": f"The business area is:\n{business_area}\n\nPresent one challenging pain-point in this industry that might be ripe for an Agentic AI solution. Be specific about who feels the pain, why it is hard today, and what a good outcome would look like."}]

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
pain_point = response.choices[0].message.content
print("\nPain-point:\n", pain_point)

# Call 3: propose an Agentic AI solution

messages = [{"role": "user", "content": f"Business area:\n{business_area}\n\nPain-point:\n{pain_point}\n\nPropose an Agentic AI solution. Describe the agent's goal, the tools or systems it would use, the steps it would take autonomously, and how a human would stay in the loop."}]

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
solution = response.choices[0].message.content
print("\nAgentic AI solution:\n")
display(Markdown(solution))
# Out:
# Business area:
#  Customer support operations — it has high-volume, repeatable workflows where an agentic AI can resolve issues, route cases, and follow up autonomously to reduce cost and response times.
#
# Pain-point:
#  **Pain point: Handling high-volume “where is my order?” and refund status cases across fragmented systems**
#
# **Who feels the pain**
# - **Support agents** get flooded with repetitive customer inquiries about order status, delivery exceptions, return progress, and refund timing.
# - **Customers** feel frustrated because they have to repeat themselves, wait in queues, and get inconsistent answers.
# - **Operations managers** struggle with backlog spikes during sales events, shipping delays, or holidays.
#
# **Why it is hard today**
# These cases seem simple, but resolving them often requires an agent to:
# - Check multiple systems: e-commerce platform, warehouse management, shipping carrier, payment processor, and CRM
# - Interpret messy status signals: “label created,” “in transit,” “delayed,” “return received,” “refund pending”
# - Decide the right next action: reassure customer, escalate to carrier, trigger replacement, initiate refund review, or route to a specialist
# - Follow up later if the issue depends on an external event
#
# This is hard to automate with traditional workflows because the logic is conditional, exceptions are common, and the needed data is scattered across disconnected tools. As a result, agents spend a lot of time on low-value lookups and manual follow-up, while customers wait.
#
# **What a good outcome would look like**
# An agentic AI could autonomously:
# - Pull data from all relevant systems
# - Determine the current order/refund state
# - Respond to the customer with a clear, accurate update
# - Take the next best action automatically, such as opening a carrier claim, initiating a refund, or sending a replacement request
# - Schedule follow-ups if the issue is unresolved
# - Escalate only when human judgment is truly needed
#
# **Success would mean**
# - Faster first response and resolution times
# - Lower support cost per case
# - Fewer handoffs and escalations
# - More consistent customer communication
# - Agents freed up to handle genuinely complex or sensitive issues
#
# If you want, I can also give you:
# 1. a **more enterprise-specific pain point**,
# 2. a **smaller SMB support pain point**, or
# 3. a **pain point with clear ROI metrics**.
#
# Agentic AI solution:
# ## Agentic AI solution: Order & Refund Resolution Agent
#
# ### Agent’s goal
# Resolve high-volume “Where is my order?” and refund-status inquiries end-to-end, with minimal human intervention, by:
# - identifying the true order/refund state across systems
# - taking the next best action automatically
# - communicating proactively with the customer
# - escalating only when policy, risk, or ambiguity requires a human
#
# ---
#
# ## Core capabilities
#
# ### 1) Systems and tools it would use
# The agent would connect to:
#
# - **E-commerce / OMS**
#   Order details, fulfillment status, cancellations, substitutions, returns, items, payment method
#
# - **Warehouse Management System (WMS)**
#   Pick/pack/ship events, return receipt, restocking status, inventory exceptions
#
# - **Shipping carrier APIs**
#   Tracking scans, delivery exceptions, lost package flags, delay estimates, proof of delivery
#
# - **Payments / refund processor**
#   Refund initiation status, settlement timing, chargeback flags, partial refund history
#
# - **CRM / support platform**
#   Customer history, prior cases, SLA status, sentiment, VIP/customer tier, case routing rules
#
# - **Policy / knowledge base**
#   Refund policies, replacement rules, delivery promise policies, escalation thresholds
#
# - **Workflow engine / ticketing system**
#   Case updates, task creation, follow-up scheduling, escalation handoff
#
# - **Messaging channels**
#   Email, chat, SMS, or in-app notifications to keep customers updated proactively
#
# ---
#
# ## Autonomous workflow
#
# ### Step 1: Intake and classify
# When a case comes in, the agent:
# - reads the customer message
# - classifies intent as:
#   - order status
#   - delayed delivery
#   - missing package
#   - return status
#   - refund pending
#   - partial refund
# - extracts identifiers like order number, email, tracking number, or return ID
# - asks for missing info only if needed
#
# ### Step 2: Gather data across systems
# The agent queries all relevant systems in parallel:
# - OMS for order and fulfillment state
# - carrier API for shipment scans and exception codes
# - WMS for warehouse/return processing status
# - payments system for refund state
# - CRM for history and policy exceptions
#
# ### Step 3: Normalize status into a customer-friendly state
# Because raw system labels are messy, the agent maps them into a unified decision layer such as:
# - **Order not yet shipped**
# - **Shipped, in transit**
# - **Carrier delay detected**
# - **Delivered**
# - **Return received**
# - **Refund initiated**
# - **Refund pending settlement**
# - **Action required**
#
# ### Step 4: Decide and act
# Based on the unified state and policy, the agent takes the next best action:
#
# #### If order is still in fulfillment
# - tell the customer expected timeline
# - set a follow-up if shipping doesn’t progress by a threshold
# - escalate to fulfillment if the order is stuck
#
# #### If carrier delay is detected
# - notify the customer proactively with updated ETA
# - open a carrier investigation or claim if policy allows
# - schedule a recheck after a defined interval
#
# #### If package is marked delivered but customer says it’s missing
# - verify delivery proof and address match
# - check for common exception patterns
# - ask a small set of clarifying questions
# - route to a specialist if theft/fraud or high-value item rules apply
#
# #### If return is received but refund is not processed
# - verify return receipt and inspection status
# - initiate refund if criteria are met
# - otherwise explain pending reason and ETA
#
# #### If refund is pending with no blocker
# - confirm refund initiation date and settlement window
# - send customer an accurate timeline
# - close the case or schedule automatic follow-up
#
# #### If action is needed
# - open a carrier claim
# - initiate a refund request
# - request replacement shipment
# - create an internal task for review
# - escalate to a human agent with a full case summary
#
# ### Step 5: Follow up automatically
# If the issue depends on an external event, the agent:
# - creates a timed follow-up task
# - rechecks status when the carrier updates or refund clears
# - sends proactive updates without waiting for the customer to ask again
#
# ### Step 6: Close the loop
# Once resolved, the agent:
# - sends a concise summary to the customer
# - updates CRM and ticket fields
# - tags the case for analytics and continuous improvement
# - closes the case if no human action is needed
#
# ---
#
# ## Human-in-the-loop design
#
# A human stays in control through defined checkpoints:
#
# ### The agent can act autonomously for:
# - status lookups
# - standard customer updates
# - policy-approved refund initiation
# - carrier claim creation
# - follow-up scheduling
# - case routing
#
# ### The agent must escalate to a human when:
# - the situation is ambiguous across systems
# - there is a policy exception
# - the customer requests a nonstandard resolution
# - fraud, abuse, chargeback, or safety risk is detected
# - the order is high value or VIP-only handling applies
# - the system confidence is below threshold
# - a refund/replacement exceeds approval limits
#
# ### What the human sees on handoff
# The agent passes a complete summary:
# - customer issue
# - order and refund timeline
# - relevant system signals
# - actions already taken
# - recommended next step
# - confidence level and reason for escalation
#
# This reduces agent toil because the human does not need to re-investigate from scratch.
#
# ---
#
# ## Operating model and controls
#
# ### Guardrails
# - policy-based action limits
# - refund and replacement approval thresholds
# - confidence scoring before autonomous actions
# - audit logs for every system read/write
# - customer communication templates with dynamic data validation
#
# ### Quality checks
# - verify the latest carrier scan before telling the customer delivery status
# - confirm refund eligibility before initiating payment actions
# - cross-check order ID, customer identity, and destination address
# - avoid taking irreversible action without policy clearance
#
# ---
#
# ## Example customer journey
#
# **Customer:** “Where is my order #48291?”
#
# 1. Agent identifies the order and queries OMS + carrier + CRM.
# 2. Finds: shipped, carrier scan delayed at regional hub, ETA slipped by 2 days.
# 3. Agent informs customer immediately with the updated ETA.
# 4. Agent opens a carrier delay investigation.
# 5. Agent schedules a follow-up in 24 hours.
# 6. If shipment updates arrive, the agent sends a proactive message.
# 7. If no progress after threshold, it escalates for replacement review.
#
# ---
#
# ## Business impact
# This agent would:
# - reduce repetitive contacts handled by humans
# - shorten first response and resolution times
# - improve consistency of status updates
# - prevent backlog spikes during peak demand
# - reduce support cost per case
# - free agents for complex or sensitive issues
#
# ---
#
# If you want, I can turn this into:
# 1. a **solution architecture diagram in text**,
# 2. a **workflow spec with decision branches**, or
# 3. a **ROI model with expected KPI improvements**.
