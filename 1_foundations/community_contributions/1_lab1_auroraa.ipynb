# %% [markdown]
# # Foundations Lab 1:
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td>
#             <h2 style="color:#ff7800;">Commercial Application</h2>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity. <br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution. <br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
    
from openai import OpenAI

openai = OpenAI()
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# Pick a business area that might be worth exploring for an Agentic opportunity

question1 = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic opportunity"}]
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=question1)
business_area = response.choices[0].message.content
print(business_area)
# Out:
# **Business area:** **Enterprise IT Service Management (ITSM) / Helpdesk operations (e.g., ticket triage, knowledge-base support, and incident routing).**
#
# **Why this is a good fit for an agentic opportunity**
# - High volume of repetitive work: categorize tickets, extract key details, suggest resolutions, update status.
# - Strong data trail: tickets, emails, chat logs, runbooks, CMDB/asset info—ideal for retrieval + action.
# - Clear workflow boundaries: diagnose → propose next steps → route/escalate → update the ticket.
# - Measurable outcomes: reduce mean time to resolution (MTTR), improve first-contact resolution, cut backlog.
#
# **Example agentic tasks**
# - Auto-triage: classify intent, detect urgency, map to service catalog/teams.
# - “Runbook copilot”: read the ticket context, retrieve relevant troubleshooting steps, and propose actions.
# - Guided resolution: draft responses to users, request missing info, and verify fix outcomes.
# ...

# %%
# Present a pain-point in the industry - something challenging that might be ripe for an Agentic solution

question2 = [{"role": "user", "content": f"Given this business area, come up with a pain point in this business are that could be sold: {business_area}"}]
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=question2)
pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# ### Pain point (sold as an agentic product)
# **“Our IT helpdesk wastes time on repetitive ticket triage and routing, which increases MTTR and causes backlog.”**
#
# **What’s happening**
# - Tickets arrive by email/chat/form with inconsistent wording and missing context.
# - Agents manually:
#   - classify the request (incident vs request vs access issue),
#   - extract key fields (service impacted, user identity, error messages, timestamps),
#   - check KB/previous similar cases,
#   - determine the correct support team/queue,
#   - draft the first response and request missing info,
#   - and only then update the ticket.
# - This results in:
#   - slow first response,
#   - frequent misroutes/escalations,
#   - longer time to resolution (MTTR),
#   - and aging tickets that pile up.
#
# **Why this is a good “agentic” sell**
# - The work is **high-volume, rules + judgment**, and **requires retrieval** (KB, runbooks, past incidents, CMDB).
# ...

# %%
# Propose the Agentic AI solution to the pain-point

question3 = [{"role": "user", "content": f"Given this business area and its pain point, propose an agentic ai solution : {business_area} {pain_point}"}]
response = openai.chat.completions.create(model="gpt-5.4-nano", messages=question3)
solution = response.choices[0].message.content

print(solution)
# Out:
# ## Agentic AI solution for ITSM/Helpdesk: **“Triage-to-Resolution Copilot Agent”**
#
# ### Goal
# Cut helpdesk backlog and MTTR by having an agent **autonomously triage tickets, retrieve the right runbook/KB steps, draft the correct next actions, and update the ticket**—with **human approval** for any changes or escalations.
#
# ---
#
# ## Core agent workflow (end-to-end)
# 1. **Ingest & understand**
#    - Read ticket body + email/chat thread.
#    - Detect language, urgency signals, and missing fields.
#
# 2. **Extract structured incident data**
#    - Create a “ticket facts” record:
#      - service impacted (e.g., VPN, M365 access, email, endpoint)
#      - user identity/account references
#      - error messages / symptoms
#      - timestamps & environment hints
#      - device/OS/browser
#      - whether this is incident vs request vs access issue
#      - suspected component (from text clues)
#
# 3. **Classify + route (reduce misroutes)**
# ...
