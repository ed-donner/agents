# %%
# !pip install langchain langchain-experimental langchain-community langchain-openai openai chromadb pypdf sentence_transformers gradio langchain-together
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.2/211.2 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.1/122.1 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 112.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.6/561.6 kB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 77.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.1 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain-text-splitters

# %%
import os
#from google.colab import userdata
#os.environ["TOGETHER_API_KEY"] = userdata.get('TOGETHER_API_KEY') # user your together ai api key here
# go to https://docs.together.ai/docs/quickstart to register

import getpass


from langchain_community.utilities import WikipediaAPIWrapper, SerpAPIWrapper
from langchain_community.tools import WikipediaQueryRun
from langchain_experimental.tools.python.tool import PythonREPLTool
from langchain_core.tools import tool
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage


# =====================================================
# Step 0: API Keys
# =====================================================
os.environ["OPENROUTER_API_KEY"] = getpass.getpass("Enter OpenRouter API Key: ")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
os.environ["SERPAPI_KEY"] = getpass.getpass("Enter SERPAPI API Key: ")
SERPAPI_KEY = os.environ["SERPAPI_KEY"]
# Out:
# /tmp/ipykernel_948/1250480756.py:9: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import WikipediaAPIWrapper, SerpAPIWrapper
# /tmp/ipykernel_948/1250480756.py:11: DeprecationWarning: `langchain-experimental` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-experimental/issues/87 for details.
#   from langchain_experimental.tools.python.tool import PythonREPLTool
# Enter OpenRouter API Key: ··········
# Enter SERPAPI API Key: ··········

# %%
import os
import getpass
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

#---------------------------------------
# API Keys
#---------------------------------------

os.environ["OPENROUTER_API_KEY"] = getpass.getpass(
    "Enter OpenRouter API Key: "
)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")


#---------------------------------------
# Initialise LLM
#---------------------------------------

llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    temperature=0.3,
    max_tokens=500,
    openai_api_key=OPENROUTER_API_KEY,
    base_url="https://openrouter.ai/api/v1"
)


#---------------------------------------
# Step 1
# Pick an Industry
#---------------------------------------

def pick_business_area():

    prompt = """
    You are an expert in AI strategy.

    Suggest ONE business domain that has significant
    opportunities for Agentic AI adoption.

    Requirements:
    - Must have complex workflows.
    - Must involve multiple stakeholders.
    - Must have repetitive or decision-making tasks.
    - Should be realistic for an Agentic AI solution.

    Return:
    - Industry Name
    - Why it is suitable for Agentic AI
    """

    response = llm.invoke([HumanMessage(content=prompt)])

    return response.content


#---------------------------------------
# Step 2
# Find pain points
#---------------------------------------

def find_pain_points(industry):

    prompt = f"""
    The following industry has been selected:

    {industry}

    Identify the top pain points that are difficult
    to solve using traditional automation.

    Focus on:
    - inefficiencies
    - manual decision making
    - fragmented systems
    - bottlenecks

    Explain:
    - the problem
    - who is affected
    - why current solutions are inadequate
    """

    response = llm.invoke([HumanMessage(content=prompt)])

    return response.content


#---------------------------------------
# Step 3
# Propose Agentic AI solution
#---------------------------------------

def propose_agentic_solution(industry, pain_points):

    prompt = f"""
    Industry:
    {industry}


    Pain Points:
    {pain_points}


    Design an Agentic AI solution.

    Describe:

    1. What agents are required.
    2. What each agent does.
    3. How agents collaborate.
    4. Which tools they might use.
    5. Expected business benefits.
    6. Why Agentic AI is preferable over a simple chatbot.

    Make the solution practical and realistic.
    """

    response = llm.invoke([HumanMessage(content=prompt)])

    return response.content


#---------------------------------------
# Run Pipeline
#---------------------------------------

industry = pick_business_area()

print("\n=========== INDUSTRY ===========\n")
print(industry)


pain_points = find_pain_points(industry)

print("\n=========== PAIN POINTS ===========\n")
print(pain_points)


solution = propose_agentic_solution(
    industry,
    pain_points
)

print("\n=========== AGENTIC AI SOLUTION ===========\n")
print(solution)
# Out:
# Enter OpenRouter API Key: ··········
#
# =========== INDUSTRY ===========
#
# **Industry Name:** Healthcare Administration
#
# **Why it is suitable for Agentic AI:**
#
# 1. **Complex Workflows:** Healthcare administration involves intricate workflows that include patient intake, scheduling, billing, insurance verification, and compliance with regulations. Each of these processes requires coordination among various departments and stakeholders, making it a prime candidate for AI intervention.
#
# 2. **Multiple Stakeholders:** The healthcare ecosystem comprises multiple stakeholders, including patients, healthcare providers, insurance companies, regulatory bodies, and administrative staff. Agentic AI can facilitate communication and streamline interactions among these diverse groups, ensuring that information flows smoothly and efficiently.
#
# ...
