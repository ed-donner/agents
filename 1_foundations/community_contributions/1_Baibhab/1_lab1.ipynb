# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
DEEPSEEK_BASE_URL = "https://api.deepseek.com"
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:8]}")
else:
    print("DeepSeek API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# DeepSeek API Key exists and begins sk-bff18

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

deepseek = OpenAI(base_url=DEEPSEEK_BASE_URL, api_key=deepseek_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = deepseek.chat.completions.create(model="deepseek-v4-flash", messages=messages)
print(response.choices[0].message.content)
# Out:
# Here's a fun fact: **Octopuses have three hearts.** Two pump blood to the gills, while the third pumps it to the rest of the body. And when they swim, the heart that delivers blood to the body actually stops beating—which is why they prefer crawling over swimming!

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = deepseek.chat.completions.create(model="deepseek-v4-flash",messages=messages,extra_body={"thinking" : {"type" : "disabled"}})
question = response.choices[0].message.content
print(question)
# Out:
# A man is trapping a ball inside a 4x4x4 cubic cage made of wires at the vertices, with a small opening at one corner that he can drop the ball through. He wants to roll the ball (not drop or bounce it) along the wires (edges of the cage) such that the ball traverses every edge exactly once, and then exits through the same opening. The cage is not on a flat surface; he can rotate it arbitrarily in 3D space while rolling. Is this possible, and if so, what is the minimum number of times he must lift his hand off the ball (i.e., break continuous contact) to achieve this?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'A man is trapping a ball inside a 4x4x4 cubic cage made of wires at the vertices, with a small opening at one corner that he can drop the ball through. He wants to roll the ball (not drop or bounce it) along the wires (edges of the cage) such that the ball traverses every edge exactly once, and then exits through the same opening. The cage is not on a flat surface; he can rotate it arbitrarily in 3D space while rolling. Is this possible, and if so, what is the minimum number of times he must lift his hand off the ball (i.e., break continuous contact) to achieve this?'}]

# %%
# Ask the model to answer the hard question

response = deepseek.chat.completions.create(model="deepseek-v4-flash", messages=messages,extra_body={"thinking" : {"type" : "disabled"}})
answer = response.choices[0].message.content
print(answer)
# Out:
# We have a **4×4×4 cubic wireframe** — that is a cube made of edges, each divided into 4 segments along each dimension.
# So there are:
#
# - **Vertices**: \( (4+1)^3 = 125 \) vertices
# - **Edges**: along x-direction: \(5 \times 5 \times 4 = 100\) edges, similarly y: 100, z: 100 → total edges = **300**
#
# The man rolls the ball along wires, meaning the ball follows the edges, traversing each **exactly once** (an Eulerian trail), starting and ending at the same corner (the opening).
#
# ---
#
# ### Step 1 – Check Eulerian circuit conditions
# For an **undirected graph** to have an Eulerian circuit (start = end, traverse each edge once), **every vertex must have even degree**.
#
# Each interior vertex in the 4×4×4 grid:
# - Interior (non-boundary): degree 6 (three directions, coming and going)
# - Face center: degree 5
# - Edge but not corner: degree 4
# - Corner: degree 3
#
# All corner vertices have **odd degree** (3), so Eulerian circuit is impossible.
#
# ---
#
# ### Step 2 – Eulerian trail possibility
# For an **Eulerian trail** (start ≠ end), exactly 2 vertices may have odd degree.
# But here, *all 8 corners* have odd degree, plus some edge and face vertices also odd. That's far more than 2 odd-degree vertices.
#
# Thus **no single continuous trail** exists covering every edge exactly once.
#
# ---
#
# ### Step 3 – Lifting hand = adding duplicate edges
# When we lift the hand, we effectively “teleport” the ball to a new starting point without traversing an edge.
# This can be seen as adding a *path* in the multigraph sense to make all vertices even except two (start/end).
#
# We need to pair up odd-degree vertices with added paths. The minimum number of added edges (lifting events) is related to the number of odd-degree vertices.
#
# ---
#
# ### Step 4 – Count odd-degree vertices
# In the 4×4×4 grid:
#
# - **Corners (8)**: degree 3 → odd
# - **Edge but not corner**: on each edge between corners, there are 3 interior vertices, each degree 4 → even
# - **Face interior**: many are degree 5? Let’s check:
#
# A vertex on a face but not on an edge of the big cube: coordinates (1..3, 1..3, 0 or 4) — for such point, connections: 4 in-plane, 1 going inside → degree 5 → odd.
#
# Count face interior vertices:
# Each face: grid 4×4 → interior 3×3 = 9 vertices. 6 faces → \(6 \times 9 = 54\) odd-degree vertices there.
#
# Additionally, edge vertices not corner: degree 4 (even).
# Interior vertices (x,y,z all 1..3): degree 6 (even).
#
# ---
#
# Odd-degree vertices total:
# - 8 corners
# - 54 face-interior points
# = **62 odd-degree vertices**
#
# ---
#
# ### Step 5 – Minimum lifts
# In graph theory, the minimum number of paths to add to make an Eulerian trail possible = \(\text{(number of odd vertices)} / 2 - 1\) if start = end, but here start=end fixed as same corner.
#
# Actually reasoning: To traverse each edge exactly once with possible teleports, the minimum number of times we must lift = number of extra **trails** minus 1.
# Each lift starts a new trail. For a graph with \(2k\) odd vertices, the minimum number of trails to cover all edges is \(k\).
#
# Here \(2k = 62 \rightarrow k = 31\) trails.
# Since he wants to start and end at the same opening, it may be possible to have the trails arranged so start of first = end of last; number of lifts = number of trails − 1 = **30**.
#
# ---
#
# \[
# \boxed{30}
# \]

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# We have a **4×4×4 cubic wireframe** — that is a cube made of edges, each divided into 4 segments along each dimension.
# So there are:
#
# - **Vertices**: \( (4+1)^3 = 125 \) vertices
# - **Edges**: along x-direction: \(5 \times 5 \times 4 = 100\) edges, similarly y: 100, z: 100 → total edges = **300**
#
# The man rolls the ball along wires, meaning the ball follows the edges, traversing each **exactly once** (an Eulerian trail), starting and ending at the same corner (the opening).
#
# ---
#
# ### Step 1 – Check Eulerian circuit conditions
# For an **undirected graph** to have an Eulerian circuit (start = end, traverse each edge once), **every vertex must have even degree**.
#
# Each interior vertex in the 4×4×4 grid:
# - Interior (non-boundary): degree 6 (three directions, coming and going)
# - Face center: degree 5
# - Edge but not corner: degree 4
# - Corner: degree 3
#
# All corner vertices have **odd degree** (3), so Eulerian circuit is impossible.
#
# ---
#
# ### Step 2 – Eulerian trail possibility
# For an **Eulerian trail** (start ≠ end), exactly 2 vertices may have odd degree.
# But here, *all 8 corners* have odd degree, plus some edge and face vertices also odd. That's far more than 2 odd-degree vertices.
#
# Thus **no single continuous trail** exists covering every edge exactly once.
#
# ---
#
# ### Step 3 – Lifting hand = adding duplicate edges
# When we lift the hand, we effectively “teleport” the ball to a new starting point without traversing an edge.
# This can be seen as adding a *path* in the multigraph sense to make all vertices even except two (start/end).
#
# We need to pair up odd-degree vertices with added paths. The minimum number of added edges (lifting events) is related to the number of odd-degree vertices.
#
# ---
#
# ### Step 4 – Count odd-degree vertices
# In the 4×4×4 grid:
#
# - **Corners (8)**: degree 3 → odd
# - **Edge but not corner**: on each edge between corners, there are 3 interior vertices, each degree 4 → even
# - **Face interior**: many are degree 5? Let’s check:
#
# A vertex on a face but not on an edge of the big cube: coordinates (1..3, 1..3, 0 or 4) — for such point, connections: 4 in-plane, 1 going inside → degree 5 → odd.
#
# Count face interior vertices:
# Each face: grid 4×4 → interior 3×3 = 9 vertices. 6 faces → \(6 \times 9 = 54\) odd-degree vertices there.
#
# Additionally, edge vertices not corner: degree 4 (even).
# Interior vertices (x,y,z all 1..3): degree 6 (even).
#
# ---
#
# Odd-degree vertices total:
# - 8 corners
# - 54 face-interior points
# = **62 odd-degree vertices**
#
# ---
#
# ### Step 5 – Minimum lifts
# In graph theory, the minimum number of paths to add to make an Eulerian trail possible = \(\text{(number of odd vertices)} / 2 - 1\) if start = end, but here start=end fixed as same corner.
#
# Actually reasoning: To traverse each edge exactly once with possible teleports, the minimum number of times we must lift = number of extra **trails** minus 1.
# Each lift starts a new trail. For a graph with \(2k\) odd vertices, the minimum number of trails to cover all edges is \(k\).
#
# Here \(2k = 62 \rightarrow k = 31\) trails.
# Since he wants to start and end at the same opening, it may be possible to have the trails arranged so start of first = end of last; number of lifts = number of trails − 1 = **30**.
#
# ---
#
# \[
# \boxed{30}
# \]

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A man is trapping a ball inside a 4x4x4 cubic cage made of wires at the vertices, with a small opening at one corner that he can drop the ball through. He wants to roll the ball (not drop or bounce it) along the wires (edges of the cage) such that the ball traverses every edge exactly once, and then exits through the same opening. The cage is not on a flat surface; he can rotate it arbitrarily in 3D space while rolling. Is this possible, and if so, what is the minimum number of times he must lift his hand off the ball (i.e., break continuous contact) to achieve this?
#
# And here is a possible answer that might be correct or incorrect:
# We have a **4×4×4 cubic wireframe** — that is a cube made of edges, each divided into 4 segments along each dimension.
# So there are:
#
# - **Vertices**: \( (4+1)^3 = 125 \) vertices
# - **Edges**: along x-direction: \(5 \times 5 \times 4 = 100\) edges, similarly y: 100, z: 100 → total edges = **300**
#
# The man rolls the ball along wires, meaning the ball follows the edges, traversing each **exactly once** (an Eulerian trail), starting and ending at the same corner (the opening).
#
# ---
#
# ### Step 1 – Check Eulerian circuit conditions
# For an **undirected graph** to have an Eulerian circuit (start = end, traverse each edge once), **every vertex must have even degree**.
#
# Each interior vertex in the 4×4×4 grid:
# - Interior (non-boundary): degree 6 (three directions, coming and going)
# - Face center: degree 5
# - Edge but not corner: degree 4
# - Corner: degree 3
#
# All corner vertices have **odd degree** (3), so Eulerian circuit is impossible.
#
# ---
#
# ### Step 2 – Eulerian trail possibility
# For an **Eulerian trail** (start ≠ end), exactly 2 vertices may have odd degree.
# But here, *all 8 corners* have odd degree, plus some edge and face vertices also odd. That's far more than 2 odd-degree vertices.
#
# Thus **no single continuous trail** exists covering every edge exactly once.
#
# ---
#
# ### Step 3 – Lifting hand = adding duplicate edges
# When we lift the hand, we effectively “teleport” the ball to a new starting point without traversing an edge.
# This can be seen as adding a *path* in the multigraph sense to make all vertices even except two (start/end).
#
# We need to pair up odd-degree vertices with added paths. The minimum number of added edges (lifting events) is related to the number of odd-degree vertices.
#
# ---
#
# ### Step 4 – Count odd-degree vertices
# In the 4×4×4 grid:
#
# - **Corners (8)**: degree 3 → odd
# - **Edge but not corner**: on each edge between corners, there are 3 interior vertices, each degree 4 → even
# - **Face interior**: many are degree 5? Let’s check:
#
# A vertex on a face but not on an edge of the big cube: coordinates (1..3, 1..3, 0 or 4) — for such point, connections: 4 in-plane, 1 going inside → degree 5 → odd.
#
# Count face interior vertices:
# Each face: grid 4×4 → interior 3×3 = 9 vertices. 6 faces → \(6 \times 9 = 54\) odd-degree vertices there.
#
# Additionally, edge vertices not corner: degree 4 (even).
# Interior vertices (x,y,z all 1..3): degree 6 (even).
#
# ---
#
# Odd-degree vertices total:
# - 8 corners
# - 54 face-interior points
# = **62 odd-degree vertices**
#
# ---
#
# ### Step 5 – Minimum lifts
# In graph theory, the minimum number of paths to add to make an Eulerian trail possible = \(\text{(number of odd vertices)} / 2 - 1\) if start = end, but here start=end fixed as same corner.
#
# Actually reasoning: To traverse each edge exactly once with possible teleports, the minimum number of times we must lift = number of extra **trails** minus 1.
# Each lift starts a new trail. For a graph with \(2k\) odd vertices, the minimum number of trails to cover all edges is \(k\).
#
# Here \(2k = 62 \rightarrow k = 31\) trails.
# Since he wants to start and end at the same opening, it may be possible to have the trails arranged so start of first = end of last; number of lifts = number of trails − 1 = **30**.
#
# ---
#
# \[
# \boxed{30}
# \]
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages)
print(response.choices[0].message.content)
# Out:
# The provided answer contains a critical oversight, making it **incorrect**.
#
# ### What the answer gets right:
# - The cage is correctly modeled as the edge graph of a \(4\times4\times4\) grid, giving 125 vertices and 300 edges.
# - The degrees of the vertices are correctly computed: corners (3), edge-interiors (4), face-interiors (5), and body-interiors (6).
# - There are \(8 + 54 = 62\) odd-degree vertices, so the minimum number of edge-disjoint trails needed to cover all edges exactly once is \(62/2 = 31\).
#
# ### Where the answer goes wrong:
# The problem requires the overall journey to **start and end at the same opening** (a corner with degree 3). In any decomposition of the edges into trails, the multiset of trail endpoints must satisfy:
# - Each odd-degree vertex appears an **odd** number of times as an endpoint.
# - The total number of endpoint occurrences is \(2 \times (\text{number of trails})\).
#
# With 31 trails, the total number of endpoint occurrences is exactly 62, meaning **every odd-degree vertex appears exactly once**. The opening corner would then appear only once as an endpoint, making it impossible to be both the start of the first trail and the end of the last trail.
#
# To have the opening serve as both start and end, it must appear at least **three** times as an endpoint (since 1 is too few, and 2 is even—contradicting its odd degree). This forces the total endpoint count to be at least \(61 \times 1 + 3 = 64\), which requires **32 trails**. The number of times the hand must lift (breaks between trails) is therefore \(32 - 1 = 31\).
#
# The correct minimum number of lifts is **31**, not 30.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a Business idea that might be worth exploring for an agentic AI opportunity."}]

# Then make the first call:

response = deepseek.chat.completions.create(model="deepseek-v4-flash",messages=messages,extra_body={"thinking" : {"type" : "enabled"}})

# Then read the business idea:

business_area = response.choices[0].message.content
print(business_area)

# And repeat! In the next message, include the business area within the message
# Out:
# Here’s a high-potential **agentic AI** business idea: **Autonomous Supply Chain Procure-to-Pay (P2P) Agent**.
#
# **Why this is an agentic AI opportunity (not just another SaaS tool):**
# Current procurement software mostly tracks data, flags approvals, or generates reports. An *agentic* AI doesn’t just analyze—it **acts**. It negotiates with suppliers, resolves invoice discrepancies, triggers re-orders, and re-routes shipments autonomously, only escalating truly novel exceptions to humans.
#
# ---
#
# ### The Business Idea: “ProcureWise” – An Autonomous Procurement Agent
#
# **Core problem solved:**
# Mid-market companies (100–1,000 employees) waste 15–30% of procurement costs on manual tasks: chasing down purchase orders, reconciling invoices, negotiating with vendors for standard supplies, and managing inventory restocks. They lack the resources for large procurement teams.
#
# **What ProcureWise does differently (agentic behavior):**
#
# 1. **Multi-step negotiation** – Given a policy (e.g., “spend < $5k requires one quote, > $5k requires three”), the agent emails/calls approved suppliers, compares quotes, suggests counter-offers, and places orders autonomously.
# 2. **Exception handling** – If an invoice doesn’t match a purchase order, the agent emails the supplier with the discrepancy, proposes a resolution, and if unresolved, escalates to the finance team with a summary.
# 3. **Inventory-aware reordering** – Connects to your ERP, predicts when stock hits reorder point, and sends requests to the best-priced supplier (based on historical data and current market pricing scraped from supplier catalogs).
# 4. **Self-learning preferences** – Over time, it learns which suppliers are most reliable, which times yield best discounts, and which contract terms are acceptable without human input.
#
# **Why now?**
# - Multimodal LLMs can now parse PDF quotes, read supplier emails, and generate context-aware negotiation scripts.
# - API access to procurement platforms (Coupa, SAP Ariba) is mature.
# - Businesses are already comfortable with AI for finance (e.g., accounts payable automation) but not yet for full buying autonomy.
#
# **Business model:**
# - **Per-transaction fee** (e.g., 0.5–1% of procurement spend saved/processed).
# - Tiered: $1,000/mo base + $0.10 per autonomous action (much cheaper than a $60k/year procurement assistant).
# - Start with *non-negotiable supplies* (office supplies, IT equipment, raw materials for manufacturers) → expand to services.
#
# **Build vs. defensibility:**
# - Early moat: **Trained supplier communication templates** based on 100,000+ simulated negotiations (trained on synthetic data).
# - Later moat: **Industry-specific “negotiation strategies”** (e.g., healthcare suppliers vs. manufacturing suppliers price differently).
#
# **Risks to address:**
# - Trust: Offer a “training mode” where the agent suggests actions but doesn’t execute for first 30 days.
# - Compliance: Hard-code regulatory boundaries (e.g., “never sign a contract > $50k without CFO approval”).
#
# ---
#
# **A second, adjacent opportunity** (in case procurement feels too crowded):
# **Regulatory Compliance Agent** for small banks/credit unions.
# - Agent scans new regulations, maps them to existing internal policies, drafts change recommendations, and sends reports to the compliance officer.
# - It then monitors employee training logs and flags gaps autonomously.
# - Reason it’s agentic: it *manages the workflow* (not just reads documents), and can act on your behalf to patch policy gaps.
#
# ---
#
# **Recommendation:**
# If you prefer a *transactional* revenue model with clear ROI, go with the **Procurement Agent**. If you prefer *higher margins and stickier contracts* (compliance departments rarely switch vendors), go the **Regulatory Agent** route.
#
# Which direction feels more aligned with your background?

# %%
messages.append({
    "role" : "assistant",
    "content" : business_area
})

# %%
messages.append({
    "role" : "user",
    "content" : "Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution."
})

response = deepseek.chat.completions.create(model="deepseek-v4-pro",messages=messages,extra_body={"thinking" : {"type" : "enabled"}})
pain_point = response.choices[0].message.content

# %%
messages.append({
    "role" : "assistant",
    "content" : pain_point
})
messages.append({
    "role" : "user",
    "content" : "Now propose an Agentic AI solution for this pain-point."
})

response = deepseek.chat.completions.create(model="deepseek-v4-pro",messages=messages,extra_body={"thinking" : {"type" : "enabled"}})
print(response.choices[0].message.content)
# Out:
# Here’s an **Agentic AI solution** designed to autonomously resolve the three-way match reconciliation pain-point. It’s built as a multi-agent system that doesn’t just flag problems — it investigates, negotiates, adjusts records, and learns.
#
# ---
#
# ## Solution: **“ReconAgent” – Autonomous Three-Way Match & Dispute Resolution Engine**
#
# ### Core Agentic Architecture
#
# ReconAgent comprises four specialized sub-agents orchestrated by a central controller, all operating within a bounded autonomy framework:
#
# 1. **Detective Agent** – Gathers and interprets context from scattered data sources.
# 2. **Resolver Agent** – Evaluates resolution strategies against business policies.
# 3. **Communicator Agent** – Drafts, sends, and interprets external messages to suppliers.
# 4. **Executor Agent** – Performs ERP updates, approvals, and audit logging.
#
# A **Human Escalation Interface** triggers only when confidence falls below threshold or a novel exception exceeds policy limits.
#
# ---
#
# ### How It Works (Step-by-Step Agentic Loop)
#
# **Trigger:** An invoice arrives (via email, EDI, or AP portal) and a preliminary match vs. PO/receipt is attempted. A mismatch is detected. The controller spins up the workflow:
#
# #### 1. Investigation Phase (Detective Agent)
# - Pulls structured data: PO, receiving report, invoice line items, supplier master data, quality records, and any shipment notes.
# - Queries unstructured data: Scans related email threads (subject line, PO number), Slack/Teams channels (if integrated), and supplier portal comments. Using an LLM, it extracts key facts: “48 units received, 2 damaged,” “substitution approved by [person] on [date].”
# - Clarifies internal ambiguities: If a receiving discrepancy is vague (e.g., “short 2 pcs, no reason”), it can autonomously message the warehouse lead: *“PO #8901 – you reported short 2 pcs. Was this a carrier damage or quality reject? Please reply with reason code.”* Waits for response, then proceeds. This is a controlled, templated interaction, not open-ended.
#
# **Output:** A consolidated discrepancy summary with confidence scores for each potential root cause.
#
# #### 2. Resolution Planning (Resolver Agent)
# - Cross-references the cause against a policy library (price tolerance, acceptable substitutions, damage claim rules, contract terms).
# - Generates possible resolution paths with pros/cons and cost/risk scores. Example:
#   - **Path A:** Accept substitution at no additional cost → adjust PO line item, approve invoice at original total.
#   - **Path B:** Short-shipment → request credit note of $X from supplier, process invoice at reduced amount.
#   - **Path C:** Goods damaged by carrier → file claim with carrier, request supplier to reship, defer payment.
# - Selects the highest-probability, in-policy action if confidence > 90%. If multiple paths are viable, picks the cheapest/fastest and logs justification.
# - If confidence is low (e.g., dispute involves a high-value order without clear contract language), the agent packages a **decision memo** (summary, options, recommended action, required approval) and sends it to the human via the escalation interface.
#
# #### 3. External Action (Communicator Agent)
# - Drafts a professional, context-rich email to the supplier contact:
#   - References PO number, invoice number, and the specific line item.
#   - States the discrepancy clearly and proposes resolution exactly as Resolver Agent decided.
#   - Example: *“We received 48 units of SKU 4567 against PO #8901 (ordered 50). 2 units were damaged in transit (inspection report #IR-102 attached). Please issue a credit note for 2 units at $32/unit, total $64. We will process the invoice for the remaining 48 units. Kindly confirm.”*
# - Sends the email via authenticated company email, BCC’s the AP manager for transparency.
# - Monitors the supplier’s reply. An LLM parses the response:
#   - If supplier agrees: triggers Executor Agent.
#   - If supplier disputes with new information (e.g., “We shipped 50, damage must be carrier’s fault”): cycles back to Detective Agent to gather carrier POD documents and adjusts its resolution path. This can continue for 2–3 turns before escalating.
# - For phone calls, an optional voice agent integration could handle basic supplier acknowledgment calls, but email is the primary channel for audit trails.
#
# #### 4. ERP Execution (Executor Agent)
# - Once resolution is confirmed (supplier agrees or autonomous decision passes policy checks):
#   - Adjusts the PO line-item quantity if substitution accepted.
#   - Creates or matches a credit note in the ERP.
#   - Unblocks the invoice for payment.
#   - Posts a detailed reconciliation note with a full audit trail: what was done, by which agent, at what confidence, and linking original evidence (receipt, emails, policy rule).
# - All actions are recorded in a tamper-proof log for SOX/audit compliance.
#
# ---
#
# ### Key Agentic Capabilities That Make This Different
#
# | Traditional RPA / Rule-Based | ReconAgent (Agentic AI) |
# |------------------------------|--------------------------|
# | Fails on any unexpected mismatch format | Understands unstructured comments, emails, and chats |
# | Requires pre-mapped decision trees | Plans multi-step resolutions dynamically |
# | Can’t communicate with external parties | Drafts, sends, and interprets supplier correspondence |
# | Only outputs exception reports | Acts to resolve the exception (adjust PO, apply credit) |
# | Static thresholds | Learns supplier patterns and refines tolerance rules over time |
#
# ---
#
# ### Learning & Continuous Improvement
#
# - **Supplier behavior modeling:** Tracks which suppliers frequently cause certain discrepancies (e.g., short-shipments, price variances) and factors that into future resolution confidence. A “trust score” influences how much back-and-forth is allowed before escalating.
# - **Policy refinement via human feedback:** When a human overrides an agent decision, the system captures the reason and proposes to update the policy library. For instance, if a manager approves a 5% price variance for a critical supplier, the agent suggests adding that rule.
# - **Cross-company anonymized patterns:** Over time, a network effect across customers could surface industry benchmarks (e.g., “carriers in Midwest causing 20% more damage in winter”) and proactively adjust receiving tolerances.
#
# ---
#
# ### Human-in-the-Loop & Trust Layers
#
# - **Observation mode (onboarding):** For the first 30 days, the agent proposes resolutions but all external actions are drafted in an outbox; a designated human clicks “Send” or “Override.” This builds confidence and captures preferences.
# - **Escalation triggers:**
#   - Dollar value above configured threshold (e.g., >$5,000 discrepancy).
#   - New supplier (less than 3 historical matches).
#   - Resolution path requires contract interpretation with no precedent.
#   - Supplier response contains threat of legal action or contract termination (“If you don’t pay in full, we stop supply.”).
# - **Full audit trail & explainability:** Every autonomous move is explained in plain language: “I reduced the invoice by $64 because 2 units were damaged in transit (receiving report #IR-102, carrier waybill photo attached).”
#
# ---
#
# ### Technical Feasibility
#
# - **LLM backbone:** GPT-4o or Claude 3.5 Sonnet with function-calling for structured actions.
# - **Integrations:** REST APIs for ERPs (SAP Business One, NetSuite, Microsoft Dynamics 365), email (Microsoft Graph/Google Workspace), and Slack/Teams. Document parsing via Azure Form Recognizer or LlamaParse for PDF invoices/receipts.
# - **Vector memory:** A knowledge base of resolved disputes (anonymized) to provide few-shot examples for similar future mismatches.
# - **Safety guardrails:** Hard-coded boundaries — never delete original transaction records, never send external emails without an internal notice, never exceed policy limits.
#
# ---
#
# ### Business Value for the Manufacturer
#
# - **Cycle-time reduction:** From 10 days to < 2 hours for 80% of discrepancies.
# - **Cost savings:** Eliminates ~70% of human touches per mismatch (AP, warehouse, purchasing). For 400 discrepancies/month, that’s roughly $15,000 saved monthly in labor alone.
# - **Early-pay discount capture:** Faster resolution means invoices are paid in time for 2%/10 net 30 discounts.
# - **Supplier satisfaction:** Suppliers get clear, immediate communication instead of silence followed by urgent disputes.
# - **Audit-readiness:** Complete, tamper-proof documentation of every reconciliation decision.
#
# ---
#
# ReconAgent turns a chaotic, multi-departmental quagmire into a seamless, self-resolving loop. It's not a chatbot thrown on top of an RPA script — it’s a genuine digital workforce member that takes ownership of the entire exception-handling process. That’s the agentic AI opportunity.
