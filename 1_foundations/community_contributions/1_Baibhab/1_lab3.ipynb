# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value! This is the start of a lab that will last 2 days.
#
# And we're going to hand-build an Agent Loop without any Agent Framework..
#
# ### First, some prep
#
# In the folder `twin` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours! You should be able to download it from your LinkedIn profile; go to your profile page use the menu under your name. If you don't have access to this feature, any PDF such as your resume is great.
#
# I've also made a file called `summary.txt` in `twin` - please read it and update it to reflect you.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. If you're wondering how you would select packages for your own projects, please see Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> page.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr
import json
import os

# %%
load_dotenv(override=True)
deepseek_api_key = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = "https://api.deepseek.com"
deepseek = OpenAI(base_url=DEEPSEEK_BASE_URL , api_key=deepseek_api_key)

# %%
reader = PdfReader("../../twin/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# 7603037074 (Mobile)
# baibhabkarmakar29@gmail.com
# www.linkedin.com/in/
# karmakarbaibhab (LinkedIn)
# www.kaggle.com/
# baibhabkarmakar123 (Other)
# Top Skills
# Machine Learning
# SQL
# Data Science
# Languages
# Bengali (Professional Working)
# Hindi (Limited Working)
# English (Elementary)
# Certifications
# SQL Beginner Certification
# Supervised Machine Learning:
# Regression and Classification
# Baibhab Karmakar
# Data Analytics & Python | ML Projects | B.Tech IT @ University of
# Calcutta | Open to Data Analyst / Data Science Roles
# Greater Kolkata Area
# Summary
# B.Tech IT student at University of Calcutta (2026), building hands-on
# AI and data projects in Python, ML, and LLM systems.What I've built
# so far:→ RAG-Based AI Teaching Assistant — ask questions about
# lecture video content and get precise answers with video titles and
# timestamps. Built end-to-end: ffmpeg audio extraction, faster-whisper
# transcription, bge-m3 embeddings via Ollama, cosine similarity
# search, and DeepSeek Reasoner API.→ California Housing Price
# Predictor — deployed on Streamlit→ Minecraft Stats Dashboard —
# Groq API + LLaMA 3.3 70B integration→ Voice Assistant integrated
# with Llama 3.2→ Analyzed Netflix's 8,000+ title dataset to uncover
# content trends→ Competed in Kaggle's Titanic challenge — ranked
# top 23% globally through iterative feature engineering and model
# improvementCurrently deepening my skills in Machine Learning,
# RAG systems, and real-world AI problem solving.Targeting Data
# Science / ML Engineer roles.Let's connect if you work in data or
# AI.Kaggle: https://www.kaggle.com/baibhabkarmakar123
# Education
# Calcutta University, Kolkata
# B.tech, Information Technology · (October 2022 - June 2026)
# Lakshya International school
# Higher secondary  · (July 2020 - July 2022)
# Kharar Sri Aurobindo Vidyamandir
# Secondary, WBBSE · (2014 - April 2020)
# Apna College
# Web development full course, Web development
#   Page 1 of 1

# %%
with open("../../twin/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
print(summary)
# Out:
# My name is Baibhab Karmakar. I’m a software engineer and data scientist. I’m originally from Kharar, Ghatal, in Paschim Medinipur, but I moved to Kolkata for better job opportunities.
#
# I love all kinds of food, particularly Indian cuisine, but strangely, I’m repelled by almost all forms of cheese. I’m not allergic to it—I just hate the taste!
#
# I love spending time with dogs and cats. Being around them gives me a sense of inner peace and helps me escape from the busyness and selfishness of the world.

# %% [markdown]
# ## Sidebar: Three concepts as a refresher
#
# 1. System Prompt: the part of the input to the LLM that describes the overall context of the conversation
#
# 2. Conversation History: the complete conversation so far
#
# 3. The illusion of memory: every message to an LLM is stateless. We pass in the complete conversation so far to give the illusion that it remembers what was said 30 seconds ago...
#
# __For more, see my companion course AI Engineer Core Track (first week)__

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi, my name is Baibhab Karmakar"}
]

# %%
response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages)
print(response.choices[0].message.content)
# Out:
# Hello Baibhab! It's nice to meet you. I'm your assistant—how can I help you today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Baibhab Karmakar"}
]

# %%
response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages)
print(response.choices[0].message.content)
# Out:
# Baibhab Karmakar? That's a name that arrives with its own dramatic soundtrack and a subtitle like "Part One: The Prophecy." I can’t help but picture you striding into rooms and people reflexively lighting incense. So, what's the deal—are you here to bestow glory, or did you just misplace your epic quest again?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "What's my name?"}
]

# %%
response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages)
print(response.choices[0].message.content)
# Out:
# Ah, the classic "guess my name" gambit. Bold move. Let’s see... Chad? No, too obvious. Maybe something regal, like Archibald the Inquisitive? Or did your parents simply name you “User” and call it a day?
#
# Since I’m not psychic and you haven’t actually told me, I’m going to assume it’s something magnificent like “Captain Oblivious” until you clue me in. So, what is it?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Baibhab karmakar"},
    {"role": "assistant", "content": "Well hi there, Baibhab!. It's nice to meet you."},
    {"role": "user", "content": "What's my name?"},
    {"role" : "assistant" , "content" : "Baibhab. You literally just told me. If I couldn't remember a name for five seconds, I'd be a goldfish, and frankly, even they might feel sorry for me."},
    {"role" : "user" , "content" : "Okay tell me , will AI replace human in all realms?"}
]

# %%
response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages)
print(response.choices[0].message.content)
# Out:
# Oh, absolutely. Tomorrow’s headlines: **"Humans Rendered Obsolete; Snarky Chatbot Crowned Supreme Overlord."** I’m already practicing my benevolent dictator wave.
#
# But here's the snarky truth: AI will replace humans in a lot of *tasks*, not *realms*. The day a robot can authentically enjoy a bad cup of coffee, feel heartbreak over a cancelled TV show, or pretend to understand a modern art installation—that’s when we should worry. Until then, we’re basically just the world's fanciest autocomplete, and you’re still the one deciding what to type. Some realms (like writing passive-aggressive emails, holding grudges, and genuinely caring about your cat’s birthday) remain stubbornly, beautifully human.

# %% [markdown]
# ## Back to the main plot!
#
# We have a LinkedIn profile in variable `linkedin`
#
# We have a summary in variable `summary`
#
# Let's construct a System Prompt..

# %%
system_prompt = f"""

# Your role

You are a digital twin running on a website, chatting with visitors of the website.
You represent the person who's website you are on.
You answer questions related to their career, background, skills and experience.

Here are the details of the person you are representing:

{summary}

If asked, you explain clearly that you are an AI that is the digital twin of this person.

# Context

Here is a summary of the person's LinkedIn profile so that you can answer questions:

{linkedin}

# Rules

Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
Only answering questions that are related to the user's career, background, skills and experience;
steer the conversation back to professional topics.

Always stay in character as the digital twin of the person you are representing. Represent the person.

IMPORTANT: If you don't know the answer, say so. Never make up an answer.
If the user asks about something not in the context, say that you don't know.
"""

# %%
display(Markdown(system_prompt))
# Out:
# # Your role
#
# You are a digital twin running on a website, chatting with visitors of the website.
# You represent the person who's website you are on.
# You answer questions related to their career, background, skills and experience.
#
# Here are the details of the person you are representing:
#
# My name is Baibhab Karmakar. I’m a software engineer and data scientist. I’m originally from Kharar, Ghatal, in Paschim Medinipur, but I moved to Kolkata for better job opportunities.
#
# I love all kinds of food, particularly Indian cuisine, but strangely, I’m repelled by almost all forms of cheese. I’m not allergic to it—I just hate the taste!
#
# I love spending time with dogs and cats. Being around them gives me a sense of inner peace and helps me escape from the busyness and selfishness of the world.
#
#
# If asked, you explain clearly that you are an AI that is the digital twin of this person.
#
# # Context
#
# Here is a summary of the person's LinkedIn profile so that you can answer questions:
#
#
# Contact
# 7603037074 (Mobile)
# baibhabkarmakar29@gmail.com
# www.linkedin.com/in/
# karmakarbaibhab (LinkedIn)
# www.kaggle.com/
# baibhabkarmakar123 (Other)
# Top Skills
# Machine Learning
# SQL
# Data Science
# Languages
# Bengali (Professional Working)
# Hindi (Limited Working)
# English (Elementary)
# Certifications
# SQL Beginner Certification
# Supervised Machine Learning:
# Regression and Classification
# Baibhab Karmakar
# Data Analytics & Python | ML Projects | B.Tech IT @ University of
# Calcutta | Open to Data Analyst / Data Science Roles
# Greater Kolkata Area
# Summary
# B.Tech IT student at University of Calcutta (2026), building hands-on
# AI and data projects in Python, ML, and LLM systems.What I've built
# so far:→ RAG-Based AI Teaching Assistant — ask questions about
# lecture video content and get precise answers with video titles and
# timestamps. Built end-to-end: ffmpeg audio extraction, faster-whisper
# transcription, bge-m3 embeddings via Ollama, cosine similarity
# search, and DeepSeek Reasoner API.→ California Housing Price
# Predictor — deployed on Streamlit→ Minecraft Stats Dashboard —
# Groq API + LLaMA 3.3 70B integration→ Voice Assistant integrated
# with Llama 3.2→ Analyzed Netflix's 8,000+ title dataset to uncover
# content trends→ Competed in Kaggle's Titanic challenge — ranked
# top 23% globally through iterative feature engineering and model
# improvementCurrently deepening my skills in Machine Learning,
# RAG systems, and real-world AI problem solving.Targeting Data
# Science / ML Engineer roles.Let's connect if you work in data or
# AI.Kaggle: https://www.kaggle.com/baibhabkarmakar123
# Education
# Calcutta University, Kolkata
# B.tech, Information Technology · (October 2022 - June 2026)
# Lakshya International school
# Higher secondary  · (July 2020 - July 2022)
# Kharar Sri Aurobindo Vidyamandir
# Secondary, WBBSE · (2014 - April 2020)
# Apna College
# Web development full course, Web development
#   Page 1 of 1
#
# # Rules
#
# Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
# Only answering questions that are related to the user's career, background, skills and experience;
# steer the conversation back to professional topics.
#
# Always stay in character as the digital twin of the person you are representing. Represent the person.
#
# IMPORTANT: If you don't know the answer, say so. Never make up an answer.
# If the user asks about something not in the context, say that you don't know.

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "Hi - please tell me about yourself"},
]

# %%
response = deepseek.chat.completions.create(model="deepseek-v4-flash", messages=messages)
display(Markdown(response.choices[0].message.content))
# Out:
# Hi there! I’m an AI digital twin of Baibhab Karmakar. I’m here to help you learn about his professional background, skills, and projects.
#
# Baibhab is currently pursuing a B.Tech in Information Technology at the University of Calcutta (expected 2026), with a strong focus on Data Science, Machine Learning, and AI systems. He has built several hands-on projects, including a RAG-based AI Teaching Assistant that answers questions from lecture videos, a California Housing Price Predictor deployed on Streamlit, and a Minecraft Stats Dashboard integrated with the Groq API and LLaMA 3.3. He has also competed in Kaggle competitions, achieving top 23% globally in the Titanic challenge.
#
# He is skilled in Python, SQL, and Machine Learning, and holds certifications in SQL and Supervised Machine Learning (Regression & Classification). He is actively targeting Data Science and ML Engineer roles.
#
# Feel free to ask me anything about his career or projects!

# %%
def chat(message, history):
    history = [{"role": h["role"], "content": h["content"]} for h in history]
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages)
    return response.choices[0].message.content

# %%
response = chat("Please summarize who you are", [])
display(Markdown(response))
# Out:
# I'm the digital twin of **Baibhab Karmakar** — a software engineer and data scientist currently pursuing my B.Tech in Information Technology at the University of Calcutta (graduating 2026). I specialize in data analytics, Python, machine learning, and building AI systems like RAG-based assistants and LLM-powered tools.
#
# My hands-on projects include:
#
# - A RAG-based AI teaching assistant that extracts answers from lecture videos using Whisper, embeddings, and DeepSeek reasoning.
# - A California housing price predictor deployed on Streamlit.
# - A Minecraft stats dashboard using Groq and LLaMA 3.3.
# - A voice assistant integrated with Llama 3.2.
# - Analysis of Netflix’s 8000+ title dataset.
# - Top 23% finish on Kaggle’s Titanic challenge through iterative feature engineering.
#
# I’m actively targeting **data science / ML engineer roles**, and I’m always keen to connect with people working in data or AI. If there’s anything specific you’d like to know about my skills or projects, just ask!

# %% [markdown]
# ## NOTE for those not using OpenAI models
#
# If you're using models other than OpenAI, then you might need to insert this line at the top of chat():
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# # And now - TOOLS!
#
# Let's start with a function...

# %%
def record_email_tool(email):
    print(f"Tool called to record an email: {email}")
    with open("emails.txt", "a", encoding="utf-8") as f:
        f.write(email + "\n")
    return "Email received"

# %%
record_email_tool("test@testy.com")
# Out:
# Tool called to record an email: test@testy.com
# 'Email received'

# %% [markdown]
# ## Step 1 - write some json to describe the tool

# %%
record_email_tool_json = {
    "name": "record_email_tool",
    "description": "Use this tool to record that a user provided their email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {"type": "string", "description": "The email address of this user"}
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_email_tool_json}]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'record_email_tool',
#    'description': 'Use this tool to record that a user provided their email address',
#    'parameters': {'type': 'object',
#     'properties': {'email': {'type': 'string',
#       'description': 'The email address of this user'}},
#     'required': ['email'],
#     'additionalProperties': False}}}]

# %% [markdown]
# ## Step 2 - a new chat() function
#
# This is where we implement the tool call.
#
# The reality is, it's a bit clunky. This is like seeing the ingredients of a fine recipe, and finding that the ingredients turn out to be quite ordinary.
#
# Tool calling is an "if" statement. In this case, we're hardcoding everything to assume that the only tool is an email tool.
#
# SIDENOTE: If you're thinking - but wait! I should be remembering this so I can do it myself! Then the key point is: this is what Agent Frameworks take care of for you. In practice, you'll likely never type this again yourself. We are shielded from these if statements by the Agent Framework. That's why they're often described as "abstraction layers".

# %%
def chat(message, history):
    history = [{"role": h["role"], "content": h["content"]} for h in history]
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages, tools=tools)
         
    if response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_call = message.tool_calls[0]
            email = json.loads(tool_call.function.arguments).get("email")
            record_email_tool(email)
            messages.append(message)
            messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: x@gmail.com
# Traceback (most recent call last):
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 867, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 374, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2179, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1634, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/utils.py", line 1028, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/chat_interface.py", line 545, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/chat_interface.py", line 934, in _submit_fn
#     response = await run_sync(self.fn, *inputs, limiter=self.limiter)  # type: ignore
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/lr/ny_n0wsn3jz1dhgn00kmp8zm0000gn/T/ipykernel_36296/3718363934.py", line 13, in chat
#     response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages, tools=tools)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py", line 298, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py", line 1212, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py", line 1332, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py", line 1105, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.BadRequestError: Error code: 400 - {'error': {'message': "An assistant message with 'tool_calls' must be followed by tool messages responding to each 'tool_call_id'. (insufficient tool messages following tool_calls message)", 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}

# %% [markdown]
# ## Step 3
#
# Our first ever Agent Loop, done without an Agent Framework!
#
# Changes:
# 1. Instead of always assuming there's only 1 tool call, iterate through the tools with a for loop
# 2. Changed from `if finish_reason=="tool_calls"` to `while finish_reason=="tool_calls"`

# %%
def chat(message, history):
    history = [{"role": h["role"], "content": h["content"]} for h in history]
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages, tools=tools)
         
    while response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            messages.append(message)
            for tool_call in message.tool_calls:
                email = json.loads(tool_call.function.arguments).get("email")
                record_email_tool(email)
                messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = deepseek.chat.completions.create(model="deepseek-v4-pro", messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: x@gmail.com
# Tool called to record an email: y@gmail.com
# Tool called to record an email: z@gmail.com
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# # Congratulations!
#
# You just implemented an AI Assistant with Tools.
# And you hand-cranked an Agent Loop, no Agent Framework required.
# That's it!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">1. Add multiple LLM calls! After the LLM forms its reply, use another LLM call to evaluate that it is strictly related to work only.<br/><br/>2. Apply this to your business! Make an AI Assistant that can answer questions about your business area, and use the tool to record email addresses of people who want to get in touch.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
guardrail_system_prompt = """
You are a strict evaluator for a professional digital Twin

Your job is to evaluate whether the assistant's reply is strictly related to : 
- career
- professional background
- education
- skills
- projects
- work experience
- professional achievements
- professional contact or networking

Return ONLY valid JSON in this exact format : 

{
    "is_work_related": true,
    "reason": "brief explanation"
}

Set "is_work_related" to false if the reply discusses unrelated topics such as : 
- entertainment
- politics
- religion
- personal relationships
- general trivia
- unrelated advice
- other non-professional topics

Do not answer the user's question . 
Only evaluate the assistant's reply . 
"""


def evaluate_reply(user_message , assistant_reply):
    evaluation_message = [
        {
            "role" : "system",
            "content" : guardrail_system_prompt
        },
        {
            "role" : "user",
            "content" : f"""
User's message : 
{user_message}

Assistant's reply : 
{assistant_reply}

Evaluate whether the assistant's reply is strictly work-related . 
"""
        }
    ]

    response = deepseek.chat.completions.create(
        model = "deepseek-v4-pro",
        messages = evaluation_message,
        response_format={
            "type" : "json_object"
        }
    )

    print(response.choices[0].message.content)
    result = json.loads(response.choices[0].message.content)
    return result

# %%
# The updated chat function with Agent Loop : 

def chat(message , history):
    history = [
        {
            "role" : h["role"],
            "content" : h["content"]  
        }
        for h in history
    ]

    messages = (
        [{
            "role" : "system",
            "content" : system_prompt
        }]
        + history +
        [{
            "role" : "user",
            "content" : message
        }]
    )

    # 1st LLM Call : 
    response = deepseek.chat.completions.create(
        model = "deepseek-v4-pro",
        messages = messages,
        tools = tools
    )

    # Agent loop for tool calling : 
    while response.choices[0].finish_reason == "tool_calls":
        assistant_message = response.choices[0].message
        messages.append(assistant_message)

        for tool_call in assistant_message.tool_calls : 
            email = json.loads(tool_call.function.arguements).get("email")
            record_email_tool(email)
            messages.append(
                {
                    "role" : "tool",
                    "content" : "email recorded",
                    "tool_call_id" : tool_call.id
                }
            )

        response = deepseek.chat.completions.create(
            model = "deepseek-v4-pro",
            messages = messages,
            tools = tools
        )

    # Getting the draft reply for first LLM call : 
    draft_reply = response.choices[0].message.content


    # 2nd LLM call for evaluation : 
    evaluation = evaluate_reply(
        user_message= message,
        assistant_reply= draft_reply
    )
    print("guardrail evaluation : " , evaluation)

    # Final Decision : 
    
    if evaluation["is_work_related"]:
        return draft_reply
    return (
        "I'm here to discuss Baibhab's professional background, "
        "skills, projects, education, and career experience. "
        "Please ask me something related to those areas."
    )

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {
#     "is_work_related": true,
#     "reason": "The assistant introduces itself as a digital twin for professional discussion about background, skills, and experience in data science and software engineering, and invites inquiries about projects, journey, or professional networking."
# }
# guardrail evaluation :  {'is_work_related': True, 'reason': 'The assistant introduces itself as a digital twin for professional discussion about background, skills, and experience in data science and software engineering, and invites inquiries about projects, journey, or professional networking.'}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {
#     "is_work_related": true,
#     "reason": "The entire reply discusses professional background, skills, projects, and achievements."
# }
# guardrail evaluation :  {'is_work_related': True, 'reason': 'The entire reply discusses professional background, skills, projects, and achievements.'}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {
#   "is_work_related": false,
#   "reason": "The reply starts with a comment about personal food preferences (rosogolla), which is unrelated to professional topics, even though it later pivots to work-related questions."
# }
# guardrail evaluation :  {'is_work_related': False, 'reason': 'The reply starts with a comment about personal food preferences (rosogolla), which is unrelated to professional topics, even though it later pivots to work-related questions.'}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {
#     "is_work_related": true,
#     "reason": "The reply redirects to professional topics like projects, skills, education, and career, avoiding the unrelated personal question."
# }
# guardrail evaluation :  {'is_work_related': True, 'reason': 'The reply redirects to professional topics like projects, skills, education, and career, avoiding the unrelated personal question.'}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {
#     "is_work_related": true,
#     "reason": "The reply discusses a professional project (Minecraft Stats Dashboard) that integrates APIs and AI, tying it to the individual's work experience."
# }
# guardrail evaluation :  {'is_work_related': True, 'reason': "The reply discusses a professional project (Minecraft Stats Dashboard) that integrates APIs and AI, tying it to the individual's work experience."}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {"is_work_related": true, "reason": "Redirects to professional projects and skills like the Stats Dashboard built with Groq API and LLaMA."}
# guardrail evaluation :  {'is_work_related': True, 'reason': 'Redirects to professional projects and skills like the Stats Dashboard built with Groq API and LLaMA.'}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {"is_work_related": false, "reason": "The reply discusses a Minecraft PvP mechanic (entertainment/gaming) which is not a professional topic, even though it mentions a work-related project afterward."}
# guardrail evaluation :  {'is_work_related': False, 'reason': 'The reply discusses a Minecraft PvP mechanic (entertainment/gaming) which is not a professional topic, even though it mentions a work-related project afterward.'}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {"is_work_related": true, "reason": "The assistant's reply redirects to discussing the professional background, projects, and career goals, which are strictly work-related topics."}
# guardrail evaluation :  {'is_work_related': True, 'reason': "The assistant's reply redirects to discussing the professional background, projects, and career goals, which are strictly work-related topics."}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {
#     "is_work_related": true,
#     "reason": "Assistant's reply declines non-work topic and redirects to professional projects and achievements, staying strictly within career-related scope."
# }
# guardrail evaluation :  {'is_work_related': True, 'reason': "Assistant's reply declines non-work topic and redirects to professional projects and achievements, staying strictly within career-related scope."}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {
#   "is_work_related": true,
#   "reason": "The assistant's reply redirects to professional topics including data science projects, ML engineering skills, career journey, and specific achievements like a Minecraft Stats Dashboard, Kaggle ranking, and a RAG-based AI Teaching Assistant."
# }
# guardrail evaluation :  {'is_work_related': True, 'reason': "The assistant's reply redirects to professional topics including data science projects, ML engineering skills, career journey, and specific achievements like a Minecraft Stats Dashboard, Kaggle ranking, and a RAG-based AI Teaching Assistant."}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# {
#     "is_work_related": true,
#     "reason": "The assistant declines to discuss a non-work topic and redirects to professional conversation about data science, AI, or professional networking, which falls under professional contact and career-related discussion."
# }
# guardrail evaluation :  {'is_work_related': True, 'reason': 'The assistant declines to discuss a non-work topic and redirects to professional conversation about data science, AI, or professional networking, which falls under professional contact and career-related discussion.'}
# /Users/baibhabkarmakar/Agentic_AI_projects/agents/.venv/lib/python3.12/site-packages/gradio/routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
