# %% [markdown]
# # Bienvenido al comienzo de tu aventura en Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">¿Listo para la acción?</h2>
# <span style="color:#ff7800;">¿Has completado todos los pasos de configuración en la carpeta <a href="../setup/">setup</a>?<br/>
#
# ¿Has consultado las guías en la carpeta <a href="../guides/01_intro.ipynb">guides</a>?<br/>
#
# En ese caso, ¡estás listo! </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#00bfff;">Este código es un recurso activo; esté atento a mis actualizaciones</h2>
# <span style="color:#00bfff;">Actualizo periódicamente. A medida que los usuarios hacen preguntas o tienen problemas, añado más ejemplos y mejoro las explicaciones. Por lo tanto, es posible que el código a continuación no sea idéntico al de los vídeos, ya que he añadido más pasos y mejores comentarios. Considérelo como un libro interactivo que acompaña a las clases.<br/><br/>
# Intento enviar correos electrónicos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrarlo en la sección "Anuncios" de Udemy, en la barra lateral izquierda. También puedes optar por recibir mis correos electrónicos a través de la configuración de notificaciones en Udemy. Soy respetuoso con tu bandeja de entrada y siempre intento aportar valor con mis correos.
#
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ### Y por favor, recuerda contactarme si puedo ayudarte.
#
# Me encantaría conectar contigo: https://www.linkedin.com/in/juan-gabriel-gomila-salas/
#
# ### ¿Eres nuevo en Notebooks como este? ¡Visita la carpeta de guías!
#
# Para comprobar que ya has añadido las extensiones de Python y Jupyter a Cursor, si aún no las tienes instaladas:
# - Abre Extensiones (Ver >> Extensiones).
# - Busca Python y, cuando aparezcan los resultados, haz clic en la de ms-python e instálala si aún no está instalada.
# - Busca Jupyter y, cuando aparezcan los resultados, haz clic en la de Microsoft e instálala si aún no está instalada.
# Luego, ve a Ver >> Explorador para volver al Explorador de archivos.
#
# Y luego:
# 1. Haz clic donde dice "Seleccionar Kernel" cerca de la esquina superior derecha y selecciona la opción `.venv (Python 3.12.9)` o similar, que debería ser la primera opción o la más destacada. Quizás primero debas seleccionar "Entornos de Python".
# 2. Haz clic en cada celda a continuación, comenzando por la celda inmediatamente inferior a este texto, y presiona Mayús+Intro para ejecutar.
# 3. ¡Disfruta!
#
# Después de hacer clic en "Seleccionar Kernel", si no hay ninguna opción como `.venv (Python 3.12.9)`, haz lo siguiente:
# 1. En Mac: En el menú Cursor, selecciona Configuración >> Configuración de VS Code (NOTA: asegúrate de seleccionar `Configuración de VSCode`, no `Configuración de Cursor`). En una PC con Windows: En el menú Archivo, seleccione Preferencias >> Configuración de VS Code (NOTA: asegúrate de seleccionar "Configuración de VS Code" y no "Configuración de Cursor").
# 2. En la barra de búsqueda de Configuración, escriba "venv".
# 3. En el campo "Ruta a la carpeta con la lista de entornos virtuales", introduzca la ruta a la raíz del proyecto, como C:\Users\username\projects\agents (en una PC con Windows) o /Users/username/projects/agents (en Mac o Linux).
# Inténtelo de nuevo.
#
# ¿Tiene problemas porque faltan versiones de Python en la lista? ¿Ha usado Anaconda anteriormente? Podría estar interfiriendo. Salga de Cursor, abra una nueva línea de comandos y asegúrese de que su entorno de Anaconda esté desactivado: `conda deactivate`
# Si aún tiene problemas con las versiones de Conda y Python, es posible que también deba ejecutar esto: `conda config --set auto_activate_base false`
# Y luego, desde el directorio Agentes, debería poder ejecutar `uv python list` y ver la versión de Python 3.12.

# %%
# Empecemos por hacer un import
from dotenv import load_dotenv

# %%
# A continuación, es el momento de cargar las claves API en las variables de entorno.

load_dotenv(override=True)
# Out:
# True

# %%
# Comprobamos las claves

import os
gemini_api_key= os.getenv('GEMINI_API_KEY')

if gemini_api_key:
    print(f"La clave API de OpenAI existe y empieza por {gemini_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.")
# Out:
# La clave API de OpenAI existe y empieza por AQ.Ab8RN

# %%
# Y ahora, la importante declaración de importación
# Si recibes un error de importación, consulta la guía de solución de problemas

from openai import OpenAI

# %%
# Ahora crearemos una instancia de la clase OpenAI.
# Si no estás seguro de lo que significa crear una instancia de una clase, ¡visita la carpeta de guías!
# Si recibes un error de nombre, visita la carpeta de guías para obtener más información sobre los errores de nombre.

gemini = OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=os.getenv('GEMINI_API_KEY')
)

# %%
# Crea una lista de mensajes en el formato familiar de OpenAI

messages = [{"role": "user", "content": "¿Cuanto es 2+2?"}]

# %%
# ¡Y ahora, a llamarlo! Si tienes algún problema, consulta la guía de solución de problemas.
# Usa GPT gemini-2.5-flash, el modelo increíblemente económico.

response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2+2 es **4**.

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta."
messages = [{"role": "user", "content": question}]

# %%
# Pregúntale: usa GPT 4.1 mini, aún barato pero más potente que nano

response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# En un sistema donde cada elemento se define por dos propiedades mutuamente excluyentes (A o no-A; B o no-B), y se observa la siguiente secuencia de transformaciones:
#
# 1.  Un elemento (A, B) se convierte en (no-A, B).
# 2.  Un elemento (no-A, B) se convierte en (no-A, no-B).
# 3.  Un elemento (no-A, no-B) se convierte en (A, no-B).
#
# ¿Cuál es la regla más simple y consistente que rige esta secuencia, y en qué se transformaría un elemento (A, no-B) para cerrar el ciclo de manera lógica y coherente con dicha regla?

# %%
# una nueva lista de mensajes
messages = [{"role": "user", "content": question}]

# %%
# Hacemos una nueva pregunta

response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Analicemos la secuencia de transformaciones paso a paso:
#
# 1.  **(A, B) se convierte en (no-A, B)**
#     *   La propiedad A cambia a no-A.
#     *   La propiedad B permanece igual.
#     *   **Observación:** Se flipa la primera propiedad.
#
# 2.  **(no-A, B) se convierte en (no-A, no-B)**
#     *   La propiedad A permanece igual.
#     *   La propiedad B cambia a no-B.
#     *   **Observación:** Se flipa la segunda propiedad.
#
# 3.  **(no-A, no-B) se convierte en (A, no-B)**
#     *   La propiedad A cambia a A.
#     *   La propiedad B permanece igual.
#     *   **Observación:** Se flipa la primera propiedad.
#
# **La regla más simple y consistente:**
#
# La regla que rige esta secuencia es la **alternancia en el "flipeo" (cambio de estado) de las propiedades**. Una propiedad cambia en cada paso, mientras que la otra se mantiene. El orden en que las propiedades cambian es alternado: primero la primera propiedad (A/no-A), luego la segunda propiedad (B/no-B), luego la primera propiedad de nuevo, y así sucesivamente.
#
# **En qué se transformaría un elemento (A, no-B) para cerrar el ciclo:**
#
# Siguiendo la regla de alternancia:
#
# *   La transformación anterior (paso 3) implicó cambiar la **primera propiedad** (de no-A a A).
# *   Por lo tanto, la próxima transformación (para el elemento (A, no-B)) debe implicar cambiar la **segunda propiedad**.
#
# Así, un elemento **(A, no-B)** se transformaría en:
# *   La propiedad A permanece igual (A).
# *   La propiedad no-B se flipa a B.
#
# Por lo tanto, **(A, no-B) se transformaría en (A, B)**.
#
# Esto cierra el ciclo de manera lógica y coherente, volviendo al estado inicial:
# (A, B) -> (no-A, B) -> (no-A, no-B) -> (A, no-B) -> (A, B)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Analicemos la secuencia de transformaciones paso a paso:
#
# 1.  **(A, B) se convierte en (no-A, B)**
#     *   La propiedad A cambia a no-A.
#     *   La propiedad B permanece igual.
#     *   **Observación:** Se flipa la primera propiedad.
#
# 2.  **(no-A, B) se convierte en (no-A, no-B)**
#     *   La propiedad A permanece igual.
#     *   La propiedad B cambia a no-B.
#     *   **Observación:** Se flipa la segunda propiedad.
#
# 3.  **(no-A, no-B) se convierte en (A, no-B)**
#     *   La propiedad A cambia a A.
#     *   La propiedad B permanece igual.
#     *   **Observación:** Se flipa la primera propiedad.
#
# **La regla más simple y consistente:**
#
# La regla que rige esta secuencia es la **alternancia en el "flipeo" (cambio de estado) de las propiedades**. Una propiedad cambia en cada paso, mientras que la otra se mantiene. El orden en que las propiedades cambian es alternado: primero la primera propiedad (A/no-A), luego la segunda propiedad (B/no-B), luego la primera propiedad de nuevo, y así sucesivamente.
#
# **En qué se transformaría un elemento (A, no-B) para cerrar el ciclo:**
#
# Siguiendo la regla de alternancia:
#
# *   La transformación anterior (paso 3) implicó cambiar la **primera propiedad** (de no-A a A).
# *   Por lo tanto, la próxima transformación (para el elemento (A, no-B)) debe implicar cambiar la **segunda propiedad**.
#
# Así, un elemento **(A, no-B)** se transformaría en:
# *   La propiedad A permanece igual (A).
# *   La propiedad no-B se flipa a B.
#
# Por lo tanto, **(A, no-B) se transformaría en (A, B)**.
#
# Esto cierra el ciclo de manera lógica y coherente, volviendo al estado inicial:
# (A, B) -> (no-A, B) -> (no-A, no-B) -> (A, no-B) -> (A, B)

# %% [markdown]
# # ¡Felicidades!
#
# ¡Ese fue un pequeño y sencillo paso hacia la IA Agentic con tu nuevo entorno!
#
# La próxima vez que las cosas se pongan más interesantes...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Ejercicio</h2>
# <span style="color:#ff7800;">Ahora, prueba esta aplicación comercial:<br/>
# Primero, pide al LLM que elija un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic.<br/>
# Después, pide al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.<br/>
# Finalmente, pide a la tercera convocatoria del LLM que proponga la solución de IA con Agentic. </span>
# </td>
# </tr>
# </table>

# %%
# 1. Creamos la lista donde vamos a acumular TODA la conversación
messages = [{"role": "user", "content": "elegime un area que valga la pena explorar para una oportunidad de IA con Agentic"}]

# --- PRIMERA LLAMADA: Elegir el área ---
response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages  # Le pasamos la lista con la primera pregunta
)

business_idea = response.choices[0].message.content


# Guardamos la respuesta de la IA en el historial para que "recuerde" qué eligió
messages.append({"role": "assistant", "content": business_idea})



# Agregamos la segunda pregunta al historial
messages.append({"role": "user", "content": "luego presentame un problema para esa industria que pueda ser propicio para una solucion con Agentic"})

response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages  
)

problem = response.choices[0].message.content


# Guardamos la respuesta del problema en el historial
messages.append({"role": "assistant", "content": problem})


# Agregamos la tercera pregunta al historial
messages.append({"role": "user", "content": "y por ultimo, propone una solucion de AI con Agentic"})

response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages  # Contiene todo el caminito de la conversación
)

solution = response.choices[0].message.content

display(Markdown(business_idea))
display(Markdown(problem))
display(Markdown(solution))
# Out:
# --- PROBLEMA DE LA INDUSTRIA ---
# ¡Excelente pregunta! Dada la palabra clave "Agentic", que implica sistemas de IA capaces de percibir, razonar, planificar, ejecutar acciones y aprender de forma autónoma para lograr objetivos complejos, el área más prometedora y de alto valor para explorar es:
#
# **"Agentes de Inteligencia Estratégica y Ejecución Adaptativa para la Transformación Empresarial (Strategic Intelligence & Adaptive Execution Agents for Business Transformation)"**
#
# ### ¿Por qué vale la pena explorar esta área con IA Agentic?
#
# 1.  **Alto Valor de Negocio:** Este es el "santo grial" para muchas empresas. La capacidad de no solo analizar datos, sino de *traducir esos análisis en acciones concretas y adaptativas* que impacten directamente en la estrategia, el crecimiento y la eficiencia, es inmensamente valiosa.
# 2.  **Complejidad Adecuada para Agentes:** Los problemas empresariales estratégicos no son lineales ni simples. Requieren la integración de múltiples fuentes de información, razonamiento complejo, planificación a largo plazo, interacción con diversas herramientas y sistemas, y adaptación constante a nuevas condiciones. Esto es precisamente donde los sistemas agentic brillan, a diferencia de los modelos de IA tradicionales o chatbots simples.
# 3.  **Brecha Existente:** Actualmente, existe una brecha significativa entre la capacidad de generar información (dashboards, informes, análisis predictivos) y la capacidad de ejecutar de manera autónoma y adaptativa sobre esa información. Los consultores humanos hacen esto, pero es costoso, lento y no escala bien.
# 4.  **Escalabilidad y Velocidad:** Un agente de este tipo podría operar 24/7, procesar volúmenes masivos de datos a una velocidad inalcanzable para humanos, y coordinar acciones a través de diferentes departamentos o sistemas con una eficiencia sin precedentes.
#
# ### ¿Qué haría un "Agente de Inteligencia Estratégica y Ejecución Adaptativa"?
#
# Imagina un sistema de IA compuesto por múltiples agentes colaborativos, con un Agente Orquestador principal. Sus capacidades incluirían:
#
# 1.  **Percepción y Recopilación de Datos Multi-Fuente:**
#     *   **Internos:** Acceso a ERP, CRM, bases de datos de ventas, marketing, finanzas, operaciones, RRHH.
#     *   **Externos:** Fuentes de mercado (análisis de competidores, tendencias de la industria, noticias económicas), datos demográficos, redes sociales, APIs de terceros.
#     *   **Objetivo Agentic:** No solo recopilar, sino *identificar proactivamente* qué datos son relevantes para el objetivo estratégico dado.
#
# 2.  **Razonamiento y Planificación Estratégica:**
#     *   **Interpretación de Objetivos:** Tomar un objetivo de negocio de alto nivel (ej. "aumentar la cuota de mercado en el segmento X en un 15% en 12 meses", "reducir los costes operativos en la cadena de suministro en un 10%").
#     *   **Descomposición:** Desglosar el objetivo en sub-objetivos y tareas más pequeñas y manejables.
#     *   **Generación de Estrategias:** Proponer múltiples planes de acción y evaluar sus posibles resultados, riesgos y recursos requeridos, basándose en la información recopilada.
#     *   **Simulación:** Ejecutar simulaciones de los planes propuestos para prever resultados.
#
# 3.  **Ejecución Adaptativa con Herramientas (Tool-Use):**
#     *   **Automatización de Campañas:** Integrarse con plataformas de marketing (ej. HubSpot, Salesforce Marketing Cloud) para lanzar campañas dirigidas, crear contenido, A/B testear, y optimizar en tiempo real.
#     *   **Optimización de Operaciones:** Interactuar con sistemas de gestión de cadena de suministro, logística, o producción para ajustar inventarios, rutas, o calendarios.
#     *   **Análisis Financiero y Recomendaciones:** Usar herramientas financieras para modelar escenarios, identificar oportunidades de inversión o ahorro, y generar informes para la dirección.
#     *   **Desarrollo de Producto/Servicio:** Ayudar en la investigación de mercado para nuevos productos, generar prototipos de ideas, o automatizar la retroalimentación de clientes.
#     *   **Gestión de Proyectos:** Crear y actualizar planes de proyecto, asignar tareas, monitorear el progreso y alertar sobre desviaciones.
#
# 4.  **Monitoreo y Reflexión (Self-Correction):**
#     *   **Observación Continua:** Monitorear KPIs relevantes y el entorno externo en tiempo real.
#     *   **Detección de Desviaciones:** Identificar cuándo los planes no están funcionando como se esperaba o cuando surgen nuevas oportunidades/amenazas.
#     *   **Replanificación Autónoma:** Ajustar los planes y acciones en curso basándose en la retroalimentación y los cambios del entorno, sin intervención humana constante.
#     *   **Aprendizaje y Memoria:** Aprender de los éxitos y fracasos, almacenando este conocimiento en una memoria a largo plazo para mejorar futuras decisiones y estrategias.
#
# 5.  **Comunicación Inter-Agentes y Humana:**
#     *   **Coordinación:** Diferentes agentes especializados (ej. "Agente de Marketing", "Agente de Operaciones", "Agente Financiero") podrían colaborar para un objetivo común.
#     *   **Reporting:** Generar informes ejecutivos, alertas, y recomendaciones para la toma de decisiones humana cuando sea necesario.
#
# ### Ejemplos Concretos de Oportunidades:
#
# *   **Agente de Lanzamiento de Productos (Product Launch Agent):** Desde la investigación de mercado inicial, pasando por la creación de la estrategia de precios, el desarrollo de materiales de marketing (texto, imágenes, video scripts), el lanzamiento de campañas publicitarias multicanal, hasta el monitoreo del rendimiento y la adaptación de la estrategia post-lanzamiento.
# *   **Agente de Optimización de Cadena de Suministro (Supply Chain Optimization Agent):** Un agente que monitorea la demanda, la oferta, los precios de los insumos, las condiciones climáticas, los eventos geopolíticos, y ajusta dinámicamente las órdenes de compra, las rutas de envío, los niveles de inventario y la producción para maximizar la eficiencia y minimizar los costes/riesgos.
# *   **Agente de Expansión de Mercado (Market Expansion Agent):** Un agente que identifica nuevos mercados potenciales para un producto/servicio, analiza barreras de entrada, oportunidades competitivas, genera estrategias de entrada personalizadas, e incluso inicia las primeras campañas de reconocimiento de marca y lead generation en esos nuevos mercados.
#
# ### ¿Por qué ahora es el momento ideal para explorar esto?
#
# *   **Avances en LLMs:** Los modelos de lenguaje grandes son el cerebro perfecto para el razonamiento, la planificación y la comunicación de estos agentes.
# *   **Frameworks Agentic:** Herramientas como AutoGen, CrewAI, LangChain, etc., facilitan la construcción y orquestación de múltiples agentes.
# *   **Capacidades de Tool-Calling:** La habilidad de los LLMs para llamar y usar APIs y herramientas externas ha madurado enormemente.
# *   **Madurez de la IA en General:** La infraestructura y las capacidades de IA están lo suficientemente desarrolladas para empezar a abordar esta complejidad.
#
# Explorar esta área con un enfoque Agentic no solo te posiciona en la vanguardia de la IA, sino que también apunta a resolver algunos de los desafíos más complejos y de mayor valor en el mundo empresarial.
# ¡Excelente! Ahora que hemos establecido el área de **"Agentes de Inteligencia Estratégica y Ejecución Adaptativa para la Transformación Empresarial"**, presentemos un problema concreto dentro de esta industria que clama por una solución Agentic.
#
# ---
#
# ### **El Problema: La Lenta y Reactiva Adaptación Competitiva en Mercados Dinámicos**
#
# A pesar de la abundancia de datos y herramientas de análisis, las empresas luchan por mantener una ventaja competitiva sostenible y reaccionar **proactivamente** a las amenazas y oportunidades emergentes en mercados cada vez más volátiles y dinámicos.
#
# **Detalle del Problema:**
#
# 1.  **Fragmentación de la Inteligencia Competitiva:** La información sobre competidores (lanzamientos de productos, cambios de precios, estrategias de marketing, patentes, noticias de financiación, movimientos de personal clave, opiniones de clientes) está dispersa en múltiples fuentes (webs de competidores, redes sociales, noticias, informes financieros, foros de la industria, bases de datos de patentes, etc.).
# 2.  **Recopilación y Análisis Manuales, Lentos y Reactivos:** Equipos humanos dedican incontables horas a rastrear, recopilar y analizar esta información. Para cuando se compila un informe coherente, se presenta a la dirección y se toman decisiones, el competidor ya ha avanzado o la ventana de oportunidad se ha cerrado. La inteligencia es casi siempre **reactiva**, no **proactiva**.
# 3.  **Desconexión entre Insight y Acción:** Incluso cuando se generan buenos insights, existe una barrera significativa entre el "qué hacer" y el "cómo hacerlo" y "quién lo hace". La traducción de un hallazgo estratégico ("El competidor X está apuntando a nuestro segmento de clientes más valioso con una nueva característica disruptiva") en acciones operativas concretas (ajustar nuestra oferta, lanzar una contra-campaña de marketing, acelerar el desarrollo de una característica propia) es lenta y propensa a la ineficiencia.
# 4.  **Falta de Adaptabilidad Continua:** Las estrategias se establecen, se ejecutan, y se revisan en ciclos relativamente largos. El entorno competitivo, sin embargo, evoluciona a diario. No hay un mecanismo constante y autónomo que monitoree la efectividad de las acciones, detecte nuevas amenazas o valide la evolución del mercado, y ajuste la estrategia en tiempo real.
# 5.  **Subutilización de Datos Internos:** La inteligencia externa no se cruza de manera eficiente con los datos de rendimiento internos (ventas, churn de clientes, feedback de productos, coste de adquisición) para evaluar el impacto real de las acciones competitivas y formular una respuesta optimizada.
#
# **En resumen:** Las empresas están atrapadas en un ciclo de reacción lenta, perdiendo oportunidades y cuota de mercado porque no pueden transformar la inteligencia competitiva en acciones estratégicas y operativas **autónomas, rápidas y adaptativas.**
#
# ---
#
# ### **¿Por qué este problema es propicio para una solución con IA Agentic?**
#
# Este problema es ideal para un enfoque Agentic por varias razones clave que tocan las capacidades fundamentales de los sistemas Agentic:
#
# 1.  **Percepción Multi-Fuente y Continua:** Un agente puede rastrear y procesar continuamente una vasta gama de fuentes de datos no estructurados y estructurados de forma simultánea, algo inalcanzable para un equipo humano.
# 2.  **Razonamiento Complejo y Generación de Hipótesis:** Los agentes pueden analizar los datos recopilados, identificar patrones, predecir posibles movimientos de los competidores, evaluar el impacto en el negocio propio y generar múltiples planes de acción y contraestrategias.
# 3.  **Planificación Estratégica con Descomposición de Tareas:** Los agentes pueden tomar un objetivo estratégico de alto nivel ("responder al lanzamiento del competidor X") y descomponerlo en tareas operativas específicas para diferentes departamentos (marketing, producto, ventas, finanzas).
# 4.  **Ejecución Adaptativa con Tool-Use:** La capacidad de los agentes para interactuar con herramientas y APIs externas (plataformas de marketing, CRM, sistemas de gestión de contenido, herramientas de pricing, sistemas de R&D) permite la ejecución directa y autónoma de las acciones planificadas, sin intervención humana como cuello de botella.
# 5.  **Monitoreo y Reflexión (Self-Correction):** Un agente puede monitorear el rendimiento de las acciones ejecutadas y el entorno competitivo en tiempo real. Si una estrategia no funciona o si el competidor hace un nuevo movimiento, el agente puede reflexionar, aprender y ajustar el plan o las acciones en curso de forma autónoma.
# 6.  **Colaboración Multi-Agente:** Diferentes agentes especializados (ej. un "Agente de Monitoreo de Competencia", un "Agente de Estrategia de Marketing", un "Agente de Optimización de Precios") pueden colaborar para abordar el problema de manera holística.
#
# Una solución Agentic no solo informaría a los humanos sobre lo que está pasando, sino que, de manera autónoma, sugeriría, priorizaría y, en muchos casos, ejecutaría las respuestas estratégicas necesarias para mantener o expandir la ventaja competitiva. Esto transforma el negocio de ser reactivo a ser **proactivo y adaptativo de manera continua**.
# ¡Absolutamente! Aquí te presento una propuesta de solución Agentic para el problema de la "Lenta y Reactiva Adaptación Competitiva en Mercados Dinámicos".
#
# ---
#
# ### **Solución Agentic: El "Strategic Market Adaptor (SMA) Agent System"**
#
# La solución propuesta es un sistema multi-agente denominado **"Strategic Market Adaptor (SMA) Agent System"**. Su objetivo es transformar la inteligencia competitiva en acciones estratégicas y operativas **proactivas, autónomas y continuamente adaptativas**, minimizando la intervención humana en el ciclo de reacción y maximizando la agilidad de la empresa.
#
# El SMA System operaría como una orquesta de agentes de IA, cada uno con roles especializados, que colaboran bajo la dirección de un Agente Orquestador para lograr objetivos de negocio definidos.
#
# ---
#
# ### **Componentes del SMA Agent System:**
#
# El sistema estaría compuesto por los siguientes agentes clave, cada uno con sus propias capacidades de percepción, razonamiento, planificación, ejecución (tool-use) y reflexión:
#
# 1.  **Agente Orquestador (Strategic Lead Agent):**
#     *   **Rol Principal:** Es el "cerebro" central que recibe los objetivos estratégicos de alto nivel de los humanos (ej. "defender nuestra cuota de mercado del producto X ante el nuevo competidor Y", "expandir la presencia en el mercado Z", "optimizar el margen de beneficio en el segmento A").
#     *   **Funciones:** Descompone estos objetivos en sub-objetivos para los demás agentes, asigna tareas, coordina la colaboración, gestiona prioridades, supervisa el rendimiento global del sistema y presenta informes consolidados a los humanos.
#     *   **Tool-Use:** Interfaz de usuario para entrada de objetivos y reporting, herramientas de gestión de proyectos internos (Jira, Asana), sistemas de BI/dashboards para monitoreo de KPIs de alto nivel.
#
# 2.  **Agente de Inteligencia Competitiva (Competitive Intelligence Agent - CI Agent):**
#     *   **Rol Principal:** La "vista y oído" del sistema. Percibe el entorno externo en tiempo real.
#     *   **Funciones:**
#         *   **Recopilación Continua:** Rastrea proactivamente (web scraping avanzado, APIs) sitios web de competidores, comunicados de prensa, blogs de la industria, noticias financieras, redes sociales (menciones, sentimientos), foros de productos, bases de datos de patentes, ofertas de empleo, etc.
#         *   **Análisis Primario:** Detecta lanzamientos de productos, cambios de precios, nuevas características, campañas de marketing, cambios en la estrategia de canales, movimientos de personal clave, opiniones de clientes sobre competidores.
#         *   **Detección de Amenazas/Oportunidades:** Identifica patrones y anomalías que puedan indicar una amenaza competitiva o una nueva oportunidad de mercado.
#     *   **Tool-Use:** Motores de búsqueda avanzados, APIs de redes sociales (X, LinkedIn, etc.), herramientas de monitoreo de medios, bases de datos de patentes, herramientas de análisis de sentimiento y PLN.
#
# 3.  **Agente de Análisis Estratégico y Planificación (Strategic Analysis & Planning Agent - SAP Agent):**
#     *   **Rol Principal:** El "analista y estratega" del sistema. Razona sobre la información y propone planes de acción.
#     *   **Funciones:**
#         *   **Síntesis:** Integra los hallazgos del CI Agent con datos internos (ventas, márgenes, CRM, feedback de clientes, costos operativos) para comprender el impacto potencial.
#         *   **Diagnóstico:** Evalúa la gravedad de las amenazas o el potencial de las oportunidades.
#         *   **Generación de Estrategias:** Propone planes de acción estratégicos detallados para responder (ej. "lanzar una campaña de marketing de contra-ataque", "ajustar la oferta de producto", "modificar la estrategia de precios", "desarrollar una nueva característica").
#         *   **Simulación y Evaluación:** Modela los posibles resultados de diferentes estrategias, riesgos asociados y recursos requeridos.
#     *   **Tool-Use:** APIs de bases de datos internas (CRM, ERP, DWH), herramientas de modelado predictivo, motores de simulación, LLM para razonamiento y generación de texto estratégico.
#
# 4.  **Agentes de Ejecución Táctica (Tactical Execution Agents):**
#     *   **Rol Principal:** Los "brazos" del sistema. Implementan las acciones estratégicas en las plataformas operativas de la empresa. Estos son agentes especializados que actúan sobre las órdenes del SAP Agent.
#     *   **Sub-Agentes Ejemplares:**
#         *   **a. Agente de Marketing y Comunicación (Marketing Agent):**
#             *   **Funciones:** Crea contenido (textos, scripts, ideas de imágenes/videos), lanza campañas publicitarias dirigidas, optimiza el presupuesto de anuncios, personaliza comunicaciones de email marketing, gestiona redes sociales.
#             *   **Tool-Use:** Plataformas de marketing automation (HubSpot, Salesforce Marketing Cloud), plataformas de publicidad digital (Google Ads, Meta Ads), CMS (WordPress, Contentful), APIs de generación de contenido (imágenes, video).
#         *   **b. Agente de Producto y Oferta (Product & Offering Agent):**
#             *   **Funciones:** Sugiere ajustes de características, propone experimentos A/B en la oferta, monitorea feedback de clientes sobre el propio producto, propone ajustes de precios o paquetes.
#             *   **Tool-Use:** Herramientas de gestión de productos (Jira, Asana), sistemas de pricing dinámico, plataformas de A/B testing, APIs de feedback de clientes.
#         *   **c. Agente de Ventas y Relaciones con el Cliente (Sales & CRM Agent):**
#             *   **Funciones:** Identifica segmentos de clientes vulnerables, propone scripts de ventas o comunicaciones personalizadas para el equipo de ventas, ajusta estrategias de lead nurturing.
#             *   **Tool-Use:** CRM (Salesforce, Zoho), plataformas de sales engagement, herramientas de segmentación de clientes.
#
# 5.  **Agente de Monitoreo y Adaptación Continua (Monitoring & Adaptation Agent - MA Agent):**
#     *   **Rol Principal:** La "retroalimentación" del sistema. Observa los resultados de las acciones y el entorno cambiante para asegurar la adaptabilidad.
#     *   **Funciones:**
#         *   **Monitoreo de Rendimiento:** Rastrea KPIs en tiempo real relacionados con las acciones ejecutadas (ej. CTR, conversiones, tasas de churn, ventas, satisfacción del cliente, precios de competidores).
#         *   **Detección de Desviaciones:** Identifica cuándo los resultados se desvían de las expectativas o si el entorno competitivo ha cambiado de nuevo.
#         *   **Reflexión y Replanificación:** Analiza la causa de las desviaciones y genera nuevas recomendaciones o ajustes al plan existente, enviándolos al SAP Agent para su reevaluación.
#         *   **Aprendizaje:** Almacena los éxitos y fracasos en una base de conocimiento para mejorar futuras estrategias y decisiones.
#     *   **Tool-Use:** APIs de analítica web (Google Analytics), dashboards de BI internos, APIs de plataformas de marketing y ventas, sistemas de A/B testing, bases de datos de conocimiento.
#
# ---
#
# ### **Flujo de Operación del SMA Agent System:**
#
# 1.  **Definición de Objetivo (Humano -> Orquestador):** Un líder de negocio define un objetivo estratégico (ej. "Responder a la nueva línea de productos ecológicos del Competidor X, que amenaza nuestra cuota de mercado en un 10%").
# 2.  **Descomposición y Asignación (Orquestador):** El Agente Orquestador descompone el objetivo en sub-objetivos y asigna al CI Agent para recopilar inteligencia.
# 3.  **Recopilación de Inteligencia (CI Agent):** El CI Agent monitorea los movimientos del Competidor X (precios, marketing, características de producto, feedback de clientes) y lo envía al SAP Agent.
# 4.  **Análisis y Planificación Estratégica (SAP Agent):** El SAP Agent combina la inteligencia del CI Agent con datos internos (ej. ventas de productos similares, margen de productos ecológicos, feedback de clientes sobre nuestra oferta). Razona y propone una estrategia (ej. "Lanzar una campaña de concientización sobre nuestras propias credenciales ecológicas y ofrecer un descuento temporal en productos clave"). Este plan incluye acciones específicas para los Agentes de Ejecución Táctica.
# 5.  **Ejecución Táctica (Agentes de Ejecución):**
#     *   El **Marketing Agent** genera textos para anuncios, configura la campaña en Google Ads y redes sociales, y programa emails.
#     *   El **Product Agent** evalúa si es necesario destacar nuevas características o considerar un pequeño ajuste en el empaque.
#     *   El **Sales Agent** prepara mensajes clave para el equipo de ventas sobre cómo abordar la amenaza competitiva.
# 6.  **Monitoreo y Adaptación (MA Agent):** El MA Agent monitorea en tiempo real el rendimiento de la campaña (clicks, conversiones), la cuota de mercado, las menciones del competidor, y el feedback de los clientes.
# 7.  **Reflexión y Replanificación (MA Agent -> SAP Agent):** Si el MA Agent detecta que la campaña no está funcionando como se esperaba (ej. el competidor bajó aún más sus precios o lanzó una característica sorprendente), lo reporta al SAP Agent. El SAP Agent revisa la estrategia y propone ajustes (ej. "Ajustar el mensaje publicitario, considerar una oferta de 'bundle' con otro producto").
# 8.  **Bucle Continuo:** El ciclo se repite, con el sistema adaptándose proactivamente a medida que el mercado evoluciona, con intervención humana solo para la validación de alto nivel o para nuevos objetivos estratégicos.
#
# ---
#
# ### **Beneficios Clave de la Solución Agentic:**
#
# *   **Proactividad Extrema:** Pasa de ser reactivo a anticipar y actuar rápidamente.
# *   **Velocidad y Escala:** Procesamiento de datos y ejecución de acciones a una velocidad y volumen inalcanzables para equipos humanos.
# *   **Adaptabilidad Continua:** Estrategias dinámicas que se ajustan en tiempo real a los cambios del mercado.
# *   **Optimización Constante:** Aprendizaje y mejora continua de las acciones estratégicas.
# *   **Reducción de Costes y Tiempos:** Libera a los equipos humanos de tareas repetitivas y lentas, permitiéndoles enfocarse en la visión y la innovación.
# *   **Insights Accionables:** Cierra la brecha entre la generación de insights y su implementación directa.
#
# Esta solución no solo automatiza procesos, sino que crea un sistema inteligente, autónomo y adaptable que opera como un "departamento estratégico" virtual, permitiendo a la empresa mantener una ventaja competitiva sostenible en un entorno en constante cambio.

# %%
)

business_idea = response.choices[0].message.content


# Guardamos la respuesta de la IA en el historial para que "recuerde" qué eligió
messages.append({"role": "assistant", "content": business_idea})



# Agregamos la segunda pregunta al historial
messages.append({"role": "user", "content": "luego presentame un problema para esa industria que pueda ser propicio para una solucion con Agentic"})

response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages  
)

problem = response.choices[0].message.content
print("--- PROBLEMA DE LA INDUSTRIA ---")


# Guardamos la respuesta del problema en el historial
messages.append({"role": "assistant", "content": problem})



# Agregamos la tercera pregunta al historial
messages.append({"role": "user", "content": "y por ultimo, propone una solucion de AI con Agentic"})

response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=messages  # Contiene todo el caminito de la conversación
)

solution = response.choices[0].message.content


from IPython.display import Markdown, display

display(Markdown(business_idea))
display(Markdown(problem))
display(Markdown(solution))
