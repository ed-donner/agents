# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role":"user","content":"What is 2+2"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'What is 2+2'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)
# Out:
# 2 + 2 = **4**.

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-EOynayZt77wzHOjiQka7xYbxrPbIN', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='2 + 2 = **4**.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1789622290, model='gpt-5.4-nano-2026-03-17', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=12, prompt_tokens=12, total_tokens=24, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# 2 + 2 = 4

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user', 'content': '2 + 2 = 4'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# Yes — 2 + 2 = 4.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Yes — 2 + 2 = 4.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# 2 + 2 = 4
#
# And here is a possible answer that might be correct or incorrect:
# Yes — 2 + 2 = 4.
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)
# Out:
# Correct.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for Agentic AI opportunity"}]

# Then make the first call:

# response =

# Then read the business idea:

# business_area = response.

# And repeat! In the next message, include the business area within the message

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Pick a business area that might be worth exploring for Agentic AI opportunity'}]

# %%
response = openai.chat.completions.create(model="gpt-5.4-mini",messages=messages)

# %%
from IPython.display import display,Markdown
answer = display(Markdown(response.choices[0].message.content))
query = response.choices[0].message.content
# Out:
# A strong business area to explore for **Agentic AI** is **customer operations in B2B SaaS / enterprise software**.
#
# ### Why this area is promising
# - **High volume of repetitive work:** support tickets, onboarding, troubleshooting, account setup, billing issues, renewals, and internal escalations.
# - **Clear workflows:** many tasks follow repeatable steps, which is ideal for agents that can decide, act, and hand off.
# - **Measurable ROI:** faster resolution times, lower support costs, better retention, and improved customer satisfaction.
# - **Multiple systems involved:** CRM, ticketing, knowledge bases, billing, product telemetry, and email—exactly where agentic workflows add value.
# - **Human-in-the-loop friendly:** agents can draft responses, gather context, and execute routine actions while escalating edge cases.
#
# ### Example agentic opportunities
# - Auto-triage incoming support requests and route them to the right queue.
# - Investigate common issues by checking logs, account state, and known incidents.
# - Draft personalized responses and suggested next steps for agents.
# - Trigger account recovery, refund, or subscription changes within policy.
# - Proactively identify at-risk customers and generate retention actions.
#
# ### Why it’s a good first bet
# Compared with more regulated or high-stakes areas, customer operations usually has:
# - lower implementation friction,
# - faster deployment cycles,
# - easier access to data,
# - and quicker proof of value.
#
# If you want, I can also suggest:
# 1. **the best industry verticals within this area**, or
# 2. **a shortlist of 5 agentic AI opportunities ranked by ROI and ease of implementation**.

# %%
question = f"""For given below business for Agentic AI find out find oput pain point - something challenging that might be ripe for an Agentic Solution
{query}
"""

# %%
question
# Out:
# 'For given below business for Agentic AI find out find oput pain point - something challenging that might be ripe for an Agentic Solution\nA strong business area to explore for **Agentic AI** is **customer operations in B2B SaaS / enterprise software**.\n\n### Why this area is promising\n- **High volume of repetitive work:** support tickets, onboarding, troubleshooting, account setup, billing issues, renewals, and internal escalations.\n- **Clear workflows:** many tasks follow repeatable steps, which is ideal for agents that can decide, act, and hand off.\n- **Measurable ROI:** faster resolution times, lower support costs, better retention, and improved customer satisfaction.\n- **Multiple systems involved:** CRM, ticketing, knowledge bases, billing, product telemetry, and email—exactly where agentic workflows add value.\n- **Human-in-the-loop friendly:** agents can draft responses, gather context, and execute routine actions while escalating edge cases.\n\n### Example agentic opportunities\n- Auto-triage incoming support requests and route them to the right queue.\n- Investigate common issues by checking logs, account state, and known incidents.\n- Draft personalized responses and suggested next steps for agents.\n- Trigger account recovery, refund, or subscription changes within policy.\n- Proactively identify at-risk customers and generate retention actions.\n\n### Why it’s a good first bet\nCompared with more regulated or high-stakes areas, customer operations usually has:\n- lower implementation friction,\n- faster deployment cycles,\n- easier access to data,\n- and quicker proof of value.\n\nIf you want, I can also suggest:\n1. **the best industry verticals within this area**, or  \n2. **a shortlist of 5 agentic AI opportunities ranked by ROI and ease of implementation**.\n'

# %%
messages = [{"role":"user","content":question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'For given below business for Agentic AI find out find oput pain point - something challenging that might be ripe for an Agentic Solution\nA strong business area to explore for **Agentic AI** is **customer operations in B2B SaaS / enterprise software**.\n\n### Why this area is promising\n- **High volume of repetitive work:** support tickets, onboarding, troubleshooting, account setup, billing issues, renewals, and internal escalations.\n- **Clear workflows:** many tasks follow repeatable steps, which is ideal for agents that can decide, act, and hand off.\n- **Measurable ROI:** faster resolution times, lower support costs, better retention, and improved customer satisfaction.\n- **Multiple systems involved:** CRM, ticketing, knowledge bases, billing, product telemetry, and email—exactly where agentic workflows add value.\n- **Human-in-the-loop friendly:** agents can draft responses, gather context, and execute routine actions while escalating edge cases.\n\n### Example agentic opportunities\n- Auto-triage incoming support requests and route them to the right queue.\n- Investigate common issues by checking logs, account state, and known incidents.\n- Draft personalized responses and suggested next steps for agents.\n- Trigger account recovery, refund, or subscription changes within policy.\n- Proactively identify at-risk customers and generate retention actions.\n\n### Why it’s a good first bet\nCompared with more regulated or high-stakes areas, customer operations usually has:\n- lower implementation friction,\n- faster deployment cycles,\n- easier access to data,\n- and quicker proof of value.\n\nIf you want, I can also suggest:\n1. **the best industry verticals within this area**, or  \n2. **a shortlist of 5 agentic AI opportunities ranked by ROI and ease of implementation**.\n'}]

# %%
response = openai.chat.completions.create(model="gpt-5.4",messages=messages)
answer=response.choices[0].message.content
print(answer)
# Out:
# A strong **pain point** in this business area that is ripe for an Agentic AI solution is:
#
# ## Pain Point: Fragmented customer support investigation across multiple systems
#
# ### What’s challenging
# When a customer submits a support request, the support rep often has to manually:
# - read the ticket,
# - identify the issue type,
# - look up the customer in the CRM,
# - check subscription/billing status,
# - inspect product usage or telemetry,
# - search the knowledge base,
# - review past tickets,
# - see if there is an active incident,
# - and then decide the next action or escalation path.
#
# This process is:
# - **slow**
# - **repetitive**
# - **error-prone**
# - **dependent on human experience**
# - **spread across too many tools**
#
# ### Why this is a real business pain
# It leads to:
# - longer first-response and resolution times,
# - inconsistent customer experience,
# - higher support costs,
# - poor handoffs between teams,
# - missed upsell/retention signals,
# - and agent burnout.
#
# ### Why it’s ideal for Agentic AI
# This is a great fit because an agent can:
# - autonomously gather context from multiple systems,
# - reason about likely issue categories,
# - decide the next best action,
# - draft a response,
# - execute approved actions like password resets, account updates, or ticket routing,
# - and escalate only when needed.
#
# ### Example of the pain point in one sentence
# **Support teams waste significant time manually investigating customer issues across disconnected systems before they can even begin solving the problem.**
#
# If you want, I can next turn this into:
# 1. a **problem statement for a startup**,
# 2. a **specific agentic AI use case**, or
# 3. a **pain point → solution → ROI table**.

# %%
query = f"""
    Propose Agentic AI solution for below pain point problem of given business
    Business : {question}

    Pain Point: {answer}
"""

print(question)
# Out:
# For given below business for Agentic AI find out find oput pain point - something challenging that might be ripe for an Agentic Solution
# A strong business area to explore for **Agentic AI** is **customer operations in B2B SaaS / enterprise software**.
#
# ### Why this area is promising
# - **High volume of repetitive work:** support tickets, onboarding, troubleshooting, account setup, billing issues, renewals, and internal escalations.
# - **Clear workflows:** many tasks follow repeatable steps, which is ideal for agents that can decide, act, and hand off.
# - **Measurable ROI:** faster resolution times, lower support costs, better retention, and improved customer satisfaction.
# - **Multiple systems involved:** CRM, ticketing, knowledge bases, billing, product telemetry, and email—exactly where agentic workflows add value.
# - **Human-in-the-loop friendly:** agents can draft responses, gather context, and execute routine actions while escalating edge cases.
#
# ### Example agentic opportunities
# - Auto-triage incoming support requests and route them to the right queue.
# - Investigate common issues by checking logs, account state, and known incidents.
# - Draft personalized responses and suggested next steps for agents.
# - Trigger account recovery, refund, or subscription changes within policy.
# - Proactively identify at-risk customers and generate retention actions.
#
# ### Why it’s a good first bet
# Compared with more regulated or high-stakes areas, customer operations usually has:
# - lower implementation friction,
# - faster deployment cycles,
# - easier access to data,
# - and quicker proof of value.
#
# If you want, I can also suggest:
# 1. **the best industry verticals within this area**, or
# 2. **a shortlist of 5 agentic AI opportunities ranked by ROI and ease of implementation**.

# %%
print("*****************")
print(answer)
# Out:
# *****************
# A strong **pain point** in this business area that is ripe for an Agentic AI solution is:
#
# ## Pain Point: Fragmented customer support investigation across multiple systems
#
# ### What’s challenging
# When a customer submits a support request, the support rep often has to manually:
# - read the ticket,
# - identify the issue type,
# - look up the customer in the CRM,
# - check subscription/billing status,
# - inspect product usage or telemetry,
# - search the knowledge base,
# - review past tickets,
# - see if there is an active incident,
# - and then decide the next action or escalation path.
#
# This process is:
# - **slow**
# - **repetitive**
# - **error-prone**
# - **dependent on human experience**
# - **spread across too many tools**
#
# ### Why this is a real business pain
# It leads to:
# - longer first-response and resolution times,
# - inconsistent customer experience,
# - higher support costs,
# - poor handoffs between teams,
# - missed upsell/retention signals,
# - and agent burnout.
#
# ### Why it’s ideal for Agentic AI
# This is a great fit because an agent can:
# - autonomously gather context from multiple systems,
# - reason about likely issue categories,
# - decide the next best action,
# - draft a response,
# - execute approved actions like password resets, account updates, or ticket routing,
# - and escalate only when needed.
#
# ### Example of the pain point in one sentence
# **Support teams waste significant time manually investigating customer issues across disconnected systems before they can even begin solving the problem.**
#
# If you want, I can next turn this into:
# 1. a **problem statement for a startup**,
# 2. a **specific agentic AI use case**, or
# 3. a **pain point → solution → ROI table**.

# %%
print(query)
# Out:
#     Propose Agentic AI solution for below pain point problem of given business
#     Business : For given below business for Agentic AI find out find oput pain point - something challenging that might be ripe for an Agentic Solution
# A strong business area to explore for **Agentic AI** is **customer operations in B2B SaaS / enterprise software**.
#
# ### Why this area is promising
# - **High volume of repetitive work:** support tickets, onboarding, troubleshooting, account setup, billing issues, renewals, and internal escalations.
# - **Clear workflows:** many tasks follow repeatable steps, which is ideal for agents that can decide, act, and hand off.
# - **Measurable ROI:** faster resolution times, lower support costs, better retention, and improved customer satisfaction.
# - **Multiple systems involved:** CRM, ticketing, knowledge bases, billing, product telemetry, and email—exactly where agentic workflows add value.
# - **Human-in-the-loop friendly:** agents can draft responses, gather context, and execute routine actions while escalating edge cases.
#
# ### Example agentic opportunities
# - Auto-triage incoming support requests and route them to the right queue.
# - Investigate common issues by checking logs, account state, and known incidents.
# - Draft personalized responses and suggested next steps for agents.
# - Trigger account recovery, refund, or subscription changes within policy.
# - Proactively identify at-risk customers and generate retention actions.
#
# ### Why it’s a good first bet
# Compared with more regulated or high-stakes areas, customer operations usually has:
# - lower implementation friction,
# - faster deployment cycles,
# - easier access to data,
# - and quicker proof of value.
#
# If you want, I can also suggest:
# 1. **the best industry verticals within this area**, or
# 2. **a shortlist of 5 agentic AI opportunities ranked by ROI and ease of implementation**.
#
#
#     Pain Point: A strong **pain point** in this business area that is ripe for an Agentic AI solution is:
#
# ## Pain Point: Fragmented customer support investigation across multiple systems
#
# ### What’s challenging
# When a customer submits a support request, the support rep often has to manually:
# - read the ticket,
# - identify the issue type,
# - look up the customer in the CRM,
# - check subscription/billing status,
# - inspect product usage or telemetry,
# - search the knowledge base,
# - review past tickets,
# - see if there is an active incident,
# - and then decide the next action or escalation path.
#
# This process is:
# - **slow**
# - **repetitive**
# - **error-prone**
# - **dependent on human experience**
# - **spread across too many tools**
#
# ### Why this is a real business pain
# It leads to:
# - longer first-response and resolution times,
# - inconsistent customer experience,
# - higher support costs,
# - poor handoffs between teams,
# - missed upsell/retention signals,
# - and agent burnout.
#
# ### Why it’s ideal for Agentic AI
# This is a great fit because an agent can:
# - autonomously gather context from multiple systems,
# - reason about likely issue categories,
# - decide the next best action,
# - draft a response,
# - execute approved actions like password resets, account updates, or ticket routing,
# - and escalate only when needed.
#
# ### Example of the pain point in one sentence
# **Support teams waste significant time manually investigating customer issues across disconnected systems before they can even begin solving the problem.**
#
# If you want, I can next turn this into:
# 1. a **problem statement for a startup**,
# 2. a **specific agentic AI use case**, or
# 3. a **pain point → solution → ROI table**.

# %%
messages = [{"role":"user","content":query}]
messages
# Out:
# [{'role': 'user',
#   'content': '\n    Propose Agentic AI solution for below pain point problem of given business\n    Business : For given below business for Agentic AI find out find oput pain point - something challenging that might be ripe for an Agentic Solution\nA strong business area to explore for **Agentic AI** is **customer operations in B2B SaaS / enterprise software**.\n\n### Why this area is promising\n- **High volume of repetitive work:** support tickets, onboarding, troubleshooting, account setup, billing issues, renewals, and internal escalations.\n- **Clear workflows:** many tasks follow repeatable steps, which is ideal for agents that can decide, act, and hand off.\n- **Measurable ROI:** faster resolution times, lower support costs, better retention, and improved customer satisfaction.\n- **Multiple systems involved:** CRM, ticketing, knowledge bases, billing, product telemetry, and email—exactly where agentic workflows add value.\n- **Human-in-the-loop friendly:** agents can draft responses, gather context, and execute routine actions while escalating edge cases.\n\n### Example agentic opportunities\n- Auto-triage incoming support requests and route them to the right queue.\n- Investigate common issues by checking logs, account state, and known incidents.\n- Draft personalized responses and suggested next steps for agents.\n- Trigger account recovery, refund, or subscription changes within policy.\n- Proactively identify at-risk customers and generate retention actions.\n\n### Why it’s a good first bet\nCompared with more regulated or high-stakes areas, customer operations usually has:\n- lower implementation friction,\n- faster deployment cycles,\n- easier access to data,\n- and quicker proof of value.\n\nIf you want, I can also suggest:\n1. **the best industry verticals within this area**, or  \n2. **a shortlist of 5 agentic AI opportunities ranked by ROI and ease of implementation**.\n\n\n    Pain Point: A strong **pain point** in this business area that is ripe for an Agentic AI solution is:\n\n## Pain Point: Fragmented customer support investigation across multiple systems\n\n### What’s challenging\nWhen a customer submits a support request, the support rep often has to manually:\n- read the ticket,\n- identify the issue type,\n- look up the customer in the CRM,\n- check subscription/billing status,\n- inspect product usage or telemetry,\n- search the knowledge base,\n- review past tickets,\n- see if there is an active incident,\n- and then decide the next action or escalation path.\n\nThis process is:\n- **slow**\n- **repetitive**\n- **error-prone**\n- **dependent on human experience**\n- **spread across too many tools**\n\n### Why this is a real business pain\nIt leads to:\n- longer first-response and resolution times,\n- inconsistent customer experience,\n- higher support costs,\n- poor handoffs between teams,\n- missed upsell/retention signals,\n- and agent burnout.\n\n### Why it’s ideal for Agentic AI\nThis is a great fit because an agent can:\n- autonomously gather context from multiple systems,\n- reason about likely issue categories,\n- decide the next best action,\n- draft a response,\n- execute approved actions like password resets, account updates, or ticket routing,\n- and escalate only when needed.\n\n### Example of the pain point in one sentence\n**Support teams waste significant time manually investigating customer issues across disconnected systems before they can even begin solving the problem.**\n\nIf you want, I can next turn this into:\n1. a **problem statement for a startup**,  \n2. a **specific agentic AI use case**, or  \n3. a **pain point → solution → ROI table**.\n'}]

# %%
response = openai.chat.completions.create(model="gpt-5.4",messages=messages)
answer=response.choices[0].message.content
print(answer)
# Out:
# Here’s a strong **Agentic AI solution proposal** for that pain point.
#
# ---
#
# # Agentic AI Solution Proposal
# ## Business Area
# **Customer Operations in B2B SaaS / Enterprise Software**
#
# ## Pain Point
# **Support teams waste significant time manually investigating customer issues across disconnected systems before they can even begin solving the problem.**
#
# ---
#
# # Proposed Agentic AI Solution
# ## AI Support Investigation & Resolution Agent
#
# An **Agentic AI support copilot/agent** that can autonomously:
# - intake customer tickets,
# - gather context from all relevant systems,
# - diagnose likely issues,
# - recommend or take next actions,
# - draft customer replies,
# - and escalate to the right human/team when needed.
#
# ---
#
# # How the Agent Works
#
# ## 1. Ticket Intake & Understanding
# When a support request comes in through email, chat, or ticketing system, the agent:
# - reads the request,
# - identifies intent/problem type,
# - detects urgency and sentiment,
# - extracts key entities such as customer name, account ID, product area, billing issue, severity.
#
# ## 2. Multi-System Investigation
# The agent connects to:
# - **CRM** for account details, contract value, renewal stage, customer tier
# - **Billing system** for payment status, invoices, subscription plan
# - **Product telemetry/logs** for usage issues, failed actions, outages, error patterns
# - **Knowledge base** for known fixes and help articles
# - **Ticketing history** for prior incidents and recurring issues
# - **Incident management tools** for active outages or known bugs
#
# It then creates a single investigation summary.
#
# ## 3. Reasoning & Next-Best Action
# The agent decides:
# - Is this a known issue?
# - Is this caused by billing/access/configuration/product bug?
# - Can the problem be solved automatically?
# - Does it require engineering, customer success, or finance?
# - Is the customer at churn risk or high priority?
#
# ## 4. Action Execution
# Based on company policy, the agent can:
# - route the ticket to the correct queue,
# - ask the customer for missing information,
# - send troubleshooting steps,
# - reset account settings,
# - trigger subscription corrections,
# - create internal escalation tickets,
# - notify on-call teams if it matches an incident,
# - schedule follow-up tasks.
#
# ## 5. Human-in-the-Loop Escalation
# If confidence is low or action is high-risk, the agent:
# - prepares a concise case summary,
# - explains what it checked,
# - suggests recommended next steps,
# - hands off to the right team.
#
# ---
#
# # Example Workflow
#
# ### Customer issue:
# “Users in our workspace cannot log in after upgrading our plan.”
#
# ### Agent actions:
# 1. Reads the ticket and classifies it as **login/access + possible billing/account sync issue**.
# 2. Checks CRM and finds customer is enterprise tier.
# 3. Checks billing and confirms a recent plan upgrade.
# 4. Checks telemetry and detects failed role provisioning after plan change.
# 5. Searches past tickets and finds similar cases linked to account sync delays.
# 6. Checks incident dashboard to see no current outage.
# 7. Decides next action:
#    - trigger account sync repair automatically,
#    - draft response to customer,
#    - mark priority as high due to enterprise account.
# 8. If repair fails, escalates to engineering with logs and full context attached.
#
# ---
#
# # Key Agentic Capabilities
# This is “agentic” because it does more than answer questions:
# - **perceives** incoming requests,
# - **plans** investigation steps,
# - **uses tools/APIs** across enterprise systems,
# - **makes decisions** using policies and business logic,
# - **takes actions** autonomously,
# - **learns from outcomes** over time.
#
# ---
#
# # Business Value / ROI
#
# ## 1. Faster Response Times
# - reduces first-response time
# - reduces mean time to resolution
#
# ## 2. Lower Support Cost
# - less manual lookup work
# - fewer repetitive tasks for agents
#
# ## 3. Better Customer Experience
# - faster and more consistent support
# - fewer handoff delays
#
# ## 4. Higher Agent Productivity
# - support reps focus on complex edge cases
# - lower burnout from repetitive investigation
#
# ## 5. Improved Retention
# - high-value or at-risk customers identified earlier
# - faster resolution reduces churn risk
#
# ---
#
# # Measurable KPIs
# Success can be measured by:
# - **First Response Time (FRT)**
# - **Mean Time to Resolution (MTTR)**
# - **Ticket Deflection Rate**
# - **Auto-resolution Rate**
# - **Escalation Accuracy**
# - **Customer Satisfaction (CSAT)**
# - **Support Cost per Ticket**
# - **Agent Productivity per Day**
#
# ---
#
# # MVP Scope
# A practical first version could focus on:
#
# ## Phase 1
# - ingest support tickets
# - classify issue type
# - pull CRM, billing, and ticket history data
# - generate investigation summary
# - draft response for human approval
#
# ## Phase 2
# - add telemetry/log investigation
# - auto-route tickets
# - detect known incidents
# - recommend next best actions
#
# ## Phase 3
# - autonomous execution of low-risk actions
# - proactive outreach for recurring issues
# - churn-risk/upsell signal detection
#
# ---
#
# # Tech Components
# Typical architecture:
# - **LLM orchestration layer**
# - **tool/API connectors** to CRM, ticketing, billing, telemetry, KB
# - **policy engine** for allowed actions
# - **workflow engine** for escalation and approvals
# - **memory/context layer** for account and case history
# - **human approval interface** for risky decisions
# - **analytics dashboard** for performance tracking
#
# ---
#
# # Risks and Guardrails
# To make this enterprise-safe:
#
# - human approval for refunds, plan changes, or sensitive account actions
# - role-based access controls
# - audit logs for every action taken
# - confidence thresholds before autonomous execution
# - fallback to human when data is incomplete
# - PII/security compliance controls
#
# ---
#
# # One-Line Solution Statement
# **Build an Agentic AI Support Investigation & Resolution Agent that automatically gathers customer context across systems, diagnoses likely issues, executes low-risk support actions, and escalates complex cases with a complete summary.**
#
# ---
#
# If you want, I can next turn this into any of these:
# 1. **pain point → solution → ROI table**
# 2. **startup pitch / problem-solution statement**
# 3. **architecture diagram in text**
# 4. **implementation roadmap with tools and agents**
