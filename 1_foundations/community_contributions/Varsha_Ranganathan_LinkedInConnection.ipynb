# %% [markdown]
# # Use the Evaluator-Optimizer Agent design pattern that can draft LinkedIn connection messages

# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
# Out:
# True

# %%
google_api_key = os.getenv('GEMINI_API_KEY')

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")
# Out:
# Google API Key exists and begins AI

# %%
request = "Please draft a LinkedIn connection message highlighting my 3 years of experience in the Data Science and Analytics field and express interest to connect and learn about open roles in their company"
request += "Do not add any place holders at any point and consider the character limit to be 300 characters."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please draft a LinkedIn connection message highlighting my 3 years of experience in the Data Science and Analytics field and express interest to connect and learn about open roles in their companyDo not add any place holders at any point and consider the character limit to be 300 characters.'}]

# %%
models = []
responses = []

# %%
client = OpenAI(
    api_key=os.getenv("GEMINI_API_KEY"),
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
model_name = "gemini-2.5-flash"

response = client.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
models.append(model_name)
responses.append(answer)
# Out:
# I'm a Data Science professional with 3 years of experience in analytics and machine learning. I'm highly impressed by your company's work and am actively exploring new opportunities. I'd appreciate connecting to learn more about your team's projects and any open roles that align with my background. Thank you.

# %%
model_name = "gemini-2.5-flash-lite"

response = client.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
models.append(model_name)
responses.append(answer)
# Out:
# Hi [Name], I have 3 years in Data Science & Analytics. I'm impressed by [Company Name]'s work and would love to connect. I'm keen to learn about any open roles where my skills could be a good fit.

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
models.append(model_name)
responses.append(answer)
# Out:
# Here's a draft LinkedIn connection message:
#
# "Hi, I came across your profile while researching exciting companies in the data science and analytics space. With 3 years of experience delivering insights that drive business growth, I'd love to connect and learn more about potential open roles at your organization. Let's connect!"
#
# This message is within the 300 character limit and conveys your interest in connecting with the person's profile while showcasing your professional background. Feel free to adjust it according to your preferences.
#
# (Note: This message is concise and doesn't ask for a specific job or title, which gives you space to explore potential opportunities without putting too much pressure on your end.)

# %%
print(models)
print(responses)
# Out:
# ['gemini-2.5-flash', 'gemini-2.5-flash-lite', 'llama3.2']
# ["I'm a Data Science professional with 3 years of experience in analytics and machine learning. I'm highly impressed by your company's work and am actively exploring new opportunities. I'd appreciate connecting to learn more about your team's projects and any open roles that align with my background. Thank you.", "Hi [Name], I have 3 years in Data Science & Analytics. I'm impressed by [Company Name]'s work and would love to connect. I'm keen to learn about any open roles where my skills could be a good fit.", 'Here\'s a draft LinkedIn connection message:\n\n"Hi, I came across your profile while researching exciting companies in the data science and analytics space. With 3 years of experience delivering insights that drive business growth, I\'d love to connect and learn more about potential open roles at your organization. Let\'s connect!"\n\nThis message is within the 300 character limit and conveys your interest in connecting with the person\'s profile while showcasing your professional background. Feel free to adjust it according to your preferences.\n\n(Note: This message is concise and doesn\'t ask for a specific job or title, which gives you space to explore potential opportunities without putting too much pressure on your end.)']

# %%
# It's nice to know how to use "zip"
for model, response in zip(models, responses):
    print(f"Competitor: {model}\n\n{answer}")
# Out:
# Competitor: gemini-2.5-flash
#
# Here's a draft LinkedIn connection message:
#
# "Hi, I came across your profile while researching exciting companies in the data science and analytics space. With 3 years of experience delivering insights that drive business growth, I'd love to connect and learn more about potential open roles at your organization. Let's connect!"
#
# This message is within the 300 character limit and conveys your interest in connecting with the person's profile while showcasing your professional background. Feel free to adjust it according to your preferences.
#
# (Note: This message is concise and doesn't ask for a specific job or title, which gives you space to explore potential opportunities without putting too much pressure on your end.)
# Competitor: gemini-2.5-flash-lite
#
# Here's a draft LinkedIn connection message:
#
# "Hi, I came across your profile while researching exciting companies in the data science and analytics space. With 3 years of experience delivering insights that drive business growth, I'd love to connect and learn more about potential open roles at your organization. Let's connect!"
#
# This message is within the 300 character limit and conveys your interest in connecting with the person's profile while showcasing your professional background. Feel free to adjust it according to your preferences.
#
# (Note: This message is concise and doesn't ask for a specific job or title, which gives you space to explore potential opportunities without putting too much pressure on your end.)
# Competitor: llama3.2
#
# Here's a draft LinkedIn connection message:
#
# "Hi, I came across your profile while researching exciting companies in the data science and analytics space. With 3 years of experience delivering insights that drive business growth, I'd love to connect and learn more about potential open roles at your organization. Let's connect!"
#
# This message is within the 300 character limit and conveys your interest in connecting with the person's profile while showcasing your professional background. Feel free to adjust it according to your preferences.
#
# (Note: This message is concise and doesn't ask for a specific job or title, which gives you space to explore potential opportunities without putting too much pressure on your end.)

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(responses):
    together += f"# Response from model {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from model 1
#
# I'm a Data Science professional with 3 years of experience in analytics and machine learning. I'm highly impressed by your company's work and am actively exploring new opportunities. I'd appreciate connecting to learn more about your team's projects and any open roles that align with my background. Thank you.
#
# # Response from model 2
#
# Hi [Name], I have 3 years in Data Science & Analytics. I'm impressed by [Company Name]'s work and would love to connect. I'm keen to learn about any open roles where my skills could be a good fit.
#
# # Response from model 3
#
# Here's a draft LinkedIn connection message:
#
# "Hi, I came across your profile while researching exciting companies in the data science and analytics space. With 3 years of experience delivering insights that drive business growth, I'd love to connect and learn more about potential open roles at your organization. Let's connect!"
#
# This message is within the 300 character limit and conveys your interest in connecting with the person's profile while showcasing your professional background. Feel free to adjust it according to your preferences.
#
# (Note: This message is concise and doesn't ask for a specific job or title, which gives you space to explore potential opportunities without putting too much pressure on your end.)

# %%
judge = f"""You are judging a linkedin connection messages between {len(models)} models.
Each model has been given this request:

{request}

Your job is to evaluate each response for clarity and ability of the models to follow instructions and rank them in order of best to worst.
If there are placehodlers or if the character limit has exceeded the instructions rank those models very low.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the models, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a linkedin connection messages between 3 models.
# Each model has been given this request:
#
# Please draft a LinkedIn connection message highlighting my 3 years of experience in the Data Science and Analytics field and express interest to connect and learn about open roles in their companyDo not add any place holders at any point and consider the character limit to be 300 characters.
#
# Your job is to evaluate each response for clarity and ability of the models to follow instructions and rank them in order of best to worst.
# If there are placehodlers or if the character limit has exceeded the instructions rank those models very low.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from model 1
#
# I'm a Data Science professional with 3 years of experience in analytics and machine learning. I'm highly impressed by your company's work and am actively exploring new opportunities. I'd appreciate connecting to learn more about your team's projects and any open roles that align with my background. Thank you.
#
# # Response from model 2
#
# Hi [Name], I have 3 years in Data Science & Analytics. I'm impressed by [Company Name]'s work and would love to connect. I'm keen to learn about any open roles where my skills could be a good fit.
#
# # Response from model 3
#
# Here's a draft LinkedIn connection message:
#
# "Hi, I came across your profile while researching exciting companies in the data science and analytics space. With 3 years of experience delivering insights that drive business growth, I'd love to connect and learn more about potential open roles at your organization. Let's connect!"
#
# This message is within the 300 character limit and conveys your interest in connecting with the person's profile while showcasing your professional background. Feel free to adjust it according to your preferences.
#
# (Note: This message is concise and doesn't ask for a specific job or title, which gives you space to explore potential opportunities without putting too much pressure on your end.)
#
#
#
# Now respond with the JSON with the ranked order of the models, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "3", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = models[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemini-2.5-flash
# Rank 2: llama3.2
# Rank 3: gemini-2.5-flash-lite
