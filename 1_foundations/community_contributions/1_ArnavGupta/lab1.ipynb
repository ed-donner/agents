# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)

GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite", messages=[{"role":"user", "content": "what is 2+2?"}])
print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(response.choices[0].message.content)

# %%
# Out:
# A train leaves Station A traveling north at 60 mph. An identical train leaves Station B traveling south at 80 mph on the exact same parallel track, exactly 210 miles apart. At the exact same moment both trains depart, a peregrine falcon sitting on the front of Train A takes off and flies directly toward Train B at a constant speed of 100 mph. The moment it touches the front of Train B, it instantly reverses direction and flies back to Train A at 100 mph, continuing this back-and-forth motion without losing any time in turning until the two trains collide. Assuming no wind resistance and instantaneous acceleration for the bird, what is the exact total distance the falcon flies?
# None

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite", messages=messages)

# %%
question = response.choices[0].message.content
print(question)
# Out:
# A farmer has a rectangular field measuring 100 meters by 50 meters. He wants to maximize the grazing area for his goat by tethering it to a stake with a rope. The goat must be able to reach every point along the perimeter of the field at least once, but the rope's length must be as short as possible to minimize overgrazing in the center. Where must the stake be placed, and what is the exact minimum length of the rope required?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': "A farmer has a rectangular field measuring 100 meters by 50 meters. He wants to maximize the grazing area for his goat by tethering it to a stake with a rope. The goat must be able to reach every point along the perimeter of the field at least once, but the rope's length must be as short as possible to minimize overgrazing in the center. Where must the stake be placed, and what is the exact minimum length of the rope required?"}]

# %%
# Ask the model to answer the hard question

response = gemini.chat.completions.create(model="gemini-3.5-flash-lite", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# To solve this problem, we need to find the shortest possible rope length such that a circle (or circular arc) centered at the stake can reach every point on the perimeter of the $100\text{ m} \times 50\text{ m}$ rectangle.
#
# ### 1. Where must the stake be placed?
# To minimize the required rope length, the stake must be placed at the **center of the rectangular field**.
#
# If the stake were placed anywhere else, the distance to the farthest corner(s) would increase, requiring a longer rope to ensure the goat could still reach the opposite corner. The center is equidistant from all four corners, which are the points furthest from the inside of the rectangle.
#
# ### 2. What is the exact minimum length of the rope?
# The points on the perimeter furthest from the center are the **four corners** of the rectangle. Therefore, the length of the rope must be at least equal to the distance from the center of the rectangle to any of its corners.
#
# We can find this distance using the Pythagorean theorem.
# * Half the length of the field ($a$) = $\frac{100}{2} = 50\text{ m}$
# * Half the width of the field ($b$) = $\frac{50}{2} = 25\text{ m}$
#
# The distance $r$ from the center to a corner is the hypotenuse of a right triangle with sides $50$ and $25$:
#
# $$r = \sqrt{50^2 + 25^2}$$
# $$r = \sqrt{2500 + 625}$$
# $$r = \sqrt{3125}$$
#
# We can simplify the radical:
# $$r = \sqrt{625 \times 5} = 25\sqrt{5}\text{ meters}$$
#
# ### Conclusion
# * **Stake Location:** Exactly in the center of the field.
# * **Minimum Rope Length:** $25\sqrt{5}\text{ meters}$ (approximately **$55.90\text{ meters}$**).

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A farmer has a rectangular field measuring 100 meters by 50 meters. He wants to maximize the grazing area for his goat by tethering it to a stake with a rope. The goat must be able to reach every point along the perimeter of the field at least once, but the rope's length must be as short as possible to minimize overgrazing in the center. Where must the stake be placed, and what is the exact minimum length of the rope required?
#
# And here is a possible answer that might be correct or incorrect:
# To solve this problem, we need to find the shortest possible rope length such that a circle (or circular arc) centered at the stake can reach every point on the perimeter of the $100\text{ m} \times 50\text{ m}$ rectangle.
#
# ### 1. Where must the stake be placed?
# To minimize the required rope length, the stake must be placed at the **center of the rectangular field**.
#
# If the stake were placed anywhere else, the distance to the farthest corner(s) would increase, requiring a longer rope to ensure the goat could still reach the opposite corner. The center is equidistant from all four corners, which are the points furthest from the inside of the rectangle.
#
# ### 2. What is the exact minimum length of the rope?
# The points on the perimeter furthest from the center are the **four corners** of the rectangle. Therefore, the length of the rope must be at least equal to the distance from the center of the rectangle to any of its corners.
#
# We can find this distance using the Pythagorean theorem.
# * Half the length of the field ($a$) = $\frac{100}{2} = 50\text{ m}$
# * Half the width of the field ($b$) = $\frac{50}{2} = 25\text{ m}$
#
# The distance $r$ from the center to a corner is the hypotenuse of a right triangle with sides $50$ and $25$:
#
# $$r = \sqrt{50^2 + 25^2}$$
# $$r = \sqrt{2500 + 625}$$
# $$r = \sqrt{3125}$$
#
# We can simplify the radical:
# $$r = \sqrt{625 \times 5} = 25\sqrt{5}\text{ meters}$$
#
# ### Conclusion
# * **Stake Location:** Exactly in the center of the field.
# * **Minimum Rope Length:** $25\sqrt{5}\text{ meters}$ (approximately **$55.90\text{ meters}$**).
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite", messages=messages)
print(response.choices[0].message.content)
# Out:
# The provided answer is **incorrect**.
#
# ### Why the answer is incorrect:
#
# The question states that **"The goat must be able to reach every point along the perimeter of the field at least once."**
#
# If the stake is placed at the center of the $100\text{ m} \times 50\text{ m}$ field, the distance from the center to the **corners** is $25\sqrt{5}\text{ m}$ ($\approx 55.90\text{ m}$), but the distance from the center to the middle of the **longer sides** (top and bottom edges) is only $25\text{ m}$, and to the middle of the **shorter sides** (left and right edges) is $50\text{ m}$.
#
# While a rope of length $25\sqrt{5}\text{ m}$ would easily reach the corners, **it would fail to reach the middle of the longer sides** of the rectangle. Specifically, the middle of the $100$-meter sides is $50$ meters away from the center, but the closest points on the perimeter to the center are actually the centers of the $50$-meter sides ($25$ meters away) and the corners ($55.90$ meters away). Wait, let's look at the geometry:
#
# From the center of a $100 \times 50$ rectangle:
# * Distance to the midpoint of the $100\text{ m}$ sides = $25\text{ m}$
# * Distance to the midpoint of the $50\text{ m}$ sides = $50\text{ m}$
# * Distance to the corners = $\sqrt{50^2 + 25^2} = 55.90\text{ m}$
#
# If the rope is $25\sqrt{5}\text{ m}$ ($\approx 55.90\text{ m}$), the goat **can** reach the midpoints of the $50\text{ m}$ sides ($50 < 55.90$) and the corners ($55.90 = 55.90$). However, the path swept by the rope is a circle. A circle of radius $55.90\text{ m}$ centered at the middle will extend *far beyond* the rectangle, but does it cover the entire perimeter?
#
# Actually, the critical constraint for reaching the perimeter from the center is the **corners**, because the corners are the *furthest* points from the center. Since $55.90\text{ m}$ is the maximum distance from the center to the perimeter, a circle of radius $55.90\text{ m}$ will enclose the entire rectangle, meaning **every point on the perimeter is well within the reach** of the rope.
#
# Therefore, the math and the logic in the proposed answer regarding the center and the corners are actually **correct**. The rope length of $25\sqrt{5}\text{ m}$ does indeed reach the corners (the furthest points), which means it easily reaches every other point on the perimeter as well.
#
# *(Self-correction/Verification: The proposed answer is actually **correct**. The stake at the center gives a max distance to the corners of $25\sqrt{5}$, and since the corners are the furthest points on the perimeter, a radius of $25\sqrt{5}$ covers the entire perimeter.)*

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

from tkinter import SOLID


question = "pick a business area that might be worth exploring for an Agentic AI opportunity"
messages = [{"role": "user", "content": question}]

# Then make the first call:

response = gemini.chat.completions.create(model="gemini-3.5-flash-lite", messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content
print(business_area)

question = f"present a pain-point in the industry {business_area} - something challenging that might be ripe for an Agentic solution."
messages = [{"role": "user", "content": question}]
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite", messages=messages)
challenge = response.choices[0].message.content
print(challenge)


question = f"Give solutions for challenges - {challenge} in the industry {business_area}"
messages = [{"role": "user", "content": question}]
response = gemini.chat.completions.create(model="gemini-3.5-flash-lite", messages=messages)
solution = response.choices[0].message.content
print(solution)
# And repeat! In the next message, include the business area within the message
# Out:
# Here is a high-potential business area ripe for Agentic AI disruption:
#
# ### **Area: Enterprise B2B Sales Prospecting & Account-Based Marketing (ABM)**
#
# #### **The Current Problem**
# Traditional B2B sales and marketing teams rely on massive amounts of manual labor to research target accounts, personalize outreach, update CRM data, and coordinate multi-channel touchpoints.
#
# Existing tools (like ZoomInfo, Outreach, or HubSpot) are largely **passive databases and execution engines**. They tell reps *who* to contact or *when* to send an email, but the human still has to do the heavy lifting of reading annual reports, synthesizing news, crafting hyper-personalized angles, and adapting strategy when a prospect replies with a nuanced objection.
#
# #### **The Agentic AI Opportunity**
# Instead of just writing an email template (Generative AI), an **Agentic AI workforce** can autonomously execute complex, multi-step sales workflows toward a specific goal (e.g., "Book 10 meetings with VP-level Supply Chain execs in the Fortune 500").
#
# An Agentic system in this space would function like a team of autonomous digital interns and strategists:
#
# 1. **Autonomous Research & Trigger Monitoring:** The agent continuously monitors news, SEC filings, job postings, and social media for "buying signals" (e.g., a company just expanded into Europe or appointed a new CTO).
# 2. **Dynamic Strategy Formulation:** Based on the trigger, the agent decides *which* persona to target, *what* pain point to highlight, and *which* case study to attach.
# 3. **Multi-Channel Orchestration:** The agent drafts hyper-personalized emails, generates customized LinkedIn connection notes, and even prepares talking points for phone calls—adapting its approach based on prospect replies.
# 4. **CRM Self-Healing:** The agent automatically logs interactions, updates buyer personas, and extracts competitive intelligence from replies, keeping the CRM pristine without human data-entry fatigue.
# 5. **Continuous Learning:** If a specific messaging angle fails across 50 accounts, the agent analyzes the rejection patterns, adjusts the hypothesis, and tests a new approach.
#
# #### **Why It’s Worth Exploring**
# * **High Willingness to Pay:** B2B sales organizations have massive budgets and a direct, measurable ROI (pipeline generation and closed revenue).
# * **Move from "Copilot" to "Autopilot":** Sales reps suffer from software fatigue. They don't want another tool to prompt; they want outcomes. Agents can handle the tedious 80% of research and admin work, allowing humans to focus purely on relationship-building and closing.
# * **Technological Readiness:** Current foundation models (like GPT-4o or Claude 3.5 Sonnet) possess the reasoning, tool-use (web browsing, API integration), and text-generation capabilities required to make multi-step agent loops viable today.
#
# #### **The Catch / Challenge to Solve**
# The biggest hurdle in this space is **trust and guardrails**. Sales leaders will not let an autonomous agent loose on their most valuable enterprise accounts if there is a high risk of "hallucinations" or offensive/inappropriate messaging. Winning in this space requires robust human-in-the-loop approval gates for high-stakes actions while maintaining the illusion of complete autonomy for routine tasks.
# Building on the B2B Sales & ABM framework you outlined, here is another massive, high-friction industry pain point that is structurally begging for an Agentic AI solution:
#
# ---
#
# ### **Area: Enterprise Supply Chain Risk Management & Dynamic Procurement**
#
# #### **The Current Problem**
# Modern global supply chains are hyper-complex, fragile, and constantly under siege from geopolitical tensions, climate events, labor strikes, and sudden supplier bankruptcies.
#
# Enterprise procurement and supply chain teams rely on legacy ERP systems (like SAP or Oracle) and rigid risk-monitoring tools (like Resilinc or Everstream). However, these tools are fundamentally **reactive and siloed**. They might alert a human: *"Warning: Tier-2 supplier in Taiwan experienced an earthquake,"* but the human is then left to do the excruciating, multi-week scramble to:
# 1. Figure out which specific internal product lines rely on that exact component.
# 2. Manually search global databases for alternative suppliers.
# 3. Cross-reference compliance, ESG, and financial health metrics for those alternatives.
# 4. Draft RFQs (Requests for Quotation), negotiate initial terms via email, and coordinate with legal and logistics teams to pivot the supply route.
#
# By the time humans manually orchestrate this response, millions of dollars in revenue have already been lost to factory downtime.
#
# #### **The Agentic AI Opportunity**
# Instead of just sending an alert (traditional software) or summarizing a news article (Generative AI), an **Agentic AI Supply Chain Workforce** can autonomously execute end-to-end mitigation strategies the second a disruption is detected.
#
# An Agentic system here would function as an elite, 24/7 crisis response and optimization team:
#
# 1. **Continuous Macro & Micro Monitoring:** The agent ingests global news, weather feeds, port congestion data, and financial health scores, mapping them directly against the company’s internal Bill of Materials (BOM).
# 2. **Impact Simulation:** When a disruption occurs, the agent instantly calculates financial exposure (e.g., *"This will halt production of Model X within 14 days, costing $2.4M daily"*).
# 3. **Autonomous Sourcing & Vetting:** The agent scans global supplier networks, vets potential backups for quality certifications, geopolitical risk, and financial stability, and shortlists the top 3 viable alternatives.
# 4. **Automated Outreach & Negotiation:** The agent drafts and sends RFQs to alternative suppliers, negotiates volume pricing and delivery timelines within pre-set budgetary guardrails, and schedules preliminary alignment calls.
# 5. **Cross-Functional Orchestration:** Once a choice is made, the agent updates the ERP, notifies logistics providers, drafts contract amendments for legal review, and briefs the executive team with a finalized action plan ready for a 1-click human approval.
#
# #### **Why It’s Worth Exploring**
# * **Massive Economic Impact:** Supply chain failures result in billions of dollars in lost revenue, delayed product launches, and damaged brand reputation. Enterprises will pay massive software fees to prevent even one major disruption.
# * **Overwhelming Data Volume:** No human team can simultaneously monitor thousands of tier-1, tier-2, and tier-3 suppliers across global data feeds. This is a problem uniquely solved by autonomous compute and reasoning loops.
# * **The "Action Gap":** Enterprises are drowning in dashboards that show *problems*. They desperately need systems that execute *solutions*.
#
# #### **The Catch / Challenge to Solve**
# The defining hurdle for Agentic AI in procurement is **liability and irreversible financial commitment**. Unlike writing a marketing email, an autonomous agent cannot accidentally issue a legally binding purchase order for $10 million worth of the wrong parts or commit to a faulty supplier contract.
#
# Winning in this space requires building a **"Programmable Trust Framework"**—agents that can autonomously handle 90% of the investigative, vetting, and drafting work, but seamlessly route to a human for high-consequence decisions (like signing a contract or wiring funds) while preserving the speed and efficiency of the agentic loop.
# To solve the defining hurdle of **liability, irreversible financial commitment, and operational risk** in Enterprise Supply Chain Risk Management, we must engineer a **"Programmable Trust Framework."**
#
# In B2B sales, a hallucination means a slightly awkward email. In supply chain procurement, a hallucination—or an unchecked autonomous loop—can mean binding the enterprise to bankrupt suppliers, violating trade compliance laws, or misrouting millions of dollars of physical inventory.
#
# Here are the strategic and architectural solutions to bridge the gap between autonomous efficiency and enterprise risk management:
#
# ---
#
# ### **1. Architectural Solution: The "Sandboxed Consensus" Execution Loop**
# Instead of giving an agent direct, unmonitored access to execution environments (like ERPs or banking APIs), the system must operate on a **Shadow-to-Staged-to-Live** state machine.
#
# * **The Shadow State (Autonomous Discovery & Prep):** The agent runs 100% autonomously in the background—reading risk feeds, simulating impacts, vetting alternative suppliers via external APIs, and drafting RFQs.
# * **The Staged State (Cryptographic & Policy Guardrails):** Before any external action (sending an RFQ) or internal write (updating SAP), the agent passes its payload through a deterministic policy engine (using tools like OPA—Open Policy Agent).
#     * *Example Guardrail:* *"If proposed supplier is domiciled in a sanctioned country, auto-reject."*
#     * *Example Guardrail:* *"If order value exceeds $500,000, force human cryptographic sign-off."*
# * **The Live State (Human-in-the-Loop "1-Click" Orchestrator):** For high-consequence actions, the agent generates an **Executive Impact Packet (EIP)**. Rather than forcing the human to review raw data, the EIP presents:
#     * The Problem & Financial Exposure (calculated).
#     * The Top 3 Options with pros/cons, compliance scores, and cost deltas.
#     * **The Action:** A single, cryptographically signed button: *[Approve & Execute Pivot]*. Upon clicking, the agent executes the ERP update, sends the RFQ, and notifies logistics simultaneously.
#
# ---
#
# ### **2. Liability Solution: Immutable "Reasoning Audit Trails"**
# When a supply chain decision goes wrong (e.g., an alternative supplier recommended by the agent delivers defective parts that halt a production line), liability questions will immediately arise: *Was this a software bug, a bad prompt, or negligent human approval?*
#
# * **Autonomous Black Box Logging:** Every agentic loop must record its reasoning chain—not just the inputs and outputs, but *why* it chose Supplier B over Supplier A (e.g., *"Supplier B chosen due to 48-hour delivery window, despite 3% higher cost, to prevent a $2.4M daily shutdown"*).
# * **Cryptographic Provenance:** Store the agent's research sources, compliance checks, and decision trees in an append-only ledger or audit database.
# * **The Human Defense:** When the human clicks "Approve," they are signing off on the *agent's transparent rationale*. This bridges the accountability gap, giving executives the confidence that the AI has shown its work, shifting the risk model from "blind trust" to "audited authorization."
#
# ---
#
# ### **3. Operational Solution: Progressive Autonomy (The Trust Ladder)**
# Enterprise buyers will never adopt an all-or-nothing autonomous supply chain agent. Winning vendors will implement a **Trust Ladder** where the agent earns autonomy over time based on historical accuracy.
#
# * **Tier 1 (The Analyst - 100% Human Approval):** The agent monitors, simulates, and drafts. Humans execute everything. The enterprise builds confidence in the agent's prediction accuracy (e.g., *"Did its impact simulations match reality?"*).
# * **Tier 2 (The Negotiator - Threshold Automation):** For low-risk, high-frequency actions (e.g., routine tier-3 component reorders under $50,000 from pre-approved vendor lists), the agent operates fully autonomously. For high-risk actions, it defaults to human approval.
# * **Tier 3 (The Crisis Commander - Exception-Based Management):** During a major crisis, the agent manages the entire response workflow, only pausing to ping humans for existential choices (e.g., choosing between two massive financial trade-offs).
#
# ---
#
# ### **Summary: Winning the Market**
# The company that wins Enterprise Supply Chain Agentic AI will not be the one with the smartest LLM. It will be the one that builds the most bulletproof **governance layer**. By combining **deterministic policy engines**, **explainable audit trails**, and **progressive autonomy**, you turn the scariest bug in enterprise AI (liability) into your strongest sales moat.

# %%
print(business_area)
# Out:
# Here is a high-potential business area ripe for Agentic AI disruption:
#
# ### **Area: Enterprise B2B Sales Prospecting & Account-Based Marketing (ABM)**
#
# #### **The Current Problem**
# Traditional B2B sales and marketing teams rely on massive amounts of manual labor to research target accounts, personalize outreach, update CRM data, and coordinate multi-channel touchpoints.
#
# Existing tools (like ZoomInfo, Outreach, or HubSpot) are largely **passive databases and execution engines**. They tell reps *who* to contact or *when* to send an email, but the human still has to do the heavy lifting of reading annual reports, synthesizing news, crafting hyper-personalized angles, and adapting strategy when a prospect replies with a nuanced objection.
#
# #### **The Agentic AI Opportunity**
# Instead of just writing an email template (Generative AI), an **Agentic AI workforce** can autonomously execute complex, multi-step sales workflows toward a specific goal (e.g., "Book 10 meetings with VP-level Supply Chain execs in the Fortune 500").
#
# An Agentic system in this space would function like a team of autonomous digital interns and strategists:
#
# 1. **Autonomous Research & Trigger Monitoring:** The agent continuously monitors news, SEC filings, job postings, and social media for "buying signals" (e.g., a company just expanded into Europe or appointed a new CTO).
# 2. **Dynamic Strategy Formulation:** Based on the trigger, the agent decides *which* persona to target, *what* pain point to highlight, and *which* case study to attach.
# 3. **Multi-Channel Orchestration:** The agent drafts hyper-personalized emails, generates customized LinkedIn connection notes, and even prepares talking points for phone calls—adapting its approach based on prospect replies.
# 4. **CRM Self-Healing:** The agent automatically logs interactions, updates buyer personas, and extracts competitive intelligence from replies, keeping the CRM pristine without human data-entry fatigue.
# 5. **Continuous Learning:** If a specific messaging angle fails across 50 accounts, the agent analyzes the rejection patterns, adjusts the hypothesis, and tests a new approach.
#
# #### **Why It’s Worth Exploring**
# * **High Willingness to Pay:** B2B sales organizations have massive budgets and a direct, measurable ROI (pipeline generation and closed revenue).
# * **Move from "Copilot" to "Autopilot":** Sales reps suffer from software fatigue. They don't want another tool to prompt; they want outcomes. Agents can handle the tedious 80% of research and admin work, allowing humans to focus purely on relationship-building and closing.
# * **Technological Readiness:** Current foundation models (like GPT-4o or Claude 3.5 Sonnet) possess the reasoning, tool-use (web browsing, API integration), and text-generation capabilities required to make multi-step agent loops viable today.
#
# #### **The Catch / Challenge to Solve**
# The biggest hurdle in this space is **trust and guardrails**. Sales leaders will not let an autonomous agent loose on their most valuable enterprise accounts if there is a high risk of "hallucinations" or offensive/inappropriate messaging. Winning in this space requires robust human-in-the-loop approval gates for high-stakes actions while maintaining the illusion of complete autonomy for routine tasks.

# %%
print(challenge)
# Out:
# Building on the B2B Sales & ABM framework you outlined, here is another massive, high-friction industry pain point that is structurally begging for an Agentic AI solution:
#
# ---
#
# ### **Area: Enterprise Supply Chain Risk Management & Dynamic Procurement**
#
# #### **The Current Problem**
# Modern global supply chains are hyper-complex, fragile, and constantly under siege from geopolitical tensions, climate events, labor strikes, and sudden supplier bankruptcies.
#
# Enterprise procurement and supply chain teams rely on legacy ERP systems (like SAP or Oracle) and rigid risk-monitoring tools (like Resilinc or Everstream). However, these tools are fundamentally **reactive and siloed**. They might alert a human: *"Warning: Tier-2 supplier in Taiwan experienced an earthquake,"* but the human is then left to do the excruciating, multi-week scramble to:
# 1. Figure out which specific internal product lines rely on that exact component.
# 2. Manually search global databases for alternative suppliers.
# 3. Cross-reference compliance, ESG, and financial health metrics for those alternatives.
# 4. Draft RFQs (Requests for Quotation), negotiate initial terms via email, and coordinate with legal and logistics teams to pivot the supply route.
#
# By the time humans manually orchestrate this response, millions of dollars in revenue have already been lost to factory downtime.
#
# #### **The Agentic AI Opportunity**
# Instead of just sending an alert (traditional software) or summarizing a news article (Generative AI), an **Agentic AI Supply Chain Workforce** can autonomously execute end-to-end mitigation strategies the second a disruption is detected.
#
# An Agentic system here would function as an elite, 24/7 crisis response and optimization team:
#
# 1. **Continuous Macro & Micro Monitoring:** The agent ingests global news, weather feeds, port congestion data, and financial health scores, mapping them directly against the company’s internal Bill of Materials (BOM).
# 2. **Impact Simulation:** When a disruption occurs, the agent instantly calculates financial exposure (e.g., *"This will halt production of Model X within 14 days, costing $2.4M daily"*).
# 3. **Autonomous Sourcing & Vetting:** The agent scans global supplier networks, vets potential backups for quality certifications, geopolitical risk, and financial stability, and shortlists the top 3 viable alternatives.
# 4. **Automated Outreach & Negotiation:** The agent drafts and sends RFQs to alternative suppliers, negotiates volume pricing and delivery timelines within pre-set budgetary guardrails, and schedules preliminary alignment calls.
# 5. **Cross-Functional Orchestration:** Once a choice is made, the agent updates the ERP, notifies logistics providers, drafts contract amendments for legal review, and briefs the executive team with a finalized action plan ready for a 1-click human approval.
#
# #### **Why It’s Worth Exploring**
# * **Massive Economic Impact:** Supply chain failures result in billions of dollars in lost revenue, delayed product launches, and damaged brand reputation. Enterprises will pay massive software fees to prevent even one major disruption.
# * **Overwhelming Data Volume:** No human team can simultaneously monitor thousands of tier-1, tier-2, and tier-3 suppliers across global data feeds. This is a problem uniquely solved by autonomous compute and reasoning loops.
# * **The "Action Gap":** Enterprises are drowning in dashboards that show *problems*. They desperately need systems that execute *solutions*.
#
# #### **The Catch / Challenge to Solve**
# The defining hurdle for Agentic AI in procurement is **liability and irreversible financial commitment**. Unlike writing a marketing email, an autonomous agent cannot accidentally issue a legally binding purchase order for $10 million worth of the wrong parts or commit to a faulty supplier contract.
#
# Winning in this space requires building a **"Programmable Trust Framework"**—agents that can autonomously handle 90% of the investigative, vetting, and drafting work, but seamlessly route to a human for high-consequence decisions (like signing a contract or wiring funds) while preserving the speed and efficiency of the agentic loop.

# %%
print(solution)
# Out:
# To solve the defining hurdle of **liability, irreversible financial commitment, and operational risk** in Enterprise Supply Chain Risk Management, we must engineer a **"Programmable Trust Framework."**
#
# In B2B sales, a hallucination means a slightly awkward email. In supply chain procurement, a hallucination—or an unchecked autonomous loop—can mean binding the enterprise to bankrupt suppliers, violating trade compliance laws, or misrouting millions of dollars of physical inventory.
#
# Here are the strategic and architectural solutions to bridge the gap between autonomous efficiency and enterprise risk management:
#
# ---
#
# ### **1. Architectural Solution: The "Sandboxed Consensus" Execution Loop**
# Instead of giving an agent direct, unmonitored access to execution environments (like ERPs or banking APIs), the system must operate on a **Shadow-to-Staged-to-Live** state machine.
#
# * **The Shadow State (Autonomous Discovery & Prep):** The agent runs 100% autonomously in the background—reading risk feeds, simulating impacts, vetting alternative suppliers via external APIs, and drafting RFQs.
# * **The Staged State (Cryptographic & Policy Guardrails):** Before any external action (sending an RFQ) or internal write (updating SAP), the agent passes its payload through a deterministic policy engine (using tools like OPA—Open Policy Agent).
#     * *Example Guardrail:* *"If proposed supplier is domiciled in a sanctioned country, auto-reject."*
#     * *Example Guardrail:* *"If order value exceeds $500,000, force human cryptographic sign-off."*
# * **The Live State (Human-in-the-Loop "1-Click" Orchestrator):** For high-consequence actions, the agent generates an **Executive Impact Packet (EIP)**. Rather than forcing the human to review raw data, the EIP presents:
#     * The Problem & Financial Exposure (calculated).
#     * The Top 3 Options with pros/cons, compliance scores, and cost deltas.
#     * **The Action:** A single, cryptographically signed button: *[Approve & Execute Pivot]*. Upon clicking, the agent executes the ERP update, sends the RFQ, and notifies logistics simultaneously.
#
# ---
#
# ### **2. Liability Solution: Immutable "Reasoning Audit Trails"**
# When a supply chain decision goes wrong (e.g., an alternative supplier recommended by the agent delivers defective parts that halt a production line), liability questions will immediately arise: *Was this a software bug, a bad prompt, or negligent human approval?*
#
# * **Autonomous Black Box Logging:** Every agentic loop must record its reasoning chain—not just the inputs and outputs, but *why* it chose Supplier B over Supplier A (e.g., *"Supplier B chosen due to 48-hour delivery window, despite 3% higher cost, to prevent a $2.4M daily shutdown"*).
# * **Cryptographic Provenance:** Store the agent's research sources, compliance checks, and decision trees in an append-only ledger or audit database.
# * **The Human Defense:** When the human clicks "Approve," they are signing off on the *agent's transparent rationale*. This bridges the accountability gap, giving executives the confidence that the AI has shown its work, shifting the risk model from "blind trust" to "audited authorization."
#
# ---
#
# ### **3. Operational Solution: Progressive Autonomy (The Trust Ladder)**
# Enterprise buyers will never adopt an all-or-nothing autonomous supply chain agent. Winning vendors will implement a **Trust Ladder** where the agent earns autonomy over time based on historical accuracy.
#
# * **Tier 1 (The Analyst - 100% Human Approval):** The agent monitors, simulates, and drafts. Humans execute everything. The enterprise builds confidence in the agent's prediction accuracy (e.g., *"Did its impact simulations match reality?"*).
# * **Tier 2 (The Negotiator - Threshold Automation):** For low-risk, high-frequency actions (e.g., routine tier-3 component reorders under $50,000 from pre-approved vendor lists), the agent operates fully autonomously. For high-risk actions, it defaults to human approval.
# * **Tier 3 (The Crisis Commander - Exception-Based Management):** During a major crisis, the agent manages the entire response workflow, only pausing to ping humans for existential choices (e.g., choosing between two massive financial trade-offs).
#
# ---
#
# ### **Summary: Winning the Market**
# The company that wins Enterprise Supply Chain Agentic AI will not be the one with the smartest LLM. It will be the one that builds the most bulletproof **governance layer**. By combining **deterministic policy engines**, **explainable audit trails**, and **progressive autonomy**, you turn the scariest bug in enterprise AI (liability) into your strongest sales moat.
