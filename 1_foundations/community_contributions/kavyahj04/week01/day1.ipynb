# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display, Markdown

# %%
load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")

if api_key:
    print(f"Open AI API Key found and key starts with - {api_key[0:9]}")
# Out:
# Open AI API Key found and key starts with - sk-proj-7

# %%
openai = OpenAI()

# %%
# First create the messages:
message = "You are a helpful assistant who pick a business area that might be worth exploring for an Agentic AI opportunity."
messages = [{"role": "user", "content": "Something here"}]

# Then make the first call:

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

# Then read the business idea:

business_area = response.choices[0].message.content

# And repeat! In the next message, include the business area within the message

# %%
messages = [{"role": "user", "content": f"Here is the business area: {business_area} present a pain point in this industry."}]

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

pain_point = response.choices[0].message.content

# And repeat! In the next message, include the business area within the message
messages = [{"role": "user", "content": f"Here is the business area: {business_area} present a pain point in this industry{pain_point}, propose the Agentic AI solution.While proposing follow this structure. 1. Business Area 2. Pain Point 3. Agentic AI solution"}]

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)

agentic_solution = response.choices[0].message.content

display(Markdown(agentic_solution))
# Out:
# 1. **Business Area**
#    **Project-based services, operations, or client delivery teams** where clear requirements and consistent communication are critical.
#
# 2. **Pain Point**
#    **Unclear requirements and poor communication** often cause projects to stall, expectations to drift, and teams to spend time reworking deliverables. This leads to delays, increased costs, frustration, and missed opportunities.
#
# 3. **Agentic AI Solution**
#    An **Agentic AI Requirements and Communication Assistant** that can proactively:
#    - ask clarifying questions when requests are vague
#    - summarize client needs into structured requirements
#    - detect missing information or conflicting instructions
#    - track decisions, action items, and approvals
#    - send follow-up reminders to keep stakeholders aligned
#    - update project documentation automatically as new information arrives
#
#    This helps teams reduce rework, improve alignment, speed up delivery, and keep projects moving with less manual coordination.
#
# If you want, I can also turn this into a **short pitch**, **slide-ready version**, or **industry-specific example**.
