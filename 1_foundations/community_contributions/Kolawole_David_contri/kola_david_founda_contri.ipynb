# %%
# Import the library for loading environment variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Set the override flag to True to allow the environment variables to be overridden
#This is important because only what you have in this environment variable in your folder is given priority.
load_dotenv(override=True)
# Out:
# True

# %%
#Import the os library to access the environment variables
import os 
#Get the OpenAI API key from the environment variables
open_api_key = os.getenv("OPENAI_API_KEY")
#Check if the OpenAI API key exists and print the first 8 characters of the key
if open_api_key:
    print(f"OpenAI API key exists and begins {open_api_key[:8]}")
else:
    print("OpenAI API key not set -please fix")
# Out:
# OpenAI API key exists and begins sk-proj-

# %%
#Import the OpenAI library : a light library that helps you cnnect with openAI in the cloud
from openai import OpenAI

#Create an instance of the OpenAI class
openai = OpenAI()

# %%
# Create a list of jmesages in the familiar OpenAI formatat
messages = [{"role": "user", "content": "How many countries are in the United Kingdom, please list them"}]

# Call the OpenAI API with the messages
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)


# print the response
print(response.choices[0].message.content)
# Out:
# The United Kingdom (UK) consists of four countries. They are:
#
# 1. England
# 2. Scotland
# 3. Wales
# 4. Northern Ireland

# %%
question = "Please provide a question assess someone's IQ. Kindly respond only with a question"
messages = [{"role":"user","content":question}]

# Call the OpenAI API wuth messages  and the model 
question = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

#print response as a question
print(question.choices[0].message.content)
# Out:
# If two hours ago, it was as long after one o'clock in the afternoon as it was before one o'clock in the morning yesterday, what time is it now?

# %% [markdown]
# <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>

# %%
request = """Pick a business area that is usper viable for agentic AI opportunity 
or business , present a pain-point in that industry especially areas that are ripe for Agentic solution , then propose a step by step solution"""

messages = [{"role":"user", "content": request}]

#call AI response
response_1 = openai.chat.completions.create(
    model ="gpt-4.1-mini",
    messages = messages   
)

answer = response_1.choices[0].message.content

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# **Business Area:** Healthcare Revenue Cycle Management (RCM)
#
# ---
#
# ### Pain-point:
#
# **Manual and error-prone billing and claims processing**
#
# Healthcare providers struggle with the complexity of coding, billing, and claims submissions. This process is manual, time-consuming, and prone to errors leading to delayed reimbursements, claim denials, and increased administrative costs. Current automation is mostly rule-based and cannot effectively handle ambiguous cases or dynamically adapt to changing payer requirements, causing significant revenue leakage.
#
# ---
#
# ### Why agentic AI is ripe here:
#
# - **Autonomy:** Agentic AI can proactively manage end-to-end billing and claims processes without human intervention.
# - **Adaptability:** It can learn and adapt to differing payer policies and coding updates in real-time.
# - **Decision-making:** Agentic AI can make contextual decisions about claim correctness, appeal denials, and optimize billing strategies.
# - **Continuous improvement:** It can self-analyze outcomes and improve processes to reduce errors and speed up revenue cycles.
#
# ---
#
# ### Step-by-step proposed solution:
#
# **Step 1: Data Integration and Preprocessing**
# - Integrate EHR (Electronic Health Records), billing software, and payer portals into a unified data platform.
# - Preprocess historical claims data, identifying patterns in denials, delays, and coding errors.
#
# **Step 2: Develop Agentic AI Billing/Claims Agent**
# - Build an AI agent equipped with natural language processing (NLP) to understand clinical notes and extract billing-relevant information.
# - Implement reinforcement learning to enable the agent to learn from successful and unsuccessful claims.
# - Embed rule-based knowledge of coding standards (e.g., ICD-10, CPT) along with machine-learned heuristics.
#
# **Step 3: Automated Coding and Claims Preparation**
# - The AI agent interprets clinical data to auto-generate accurate claims.
# - It dynamically validates codes against the latest payer rules, catching potential errors before submission.
#
# **Step 4: Autonomous Claims Submission and Monitoring**
# - The agent submits claims to payers through integrated portals.
# - It continuously monitors claim status and automatically responds to payer queries or requests for additional info.
#
# **Step 5: Intelligent Denial Management and Appeals**
# - For denied claims, the agent diagnoses root causes using AI explainability tools.
# - It autonomously prepares and submits appeal documents, referencing relevant policy and clinical data.
# - Tracks appeal outcomes and learns to minimize future denials.
#
# **Step 6: Continuous Feedback and Optimization Loop**
# - The system periodically audits revenue cycle KPIs (e.g., days in accounts receivable, denial rates).
# - Self-adjusts rules, updates coding models, and proposes workflow changes to human supervisors.
# - Human oversight is available for exceptions or complex cases.
#
# **Step 7: Integration with Workforce and Reporting**
# - Provide dashboards and alerts to billing staff highlighting agent activities and exceptions.
# - Facilitate knowledge transfer and transparency to build trust and improve collaboration.
#
# ---
#
# ### Expected Benefits:
#
# - Significant reduction in manual billing errors and claim denials.
# - Faster claims processing and improved cash flow for healthcare providers.
# - Lower administrative burden and cost savings.
# - Scalable, adaptive system that keeps up with regulatory and payer changes.
# - Enhanced compliance and audit readiness.
#
# ---
#
# **Summary:**
# Healthcare revenue cycle management’s complex and error-prone billing process is highly suitable for an agentic AI solution. By autonomously handling claim generation, submission, denial management, and continuous feedback, agentic AI can deliver substantial efficiency, accuracy, and financial improvements.
