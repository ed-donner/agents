# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai= OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
print(f"total_tokens= {response.usage.total_tokens}")
print(response.choices[0].message.content)
# Out:
# total_tokens= 59
# Fun fact: Octopuses have three hearts—two pump blood to the gills, and one pumps blood to the rest of their body. Also, their blood is blue because it uses copper-based hemocyanin.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
question = response.choices[0].message.content
print(f"total_tokens= {response.usage.total_tokens}")
print(question)
# Out:
# total_tokens= 125
# A researcher has three sealed boxes labeled A, B, and C. One box contains a gold coin, one contains a silver coin, and one contains two coins of the same metal. The labels are all incorrect. You may open exactly one box, look at exactly one coin inside it, and then you must determine the contents of all three boxes with certainty. Which box should you open, what coin would you need to observe, and how do you deduce the contents of each box?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'A researcher has three sealed boxes labeled A, B, and C. One box contains a gold coin, one contains a silver coin, and one contains two coins of the same metal. The labels are all incorrect. You may open exactly one box, look at exactly one coin inside it, and then you must determine the contents of all three boxes with certainty. Which box should you open, what coin would you need to observe, and how do you deduce the contents of each box?'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="gpt-5.4-mini", messages=messages)
print(f"total_tokens= {response.usage.total_tokens}")
answer = response.choices[0].message.content
print(answer)
# Out:
# total_tokens= 504
# Open the box labeled **C**.
#
# ### Why C?
# Since **all labels are incorrect**, the box labeled **“two coins of the same metal”** cannot actually contain two coins of the same metal. So box **C** must contain **one gold and one silver coin**.
#
# ### What coin do you need to see?
# You only need to observe **either coin** inside box C:
# - If you see **gold**, then C = **gold + silver**.
# - If you see **silver**, then C = **gold + silver**.
#
# Either way, opening C tells you its contents immediately.
#
# ### How to deduce the other boxes
# Once you know C contains **one gold and one silver**, the remaining two boxes must contain:
# - the **two-gold** box
# - the **two-silver** box
#
# Now use the incorrect labels:
#
# - Box **A** is labeled something it cannot be.
# - Box **B** is labeled something it cannot be.
#
# There are only two possibilities left:
#
# #### Case 1: You see **gold** in box C
# Then C = **G/S**.
# The remaining boxes A and B must be **GG** and **SS**.
#
# - If box **A** is labeled “silver,” it cannot be SS, so A must be **GG**.
# - Then B must be **SS**.
#
# #### Case 2: You see **silver** in box C
# Then C = **G/S** again.
# Same logic applies:
# - If box **A** is labeled “gold,” it cannot be GG, so A must be **SS**.
# - Then B must be **GG**.
#
# ### In short
# - **Open box C**
# - **Any coin you see inside confirms C is the mixed box**
# - Then the other two boxes are determined by eliminating the impossible labelings
#
# If you want, I can also give a compact “logic table” version of the solution.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Open the box labeled **C**.
#
# ### Why C?
# Since **all labels are incorrect**, the box labeled **“two coins of the same metal”** cannot actually contain two coins of the same metal. So box **C** must contain **one gold and one silver coin**.
#
# ### What coin do you need to see?
# You only need to observe **either coin** inside box C:
# - If you see **gold**, then C = **gold + silver**.
# - If you see **silver**, then C = **gold + silver**.
#
# Either way, opening C tells you its contents immediately.
#
# ### How to deduce the other boxes
# Once you know C contains **one gold and one silver**, the remaining two boxes must contain:
# - the **two-gold** box
# - the **two-silver** box
#
# Now use the incorrect labels:
#
# - Box **A** is labeled something it cannot be.
# - Box **B** is labeled something it cannot be.
#
# There are only two possibilities left:
#
# #### Case 1: You see **gold** in box C
# Then C = **G/S**.
# The remaining boxes A and B must be **GG** and **SS**.
#
# - If box **A** is labeled “silver,” it cannot be SS, so A must be **GG**.
# - Then B must be **SS**.
#
# #### Case 2: You see **silver** in box C
# Then C = **G/S** again.
# Same logic applies:
# - If box **A** is labeled “gold,” it cannot be GG, so A must be **SS**.
# - Then B must be **GG**.
#
# ### In short
# - **Open box C**
# - **Any coin you see inside confirms C is the mixed box**
# - Then the other two boxes are determined by eliminating the impossible labelings
#
# If you want, I can also give a compact “logic table” version of the solution.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A researcher has three sealed boxes labeled A, B, and C. One box contains a gold coin, one contains a silver coin, and one contains two coins of the same metal. The labels are all incorrect. You may open exactly one box, look at exactly one coin inside it, and then you must determine the contents of all three boxes with certainty. Which box should you open, what coin would you need to observe, and how do you deduce the contents of each box?
#
# And here is a possible answer that might be correct or incorrect:
# Open the box labeled **C**.
#
# ### Why C?
# Since **all labels are incorrect**, the box labeled **“two coins of the same metal”** cannot actually contain two coins of the same metal. So box **C** must contain **one gold and one silver coin**.
#
# ### What coin do you need to see?
# You only need to observe **either coin** inside box C:
# - If you see **gold**, then C = **gold + silver**.
# - If you see **silver**, then C = **gold + silver**.
#
# Either way, opening C tells you its contents immediately.
#
# ### How to deduce the other boxes
# Once you know C contains **one gold and one silver**, the remaining two boxes must contain:
# - the **two-gold** box
# - the **two-silver** box
#
# Now use the incorrect labels:
#
# - Box **A** is labeled something it cannot be.
# - Box **B** is labeled something it cannot be.
#
# There are only two possibilities left:
#
# #### Case 1: You see **gold** in box C
# Then C = **G/S**.
# The remaining boxes A and B must be **GG** and **SS**.
#
# - If box **A** is labeled “silver,” it cannot be SS, so A must be **GG**.
# - Then B must be **SS**.
#
# #### Case 2: You see **silver** in box C
# Then C = **G/S** again.
# Same logic applies:
# - If box **A** is labeled “gold,” it cannot be GG, so A must be **SS**.
# - Then B must be **GG**.
#
# ### In short
# - **Open box C**
# - **Any coin you see inside confirms C is the mixed box**
# - Then the other two boxes are determined by eliminating the impossible labelings
#
# If you want, I can also give a compact “logic table” version of the solution.
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(f"total_tokens= {response.usage.total_tokens}")
print(response.choices[0].message.content)
# Out:
# total_tokens= 687
# Incorrect.
#
# The proposed answer assumes box C is labeled “two coins of the same metal,” but the problem only says the boxes are labeled A, B, and C. It does not specify what labels A, B, and C correspond to. So “open C” is not justified.
#
# More importantly, the correct strategy in this type of puzzle is:
#
# - Open the box labeled as the mixed box.
# - Because all labels are wrong, that box cannot be mixed.
# - Looking at one coin tells you whether that box is the two-gold box or the two-silver box.
# - Then the other two boxes can be deduced from the fact that all labels are incorrect.
#
# So the given answer is incorrect because it relies on an unsupported assumption about what C means.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from IPython.display import Markdown, display


# First create the messages:
question="Pick a business area that might be worth exploring for an Agentic AI opportunity"
messages = [
    {"role": "user", 
    "content": question}]

# Then make the first call:
response =openai.chat.completions.create(model="gpt-5.4-mini",messages=messages)
#display(Markdown(response.choices[0].message.content))
#then read the business idea
business_area=response.choices[0].message.content
print(business_area)
# Out:
# A strong business area to explore is **customer support / service operations**.
#
# Why this is a good Agentic AI opportunity:
# - **High volume, repetitive work**: Many tickets involve similar workflows, triage, lookup, and follow-up.
# - **Clear tools and actions**: Agents can read emails/chats, check CRM or order systems, draft responses, create tickets, issue refunds, and escalate when needed.
# - **Measurable ROI**: Faster resolution times, lower support costs, and improved customer satisfaction are easy to track.
# - **Natural fit for autonomy**: An agent can handle end-to-end cases within defined guardrails, only involving humans for exceptions.
#
# Good starting use cases:
# - Ticket triage and routing
# - Drafting first responses
# - Handling order status, returns, and refunds
# - Scheduling callbacks or appointments
# - Updating CRM records after interactions
#
# If you want, I can also suggest:
# 1. **3 other promising business areas**, or
# 2. a **framework for choosing the best Agentic AI opportunity** in your industry.

# %%
# Then read the business idea:

question=f"present a pain-point in the industry {business_area} - something challenging that might be ripe for an Agentic solution."
messages=[{
    "role":"user",
    "content": question
}]
response=openai.chat.completions.create(model="gpt-5.4-mini",messages=messages);
challenges = response.choices[0].message.content
display(Markdown(challenges))

# And repeat! In the next message, include the business area within the message
# Out:
# A strong pain point in **customer support / service operations** that’s ripe for an Agentic AI solution is:
#
# ## **“The long-tail of repetitive, multi-step support requests that require context switching across systems.”**
#
# ### Why this is a pain point
# Support teams spend a lot of time on cases that are simple in principle but annoying in practice, such as:
# - “Where is my order?”
# - “I need to change my address”
# - “Can I get a refund?”
# - “My account isn’t working”
# - “Can you reschedule my appointment?”
#
# Individually, these are straightforward. But in reality, each one often requires:
# - reading the customer message,
# - identifying intent,
# - checking order/CRM/billing/shipping systems,
# - validating policy rules,
# - drafting a response,
# - updating records,
# - sometimes escalating.
#
# That creates delays, inconsistency, and high operational cost.
#
# ### What makes it challenging
# This is not just a FAQ bot problem. The challenge is:
# - **Multiple systems**: CRM, ticketing, order management, billing, logistics.
# - **Policy complexity**: refunds, eligibility, exceptions, edge cases.
# - **Human handoff**: when confidence is low or the case is sensitive.
# - **High expectations**: customers want fast, accurate, personalized responses.
#
# ### Why it’s ripe for Agentic AI
# An agent can:
# - classify the request,
# - gather needed data across systems,
# - decide the next action within rules,
# - draft or send the response,
# - trigger workflow actions like refund, replacement, or escalation,
# - log everything for auditability.
#
# ### Business impact
# This can reduce:
# - first-response time,
# - average handle time,
# - support backlog,
# - agent workload on repetitive cases.
#
# It can improve:
# - customer satisfaction,
# - consistency,
# - 24/7 service coverage.
#
# ### A good “agentic” wedge
# A practical first version would be:
# - **agent handles common cases end-to-end**
# - **human reviews exceptions**
# - **confidence thresholds and approval rules** for sensitive actions like refunds
#
# If you want, I can turn this into:
# 1. a **specific use case statement**,
# 2. an **ICP + buyer persona**, or
# 3. a **problem/solution slide format** for a pitch deck.

# %%
question=f"Give solutions for challenges - {challenges} in the industry {business_area}"
messages=[
    {"role":"user",
    "content":question
    }]

response=openai.chat.completions.create(model="gpt-5.4-mini",messages=messages)
solution=response.choices[0].message.content
#print(solution)
display(Markdown(solution))
# Out:
# Here are practical **Agentic AI solution ideas** for the customer support / service operations pain point you described — specifically the **long-tail of repetitive, multi-step requests across multiple systems**.
#
# ## 1) End-to-end request resolution agent
# **What it does:**
# Handles common support requests from intake to resolution.
#
# **Example cases:**
# - order status / “where is my order?”
# - change shipping address
# - cancel order
# - refund eligibility check
# - reschedule appointment
#
# **How it works:**
# 1. Reads the customer message
# 2. Detects intent and urgency
# 3. Pulls data from CRM, order, billing, or scheduling systems
# 4. Checks policy rules
# 5. Takes the allowed action
# 6. Drafts or sends the response
# 7. Logs everything in the ticket
#
# **Why it’s valuable:**
# Removes repetitive work from agents and reduces response times.
#
# ---
#
# ## 2) Smart triage + routing agent
# **What it does:**
# Classifies tickets, prioritizes them, and routes them to the right queue or human agent.
#
# **Example actions:**
# - identify billing vs technical vs logistics issue
# - detect VIP or high-risk customers
# - assign based on language, region, or skill
# - flag urgent cases like outages or fraud
#
# **Why it’s valuable:**
# Prevents misrouting and speeds up resolution before a human even sees the case.
#
# ---
#
# ## 3) Policy-aware resolution agent
# **What it does:**
# Evaluates whether a request is eligible under company policy and suggests or executes the next step.
#
# **Example cases:**
# - refund approval based on time window
# - replacement eligibility
# - exception handling for loyal customers
# - cancellation fees
#
# **Guardrails:**
# - auto-execute only below a threshold
# - require human approval for exceptions
# - preserve audit trail
#
# **Why it’s valuable:**
# Reduces inconsistent policy interpretation and improves compliance.
#
# ---
#
# ## 4) Customer communication agent
# **What it does:**
# Drafts personalized, accurate responses based on customer context and system data.
#
# **Example outputs:**
# - “Your package is delayed and arriving tomorrow.”
# - “Your refund has been approved and will post within 3–5 business days.”
# - “We need one more verification step to update your address.”
#
# **Why it’s valuable:**
# Cuts agent writing time and improves consistency across support channels.
#
# ---
#
# ## 5) Workflow execution agent
# **What it does:**
# Takes action in backend systems after a decision is made.
#
# **Example actions:**
# - create refund request
# - issue replacement order
# - update customer contact details
# - reschedule appointment
# - reopen or escalate ticket
#
# **Why it’s valuable:**
# Eliminates manual copy-paste work across tools and reduces operational friction.
#
# ---
#
# ## 6) Exception-handling escalation agent
# **What it does:**
# Detects when a case is outside policy or confidence is low, then escalates with context.
#
# **What it sends to the human:**
# - summary of issue
# - customer history
# - actions already taken
# - recommended next step
# - reason for escalation
#
# **Why it’s valuable:**
# Makes human handoff faster and cleaner, especially for edge cases and sensitive requests.
#
# ---
#
# ## 7) Post-interaction update agent
# **What it does:**
# Automatically updates CRM, ticket notes, and case status after the interaction.
#
# **Example tasks:**
# - write call/chat summary
# - tag issue type
# - update resolution code
# - add follow-up reminders
# - record SLA status
#
# **Why it’s valuable:**
# Saves agents time after the customer conversation ends, which is often a hidden cost center.
#
# ---
#
# # Best “first wedge” for implementation
# The strongest initial Agentic AI use case is usually:
#
# ## **Common-case resolution with human approval for exceptions**
# This means:
# - the agent handles standard requests end-to-end
# - humans review only edge cases or sensitive actions
# - confidence thresholds determine whether to auto-act or escalate
#
# ### Why this is the best starting point:
# - high volume
# - repetitive workflows
# - clear business ROI
# - easy to measure
# - lower risk than fully autonomous support
#
# ---
#
# # Example solution architecture
# A simple agentic support workflow could look like this:
#
# 1. **Intake layer**
#    Email/chat/form comes in
#
# 2. **Intent detection**
#    Agent identifies request type
#
# 3. **Context retrieval**
#    Pulls data from CRM, order system, billing, shipping, etc.
#
# 4. **Policy engine**
#    Checks eligibility and constraints
#
# 5. **Action execution**
#    Performs allowed task or drafts next step
#
# 6. **Human review if needed**
#    Exception or sensitive case routed to agent
#
# 7. **Logging and audit**
#    All actions and decisions recorded
#
# ---
#
# # Business impact
# This can help improve:
# - first response time
# - average handle time
# - case deflection
# - support backlog
# - agent productivity
# - customer satisfaction
#
# And reduce:
# - manual lookup work
# - repetitive ticket handling
# - escalation volume
# - inconsistent responses
#
# ---
#
# # If you want to turn this into a pitchable opportunity, the clearest framing is:
#
# ## Problem
# Support teams waste time on repetitive, multi-step requests that require context switching across systems.
#
# ## Solution
# An agentic support layer that can understand requests, gather context, apply policy, execute actions, and escalate exceptions.
#
# ## Outcome
# Faster resolution, lower cost, higher consistency, and better customer experience.
#
# If you want, I can next turn this into one of these formats:
# 1. **a crisp problem/solution slide**,
# 2. **an ICP + buyer persona**, or
# 3. **a list of 10 concrete support workflows to automate first**.
